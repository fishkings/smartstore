# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\kcjer\\smartstore'

# %%
pd.set_option('display.max_rows', None)
df = pd.read_csv("primaryCategoryDate\cid_life_keyword.csv")
df
# Out:
#            cid           title
# 0     50000001            패션잡화
# 1     50000002          화장품/미용
# 2     50000003          디지털/가전
# 3     50000004         가구/인테리어
# 4     50000005           출산/육아
# 5     50000006              식품
# 6     50000007          스포츠/레저
# 7     50000008           생활/건강
# 8     50000009         여가/생활편의
# 9     50000013             화장품
# 10    50000014              향수
# 11    50000015          시계/기프트
# 12    50000016             주얼리
# 13    50000017           패션/잡화
# 14    50000018            전자제품
# 15    50000019           식품/건강
# 16    50000020           마라톤용품
# 17    50000021            당구용품
# 18    50000022         기타스포츠용품
# 19    50000023            건강식품
# 20    50000024          다이어트식품
# 21    50000026       냉동/간편조리식품
# 22    50000027              등산
# 23    50000028              캠핑
# 24    50000029              골프
# 25    50000030              헬스
# 26    50000031         요가/필라테스
# 27    50000033         인라인스케이트
# 28    50000034      스케이트/보드/롤러
# ...

# %%
df.set_index('cid', inplace=True)

# %%
df
# Out:
#              title
# cid
# 50000001      패션잡화
# 50000002    화장품/미용
# 50000003    디지털/가전
# 50000004   가구/인테리어
# 50000005     출산/육아
# ...            ...
# 50015120  방음/방진/흡음
# 50015140     점화케이블
# 50015160    기타전기용품
# 50015200        휴즈
# 50015340       에코백
#
# [4482 rows x 1 columns]

# %%
df = pd.read_csv("primaryCategoryDate\cid_keyword.csv")
d
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...
