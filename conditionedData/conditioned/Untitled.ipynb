# %%
import requests

cookies = {
    'NNB': '6TTK2RJU3JPWG',
    '_ga': 'GA1.2.1198469368.1669035888',
    'NV_WETR_LOCATION_RGN_M': '"MDUxMTAxMTE="',
    'ASID': '6f5bbfa400000184fa368e5f00000067',
    'NV_WETR_LAST_ACCESS_RGN_M': '"MDUxMTAxMTE="',
    'nx_ssl': '2',
    'nid_inf': '813506172',
    'NID_JKL': '7GO4JgsGQ6jSmPyQ+d0zZPEWBjZqV6VoPgsqFdP360s=',
    'NaverSuggestUse': 'unuse%26use',
    'NID_AUT': 'D2QOxk1i/qhN7mlsiYlMrQnnUV8Gl+BXV86T78q51HMwExxzB7wcbgptaPWfOS0c',
    'NID_SES': '...',
    'page_uid': 'iT8QXwqVOsossuqnkJlssssstIw-032198',
    '_datalab_cid': '50000000',
}

headers = {
    'authority': 'datalab.naver.com',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    # 'cookie': 'NNB=6TTK2RJU3JPWG; _ga=GA1.2.1198469368.1669035888; NV_WETR_LOCATION_RGN_M="MDUxMTAxMTE="; ASID=6f5bbfa400000184fa368e5f00000067; NV_WETR_LAST_ACCESS_RGN_M="MDUxMTAxMTE="; nx_ssl=2; nid_inf=813506172; NID_JKL=7GO4JgsGQ6jSmPyQ+d0zZPEWBjZqV6VoPgsqFdP360s=; NaverSuggestUse=unuse%26use; NID_AUT=D2QOxk1i/qhN7mlsiYlMrQnnUV8Gl+BXV86T78q51HMwExxzB7wcbgptaPWfOS0c; NID_SES=...; page_uid=iT8QXwqVOsossuqnkJlssssstIw-032198; _datalab_cid=50000000',
    'referer': 'https://datalab.naver.com/keyword/trendSearch.naver',
    'sec-ch-ua': '"Google Chrome";v="119", "Chromium";v="119", "Not?A_Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36',
}

params = {
    'hashKey': 'N_4d0923e64228c4dc9f4f159d8ceedc2d',
}

response = requests.get('https://datalab.naver.com/keyword/trendResult.naver', params=params, cookies=cookies, headers=headers)

# %%
from bs4 import BeautifulSoup
html = response.text
soup = BeautifulSoup(html,"html.parser")
links = soup.select("#graph_data")
links
# Out:
# [<div data-timedimension="date" id="graph_data" style="display:none">[{"title":"핸드폰 케이스","data":[{"period":"20201204","value":70.00094},{"period":"20201205","value":78.08855},{"period":"20201206","value":82.58272},{"period":"20201207","value":76.14487},{"period":"20201208","value":76.65686},{"period":"20201209","value":76.99819},{"period":"20201210","value":73.26253},{"period":"20201211","value":71.99203},{"period":"20201212","value":77.09301},{"period":"20201213","value":81.98539},{"period":"20201214","value":73.42372},{"period":"20201215","value":77.69033},{"period":"20201216","value":74.94074},{"period":"20201217","value":72.57988},{"period":"20201218","value":69.17606},{"period":"20201219","value":80.25978},{"period":"20201220","value":93.35356},{"period":"20201221","value":79.50127},{"period":"20201222","value":79.47283},{"period":"20201223","value":75.31999},{"period":"20201224","value":69.75443},{"period":"20201225","value":76.41983},{"period":"20201226","value":81.84317},{"pe
# ...

# %%
import requests

cookies = {
    'NNB': '6TTK2RJU3JPWG',
    '_ga': 'GA1.2.1198469368.1669035888',
    'NV_WETR_LOCATION_RGN_M': '"MDUxMTAxMTE="',
    'ASID': '6f5bbfa400000184fa368e5f00000067',
    'NV_WETR_LAST_ACCESS_RGN_M': '"MDUxMTAxMTE="',
    'nx_ssl': '2',
    'nid_inf': '813506172',
    'NID_JKL': '7GO4JgsGQ6jSmPyQ+d0zZPEWBjZqV6VoPgsqFdP360s=',
    'NaverSuggestUse': 'unuse%26use',
    'NID_AUT': 'D2QOxk1i/qhN7mlsiYlMrQnnUV8Gl+BXV86T78q51HMwExxzB7wcbgptaPWfOS0c',
    'NID_SES': '...',
    'page_uid': 'iT8QXwqVOsossuqnkJlssssstIw-032198',
    '_datalab_cid': '50000000',
}

headers = {
    'authority': 'datalab.naver.com',
    'accept': '*/*',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    'content-type': 'application/x-www-form-urlencoded; charset=UTF-8',
    # 'cookie': 'NNB=6TTK2RJU3JPWG; _ga=GA1.2.1198469368.1669035888; NV_WETR_LOCATION_RGN_M="MDUxMTAxMTE="; ASID=6f5bbfa400000184fa368e5f00000067; NV_WETR_LAST_ACCESS_RGN_M="MDUxMTAxMTE="; nx_ssl=2; nid_inf=813506172; NID_JKL=7GO4JgsGQ6jSmPyQ+d0zZPEWBjZqV6VoPgsqFdP360s=; NaverSuggestUse=unuse%26use; NID_AUT=D2QOxk1i/qhN7mlsiYlMrQnnUV8Gl+BXV86T78q51HMwExxzB7wcbgptaPWfOS0c; NID_SES=...; page_uid=iT8QXwqVOsossuqnkJlssssstIw-032198; _datalab_cid=50000000',
    'origin': 'https://datalab.naver.com',
    'referer': 'https://datalab.naver.com/shoppingInsight/sKeyword.naver?keyword=%EC%88%8F%ED%8C%A8%EB%94%A9&cid=50000000',
    'sec-ch-ua': '"Google Chrome";v="119", "Chromium";v="119", "Not?A_Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}

data = {
    'cid': '50000000',
    'timeUnit': 'date',
    'startDate': '2023-11-04',
    'endDate': '2023-12-04',
    'age': '',
    'gender': '',
    'device': '',
    'keyword': '핸드폰케이스',
}

response = requests.post(
    'https://datalab.naver.com/shoppingInsight/getKeywordClickTrend.naver',
    cookies=cookies,
    headers=headers,
    data=data,
)

# %%
response.text
# Out:
# '{"code":"","message":"","shoppingParam":{"startDate":"2023-11-04","endDate":"2023-12-04","timeUnit":"date","cid":"50000000","device":"","gender":"","age":"","keyword":"핸드폰케이스","page":0,"count":0,"type":null,"date":null,"dateRange":"2023.11.04. ~ 2023.12.04."},"chartType":"lineChart","range":"2023.11.04. ~ 2023.12.04.","result":[{"code":null,"title":"핸드폰케이스","fullTitle":null,"data":[]}],"success":true}'
