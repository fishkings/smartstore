# %% [markdown]
# <font color="firebrick" size="6"><b>키워드 평균 가격 구하기 </b></font>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup
import requests
import time
import os

# %%
os.chdir("../../../smartstore") # signaturehelper module 호출하기 위해 경로 설정

# %%
data = pd.read_csv("conditionedData/data/2_sort_requests.csv")
keywords = data["relative_keyword"]

# %%
data.describe()
# Out:
#        total_search  total_store_count  competitive_rate
# count  27678.000000       27678.000000      27678.000000
# mean    5115.545198       20303.918058          7.635141
# std     5398.870127       26463.303144         13.100292
# min     1010.000000           1.000000          0.000000
# 25%     1670.000000        1160.000000          0.320000
# 50%     2940.000000        7624.000000          1.990000
# 75%     6160.000000       30283.250000          8.697500
# max    29980.000000      105909.000000        102.150000

# %%
pd.options.display.max_rows = None  
keywords
# Out:
# 0                                앱코키보드
# 1                               키즈경량패딩
# 2                             후쿠오카버스투어
# 3                                 식전영상
# 4                                면세점가방
# 5                                면세점향수
# 6                              면세점선글라스
# 7                              꾸셀파운데이션
# 8                                롱샴면세점
# 9                            인천공항면세점향수
# 10                         인천공항면세점선글라스
# 11                               면세점시계
# 12                             면세점가방추천
# 13                               면세점어그
# 14                           꾸셀베이스오리지널
# 15                              면세점립스틱
# 16                            면세점립스틱추천
# 17                              면세점화장품
# 18                             면세점향수추천
# 19                               어그면세점
# 20                               밍크엘레팡
# 21                               면세점지갑
# 22                           인천공항면세점롱샴
# 23                              마라톤싱글렛
# 24                             스포벨러닝벨트
# 25                            카멜백울트라벨트
# 26                               러닝클래스
# 27                             카본제트프로3
# 28                             살로몬러닝벨트
# 29                                당구장갑
# 30                                당구그립
# 31                               당구큐가방
# 32                                쿠드롱팁
# 33                                롱고니큐
# 34                               아담무사시
# 35                                 한밭큐
# 36                                당구초크
# 37                               줄다리기줄
# 38                              게이트볼스틱
# 39                                2인3각
# 40                              컴파운드보우
# 41                                 피클볼
# 42                              리듬체조리본
# 43                                뉴스포츠
# 44                                패드민턴
# 45                                 럭비공
# 46                              리본체조리본
# 47                                  림보
# 48                               마닐라로프
# 49                               도라지배즙
# 50                                 곤약밥
# 51                                전투식량
# 52                               비비고만두
# 53                             비비고사골곰탕
# 54                             고메소바바치킨
# 55                              지포어골프화
# 56                              AB슬라이드
# 57                                치닝디핑
# 58                              무게조절덤벨
# 59                                문틀철봉
# 60                                로잉머신
# 61                                자이로볼
# 62                           천국의계단운동기구
# 63                              스피닝자전거
# 64                              스파인코렉터
# 65                                 토삭스
# 66                                소함소함
# 67                           K2인라인스케이트
# 68                              롤러블레이드
# 69                               K2인라인
# 70                              롤러브레이드
# 71                                 힐리스
# 72                               두발킥보드
# 73                                핑거보드
# 74                                문워커스
# 75                                 휠리스
# 76                              힐리스운동화
# 77                                 나인봇
# 78                              바퀴달린신발
# 79                             데카트론킥보드
# 80                            오토바이방한토시
# 81                            오토바이블랙박스
# 82                             오토바이방한복
# 83                                홍진헬멧
# 84                             존테스350D
# 85                              미즈노축구화
# 86                               키즈풋살화
# 87                             아디다스풋살화
# 88                              나이키더플백
# 89                              토트넘유니폼
# 90                              이강인유니폼
# 91                              축구바람막이
# 92                              유소년야구화
# 93                                야구바지
# 94                              야구바람막이
# 95                               야구풀오버
# 96                                포수미트
# 97                               내야글러브
# 98                               투수글러브
# 99                             인조잔디야구화
# 100                             나이키야구화
# 101                              인조잔디화
# 102                             야구공케이스
# 103                              외야글러브
# 104                            에어조던1로우
# 105                               커리11
# 106                            언더아머농구화
# 107                              축구공가방
# 108                              사브리나1
# 109                             나이키업템포
# 110                              조던1로우
# 111                              커리농구화
# 112                              농구공가방
# 113                                업템포
# 114                                루카1
# 115                              르브론20
# 116                              윌슨농구공
# 117                               줌프릭5
# 118                                피구공
# 119                             미즈노배구화
# 120                             아식스배구화
# 121                             나이키배구화
# 122                             미카사배구공
# 123                          아식스스카이엘리트
# 124                              스타배구공
# 125                               빅발리볼
# 126                            미즈노모멘텀3
# 127                                탁구화
# 128                             미즈노탁구화
# 129                              탁구복상의
# 130                             엑시옴탁구복
# 131                               탁구가방
# 132                                탁구대
# 133                              탁구유니폼
# 134                            탁구라켓케이스
# 135                             아식스탁구화
# 136                           버터플라이탁구복
# 137                           버터플라이탁구화
# 138                              리닝탁구화
# 139                               탁구네트
# 140                              테너지05
# 141                           미즈노배드민턴화
# 142                            돌아오는셔틀콕
# 143                           요넥스배드민턴화
# 144                             요넥스티셔츠
# 145                            요넥스바람막이
# 146                             셀프배드민턴
# 147                              KBB79
# 148                              요넥스가방
# 149                          요넥스배드민턴라켓
# 150                             혼자배드민턴
# 151                            나이키테니스화
# 152                            아식스테니스화
# 153                            윌슨테니스가방
# 154                           아디다스테니스화
# 155                          아식스젤레졸루션9
# 156                              테니스장갑
# 157                            요넥스테니스화
# 158                              키모니그립
# 159                             아식스FF3
# 160                              스쿼시라켓
# 161                              라테스민턴
# 162                             테크니화이버
# 163                              스타족구화
# 164                                족구공
# 165                                족구화
# 166                             조이킥족구화
# 167                               족구네트
# 168                              낫소족구화
# 169                                조이킥
# 170                             조이킥스포츠
# 171                                볼링공
# 172                                볼링화
# 173                               볼링아대
# 174                             덱스터볼링화
# 175                               볼링가방
# 176                                볼링티
# 177                              볼링티셔츠
# 178                              스톰볼링공
# 179                              볼링매니아
# 180                              중고볼링공
# 181                                하드볼
# 182                              남자볼링화
# 183                              볼링볼타올
# 184                              햄머볼링공
# 185                             우레탄볼링공
# 186                                볼링백
# 187                              드라이슈트
# 188                               수중랜턴
# 189                             다이빙컴퓨터
# 190                                 작살
# 191                              수중스쿠터
# 192                           베스트다이브슈트
# 193                             다이브로이드
# 194                                핀삭스
# 195                               순토D5
# 196                             베스트다이브
# 197                               검도용품
# 198                                검도복
# 199                               검도호구
# 200                                 죽도
# 201                              신켄무도구
# 202                              성인발레복
# 203                               드레스몰
# 204                             라인댄스바지
# 205                               발레워머
# 206                              에어로빅복
# 207                                코코랑
# 208                              폴댄스의상
# 209                             가정용샌드백
# 210                              위닝글러브
# 211                              복싱핸드랩
# 212                             트윈스글러브
# 213                                핸드랩
# 214                           에버라스트글러브
# 215                             레예스글러브
# 216                            아디다스글러브
# 217                                복싱바
# 218                                 탭볼
# 219                             라이벌글러브
# 220                          아디다스복싱글러브
# 221                           의료용무릎보호대
# 222                           의료용손목보호대
# 223                           잠스트무릎보호대
# 224                              엘보보호대
# 225                           엄지손가락보호대
# 226                                 가검
# 227                                 목검
# 228                                일본도
# 229                                쌍절곤
# 230                                 진검
# 231                                 도검
# 232                                 단검
# 233                                 단도
# 234                                카타나
# 235                               와키자시
# 236                               한일도검
# 237                              청룡언월도
# 238                                 장검
# 239                                사인검
# 240                              대조영도검
# 241                                 장도
# 242                                복싱화
# 243                              주짓수도복
# 244                            아디다스복싱화
# 245                             미즈노복싱화
# 246                               태권도화
# 247                              태권도도복
# 248                               태권도복
# 249                                유도복
# 250                             나이키복싱화
# 251                               레슬링화
# 252                             아식스복싱화
# 253                             아식스역도화
# 254                           프로스펙스복싱화
# 255                            아디다스유도복
# 256                           에버라스트복싱화
# 257                            나이키사발레오
# 258                              소요롤도복
# 259                               줄넘기화
# 260                              바이탈도복
# 261                            나이키헤어밴드
# 262                              오일파스텔
# 263                              아크릴재단
# 264                                 문진
# 265                           파버카스텔색연필
# 266                                화구통
# 267                               옷염색약
# 268                              하드보드지
# 269                         맥세이프차량용거치대
# 270                            2355519
# 271                              토이나이프
# 272                              젤다아미보
# 273                             푸쉬팝게임기
# 274                              꼬치의달인
# 275                           MGSD발바토스
# 276                               생이새우
# 277                               체리새우
# 278                              외부여과기
# 279                             브라인쉬림프
# 280                                 유목
# 281                              무환수어항
# 282                             걸이식여과기
# 283                               2자어항
# 284                                화산석
# 285                              뉴진스앨범
# 286                             플레이브앨범
# 287                              세븐틴앨범
# 288                              투바투앨범
# 289                           제로베이스원앨범
# 290                            아이브마인앨범
# 291                             르세라핌앨범
# 292                              제베원앨범
# 293                             정국골든앨범
# 294                              라이즈앨범
# 295                             QWER앨범
# 296                              잔나비LP
# 297                              이승윤LP
# 298                            아이브미니앨범
# 299                            슬램덩크만화책
# 300                             윔피키드원서
# 301                                독학사
# 302                            그리스로마신화
# 303                          EBS봉투모의고사
# 304                            드래곤볼만화책
# 305                            EBS모의고사
# 306                         EBS파이널모의고사
# 307                             받침없는동화
# 308                            지역농협NCS
# 309                             봉투모의고사
# 310                            주술회전만화책
# 311                       NATETHEGREAT
# 312                         설민석의한국사대모험
# 313                             오싹오싹팬티
# 314                                성경책
# 315                                싱잉볼
# 316                                미사보
# 317                              성경책리폼
# 318                                금강저
# 319                                 목탁
# 320                             성경필사노트
# 321                              성경책커버
# 322                              108염주
# 323                              큰글자성경
# 324                                성모상
# 325                             개역개정성경
# 326                               성경리폼
# 327                            3단빨래바구니
# 328                            스탠드다리미판
# 329                            라탄빨래바구니
# 330                            전동빨래건조대
# 331                            한샘빨래건조대
# 332                                양모볼
# 333                             가정용혈압계
# 334                             오므론혈압계
# 335                                만보기
# 336                         브라운체온계6525
# 337                         브라운체온계6030
# 338                                청진기
# 339                                혈압기
# 340                             카카오체중계
# 341                             비접촉체온계
# 342                             샤오미체중계
# 343                              카스체중계
# 344                         브라운체온계6520
# 345                            IRT6030
# 346                               전담액상
# 347                              덴탈마스크
# 348                              입호흡액상
# 349                              웰컴드링크
# 350                               차이코스
# 351                             발라리안코일
# 352                            일회용전자담배
# 353                            연속혈당측정기
# 354                           무채혈혈당측정기
# 355                            아큐첵인스턴트
# 356                          아큐첵퍼포마시험지
# 357                               글루코핏
# 358                              당뇨측정기
# 359                         아큐첵인스턴트시험지
# 360                           프리스타일리브레
# 361                           혈당측정기무채혈
# 362                           아큐첵혈당측정기
# 363                             아큐첵퍼포마
# 364                              리브레혈당
# 365                              혈당시험지
# 366                           케어센스N시험지
# 367                              혈당체크기
# 368                                아큐첵
# 369                             아큐첵액티브
# 370                             인슐린주사기
# 371                           바로잰혈당시험지
# 372                           듀오덤엑스트라씬
# 373                              여드름패치
# 374                               알콜스왑
# 375                            더마틱스울트라
# 376                               흉터연고
# 377                              실리콘약병
# 378                           더마틱스울트라겔
# 379                             소독용에탄올
# 380                               이어포셉
# 381                           오므론네블라이저
# 382                              전동휠체어
# 383                              돋보기안경
# 384                              노인보행기
# 385                              보행보조기
# 386                             납골당꾸미기
# 387                                보청기
# 388                                 목발
# 389                               포타포티
# 390                              휠체어대여
# 391                              경량휠체어
# 392                                 요강
# 393                              이동식변기
# 394                             거북목교정기
# 395                               목견인기
# 396                             자세교정밴드
# 397                           의료용압박스타킹
# 398                              거북목교정
# 399                             어깨교정밴드
# 400                           센시안압박스타킹
# 401                           허리스트레칭기구
# 402                              허리견인기
# 403                              발목보조기
# 404                              CPM대여
# 405                             굽은등교정기
# 406                              골반교정기
# 407                               깁스신발
# 408                             저주파치료기
# 409                                부항기
# 410                             적외선조사기
# 411                             적외선치료기
# 412                          원적외선온열치료기
# 413                             초음파치료기
# 414                           온열부항의료기기
# 415                               클럭패드
# 416                                부황기
# 417                              한솔부항기
# 418                                온부기
# 419                            EMS마사지기
# 420                             비웰스바디펜
# 421                             저주파자극기
# 422                              물리치료기
# 423                                 부항
# 424                             휴비딕저주파
# 425                             클럭마사지기
# 426                             가정용좌욕기
# 427                                좌훈기
# 428                            근적외선좌욕기
# 429                                 좌욕
# 430                              치질좌욕기
# 431                               좌욕대야
# 432                               큐손길N
# 433                               근적외선
# 434                            원적외선좌욕기
# 435                              질온관리기
# 436                             적외선좌욕기
# 437                             임산부좌욕기
# 438                                온릴스
# 439                           파쉬보온물주머니
# 440                               눈찜질팩
# 441                              전기찜질팩
# 442                               발온열기
# 443                                 파쉬
# 444                              허리찜질기
# 445                              어깨찜질기
# 446                              온수찜질기
# 447                              황토찜질팩
# 448                              어깨찜질팩
# 449                               팥찜질팩
# 450                              무릎찜질기
# 451                             파쉬물주머니
# 452                           이갈이마우스피스
# 453                              애터미치약
# 454                               미백치약
# 455                               켄트칫솔
# 456                               혀클리너
# 457                              어금니칫솔
# 458                              큐라덴칫솔
# 459                               첨단칫솔
# 460                              애터미칫솔
# 461                              유시몰치약
# 462                               온열안대
# 463                              안경세척기
# 464                                식염수
# 465                            보스톤심플러스
# 466                               옵티프리
# 467                               에이오셉
# 468                           초음파안경세척기
# 469                           메구리즘온열안대
# 470                              생리식염수
# 471                           안경초음파세척기
# 472                            멸균생리식염수
# 473                         옵티프리퓨어모이스트
# 474                               메구리즘
# 475                           무지외반증교정기
# 476                              건식족욕기
# 477                            내성발톱교정기
# 478                             그랜즈레미디
# 479                               셀라큐어
# 480                           코지마발마사지기
# 481                         폴리오종아리마사지기
# 482                          공기압다리마사지기
# 483                              손마사지기
# 484                              눈마사지기
# 485                             괄사마사지기
# 486                            바디프랜드팔콘
# 487                               토르박스
# 488                                매직캔
# 489                                여인초
# 490                              인형꽃다발
# 491                              올리브나무
# 492                               양파모종
# 493                             학예회꽃다발
# 494                                사랑초
# 495                             몬스테라알보
# 496                            킨더조이꽃다발
# 497                               튤립구근
# 498                                 호야
# 499                               분갈이흙
# 500                            비닐하우스자재
# 501                               제초매트
# 502                       더퍼스트슬램덩크블루레이
# 503                           슬램덩크블루레이
# 504                           블루자이언트특전
# 505                            아이유골든아워
# 506                              백색소음기
# 507                             오닉스포크5
# 508                                스캔톡
# 509                              소형녹음기
# 510                             초소형녹음기
# 511                              오닉스팔마
# 512                             오닉스페이지
# 513                          말랑하니백색소음기
# 514                                전자책
# 515                            오닉스포크5S
# 516                               전자사전
# 517                                크레마
# 518                              E북리더기
# 519                           크레마이북리더기
# 520                              소니녹음기
# 521                               포크5S
# 522                          닌텐도스위치라이트
# 523                              마리오원더
# 524                               듀얼센스
# 525                          닌텐도스위치조이콘
# 526                              중고컴퓨터
# 527                            삼성올인원PC
# 528                             삼성데스크탑
# 529                            온열마우스패드
# 530                         15인치노트북파우치
# 531                         16인치노트북파우치
# 532                           삼성노트북충전기
# 533                          17인치노트북가방
# 534                         14인치노트북파우치
# 535                         17인치노트북파우치
# 536                         아이패드에어5케이스
# 537                               짭플펜슬
# 538                         아이패드9세대케이스
# 539                            애플펜슬케이스
# 540                             애플펜슬펜촉
# 541                       갤럭시탭S9플러스케이스
# 542                       갤럭시탭S9울트라케이스
# 543                         아이패드미니6케이스
# 544                        갤럭시탭S7FE케이스
# 545                          갤럭시탭S9케이스
# 546                       갤럭시탭S6라이트케이스
# 547                           듀얼모니터받침대
# 548                              카멜마운트
# 549                             카멜모니터암
# 550                             싱글모니터암
# 551                              모니터받침
# 552                             NBH100
# 553                         높이조절모니터받침대
# 554                             NB모니터암
# 555                          다이소모니터받침대
# 556                          데스커모니터받침대
# 557                             앱코K660
# 558                               G304
# 559                              스칼렛솔로
# 560                               오디언트
# 561                             브리츠스피커
# 562                            브리츠사운드바
# 563                             로지텍헤드셋
# 564                           씨게이트외장하드
# 565                            삼성외장SSD
# 566                               삼성T7
# 567                            샌디스크USB
# 568                             삼성외장하드
# 569                             870EVO
# 570                             4070TI
# 571                           광HDMI케이블
# 572                             4060TI
# 573                          DVITOHDMI
# 574                          HDMITODVI
# 575                            RTX3060
# 576                           아이피타임공유기
# 577                          IPTIME공유기
# 578                              랜테스터기
# 579                            AX2004M
# 580                            AX6000M
# 581                            A2004SE
# 582                             A604SE
# 583                            AX3000M
# 584                             AX2004
# 585                           MSOFFICE
# 586                         마이크로소프트오피스
# 587                            마이크로오피스
# 588                            오피스2021
# 589                            굿노트다이어리
# 590                         마이크로소프트365
# 591                         프로크리에이트브러쉬
# 592                          한컴오피스2024
# 593                            자코모4인쇼파
# 594                             이케아수납장
# 595                              이케아선반
# 596                           한샘샘키즈수납장
# 597                               아기책장
# 598                                교구장
# 599                               아기옷장
# 600                             침대안전가드
# 601                             아기침대가드
# 602                               아기행거
# 603                            본베베침대가드
# 604                               방음부스
# 605                              모듈러주택
# 606                            컨테이너하우스
# 607                              이동식주택
# 608                              조립식주택
# 609                                콤비락
# 610                            화장실리모델링
# 611                           알레르망침구세트
# 612                               닥스이불
# 613                            라지킹침구세트
# 614                             알레르망키즈
# 615                             닥스이불세트
# 616                              목화솜이불
# 617                             알레르망베개
# 618                                 요솜
# 619                            헬렌스타인베개
# 620                              헬렌스타인
# 621                         빨아쓰는규조토발매트
# 622                              워셔블러그
# 623                             우드블라인드
# 624                             나비주름커튼
# 625                              작은창커튼
# 626                            모던하우스커튼
# 627                               누빔원단
# 628                               라라뜨개
# 629                                양말목
# 630                              자이언트얀
# 631                             목도리뜨개질
# 632                                벨보아
# 633                             니트컨테이너
# 634                               수세미실
# 635                            바라클라바뜨기
# 636                                힙분유
# 637                             앱솔루트명작
# 638                          앱솔루트명작1단계
# 639                                압타밀
# 640                               산양분유
# 641                               A2분유
# 642                           아이엠마더1단계
# 643                        압타밀프로푸트라1단계
# 644                              아이엠마더
# 645                        압타밀프로푸트라2단계
# 646                               액상분유
# 647                                퓨어락
# 648                           앱솔루트센서티브
# 649                              명작1단계
# 650                             위드맘1단계
# 651                             앱솔루트산양
# 652                            후디스산양분유
# 653                          앱솔루트명작2단계
# 654                        앱솔루트센서티브1단계
# 655                               천기저귀
# 656                       하기스네이처메이드1단계
# 657                       하기스네이처메이드2단계
# 658                                팸퍼스
# 659                             팸퍼스기저귀
# 660                             하기스기저귀
# 661                             신생아기저귀
# 662                          하기스네이처메이드
# 663                             나비잠기저귀
# 664                           밤부베베천기저귀
# 665                           리베로터치6단계
# 666                               크린베베
# 667                       하기스네이처메이드3단계
# 668                       팸퍼스베이비드라이5단계
# 669                       팸퍼스베이비드라이6단계
# 670                         크린베베일자형기저귀
# 671                            마미포코기저귀
# 672                       하기스네이처메이드5단계
# 673                             브라운물티슈
# 674                               마이비데
# 675                             앙블랑물티슈
# 676                          베베숲시그니처블루
# 677                             베베앙물티슈
# 678                             대용량물티슈
# 679                          베베숲시그니처레드
# 680                             순둥이물티슈
# 681                              비데물티슈
# 682                             붕어빵물티슈
# 683                             애터미물티슈
# 684                            페넬로페물티슈
# 685                              이유식큐브
# 686                               아기반찬
# 687                             생선파는언니
# 688                               큐브데이
# 689                              실온이유식
# 690                                맘마밀
# 691                               얼라맘마
# 692                              초기이유식
# 693                               아기간장
# 694                                아기김
# 695                                 바맘
# 696                               아기퓨레
# 697                              루솔이유식
# 698                            이유식야채큐브
# 699                              아넬라퓨레
# 700                                담은수
# 701                                 떡뻥
# 702                             뽀로로음료수
# 703                          루솔진한배도라지즙
# 704                              질마재농장
# 705                              뽀로로음료
# 706                            아기배도라지즙
# 707                               킨더밀쉬
# 708                              아기보리차
# 709                               아기치즈
# 710                              티딩러스크
# 711                               이치비야
# 712                             뽀로로보리차
# 713                            배도라지즙아기
# 714                               요미요미
# 715                               아기떡뻥
# 716                                또또맘
# 717                               아이키커
# 718                              아기요거트
# 719                             역류방지쿠션
# 720                        제이앤제나역류방지쿠션
# 721                               수유쿠션
# 722                            더블하트젖꼭지
# 723                             더블하트젖병
# 724                                쪽쪽이
# 725                             셀프수유쿠션
# 726                                유축기
# 727                              모윰쪽쪽이
# 728                              제이앤제나
# 729                            닥터브라운젖병
# 730                              쪽쪽이클립
# 731                             아벤트쪽쪽이
# 732                                역방쿠
# 733                               수유시트
# 734                               수유패드
# 735                               헤겐젖병
# 736                            스펙트라유축기
# 737                               트라이크
# 738                             절충형유모차
# 739                             유모차라이너
# 740                            유모차방한커버
# 741                            유모차방풍커버
# 742                             유모차컵홀더
# 743                             쌍둥이유모차
# 744                           와이업지니제로3
# 745                             초경량유모차
# 746                            트라이크유모차
# 747                             디럭스유모차
# 748                           부가부버터플라이
# 749                            에이블트라이크
# 750                                유모카
# 751                             유모차선풍기
# 752                             부가부풋머프
# 753                              유모차장갑
# 754                             주니어카시트
# 755                             휴대용카시트
# 756                             부스터카시트
# 757                           브라이텍스카시트
# 758                     브라이텍스듀얼픽스아이사이즈
# 759                         싸이벡스주니어카시트
# 760                          다이치원픽스360
# 761                             다이치카시트
# 762                             바구니카시트
# 763                           바구니카시트대여
# 764                              브라이텍스
# 765                              카시트발판
# 766                            어린이안전벨트
# 767                             안전벨트인형
# 768                             토들러카시트
# 769                            싸이벡스카시트
# 770                         폴레드올에이지360
# 771                            카시트발받침대
# 772                          페도라바구니카시트
# 773                                아기띠
# 774                             포그내아기띠
# 775                            기저귀가방백팩
# 776                                힙시트
# 777                              기저귀백팩
# 778                            베이비뵨아기띠
# 779                           포그내맥스올인원
# 780                             에르고아기띠
# 781                             신생아아기띠
# 782                             아기띠침받이
# 783                             기저귀파우치
# 784                             베이비뵨미니
# 785                              아기포대기
# 786                            누빔기저귀가방
# 787                           휴대용기저귀매트
# 788                           돗투돗아기띠워머
# 789                               아기욕조
# 790                               아기비데
# 791                            프롬유샤워핸들
# 792                               포프베베
# 793                              신생아욕조
# 794                               샤워핸들
# 795                           포프베베아기비데
# 796                             말랑하니욕조
# 797                            슈너글아기욕조
# 798                             아기목욕가운
# 799                             아기목욕타올
# 800                            폴레드샤워핸들
# 801                               말랑하니
# 802                             센스2030
# 803                           온다베이비플러스
# 804                            온다베이비욕조
# 805                              아기세면대
# 806                               아기로션
# 807                               키즈샴푸
# 808                               아기크림
# 809                             아기바디워시
# 810                              베이비오일
# 811                               쁘리마쥬
# 812                           아토팜MLE크림
# 813                               유아로션
# 814                           존슨즈베이비로션
# 815                               그린핑거
# 816                           아토팜판테놀크림
# 817                              아기선크림
# 818                             키즈바디워시
# 819                              아기수딩젤
# 820                              아토팜로션
# 821                           아토팜탑투토워시
# 822                               아기변기
# 823                              콧물흡입기
# 824                             유아변기커버
# 825                             아기변기커버
# 826                             노시부석션팁
# 827                             포켓몬마스크
# 828                           블루본마스크소형
# 829                               한일포근
# 830                             티니핑마스크
# 831                          한일포근콧물흡입기
# 832                            한일콧물흡입기
# 833                              어린이치약
# 834                              조르단칫솔
# 835                               유아치약
# 836                               아기치약
# 837                               구강티슈
# 838                              어린이치실
# 839                           조르단칫솔1단계
# 840                              벨레다치약
# 841                              제니튼치약
# 842                           조르단칫솔2단계
# 843                              예꼬맘치약
# 844                             브리스틱칫솔
# 845                              코도모칫솔
# 846                             메가텐360
# 847                             블랑키즐치약
# 848                              티니핑칫솔
# 849                            아기섬유유연제
# 850                               호호에미
# 851                           토루토루세탁세제
# 852                               아기세제
# 853                           마이비얼룩제거제
# 854                               유아세제
# 855                             아기세탁세제
# 856                           레드루트세탁세제
# 857                           헬로그린세탁세제
# 858                        애플민트라임섬유유연제
# 859                               레드루트
# 860                          호호에미섬유유연제
# 861                        폴메디슨키즈아토표백제
# 862                            비앤비섬유세제
# 863                           비앤비섬유유연제
# 864                          레드루트섬유유연제
# 865                            네이처러브메레
# 866                               베르블랑
# 867                            유팡젖병소독기
# 868                              젖병세척기
# 869                              젖병건조대
# 870                              젖병보관함
# 871                              젖병세정제
# 872                                 유팡
# 873                            픽셀젖병소독기
# 874                              리뗀클로르
# 875                           레이퀸젖병소독기
# 876                              스팀소독기
# 877                             하이비젖병솔
# 878                                하이비
# 879                           벤브와스팀소독기
# 880                           휴대용젖병소독기
# 881                            해님젖병소독기
# 882                            이유식기보관함
# 883                            젖병스팀소독기
# 884                           다퍼남젖병보관함
# 885                              아기안전문
# 886                            아기무릎보호대
# 887                              루보안전문
# 888                               모기팔찌
# 889                               모기패치
# 890                              방문스토퍼
# 891                            아기머리보호대
# 892                            호빵맨모기패치
# 893                             머리쿵보호대
# 894                              아기디딤대
# 895                              히든키즈락
# 896                             아가드안전문
# 897                               범퍼침대
# 898                             기저귀갈이대
# 899                              아기옷걸이
# 900                               유아책상
# 901                               아기쇼파
# 902                             아기식탁의자
# 903                             아기범퍼침대
# 904                              리안드림콧
# 905                               범보의자
# 906                               아기소파
# 907                              신생아침대
# 908                          리안드림콧아기침대
# 909                            에시앙범보의자
# 910                              아기턱받이
# 911                               스카프빕
# 912                               아기식판
# 913                               흡착식판
# 914                           릴리팟이유식냄비
# 915                                와우컵
# 916                             실리콘턱받이
# 917                             아기스카프빕
# 918                            그로미미빨대컵
# 919                            베이비뵨턱받이
# 920                               그로미미
# 921                             유아스카프빕
# 922                            주니자기주도컵
# 923                             임산부수영복
# 924                               수유브라
# 925                             임산부스타킹
# 926                                수유복
# 927                              임산부팬티
# 928                             임산부레깅스
# 929                             맘스안심팬티
# 930                               수유나시
# 931                              겨울임부복
# 932                              제이유블랑
# 933                                디라벨
# 934                              수유원피스
# 935                               튼살크림
# 936                            임산부튼살크림
# 937                           임산부바디필로우
# 938                            비오템튼살크림
# 939                               임밍아웃
# 940                               도넛방석
# 941                           란시노라놀린크림
# 942                           임산부손목보호대
# 943                             임밍아웃카드
# 944                            아토팜튼살크림
# 945                              임산부크림
# 946                            임밍아웃이벤트
# 947                         해피테일즈바디필로우
# 948                              임산부샴푸
# 949                            U자바디필로우
# 950                           클라란스튼살크림
# 951                               산모패드
# 952                              회음부방석
# 953                              란시노크림
# 954                             임밍아웃복권
# 955                                겉싸개
# 956                              아기블랭킷
# 957                                속싸개
# 958                            마이리틀데이지
# 959                             낮잠이불세트
# 960                           어린이집낮잠이불
# 961                             아기침대패드
# 962                               비비엔다
# 963                             아기겨울이불
# 964                             낮잠이불가방
# 965                               아기토퍼
# 966                            알레르망베이비
# 967                          어린이집생일답례품
# 968                             돌잔치답례품
# 969                               돌상대여
# 970                             할로윈구디백
# 971                            50일셀프촬영
# 972                                백일상
# 973                              결혼답례품
# 974                            어린이집구디백
# 975                             유치원답례품
# 976                              유치보관함
# 977                              성장동영상
# 978                              아이데이지
# 979                              패딩우주복
# 980                              아기우주복
# 981                             에뜨와우주복
# 982                           아기크리스마스옷
# 983                              우주복패딩
# 984                             밍크뮤우주복
# 985                             아가방우주복
# 986                              아기손수건
# 987                             블루독우주복
# 988                             압소바우주복
# 989                               미니로브
# 990                           나이키키즈운동화
# 991                          뉴발란스키즈운동화
# 992                            휠라키즈운동화
# 993                             털크록스키즈
# 994                             스케쳐스키즈
# 995                                씨엔타
# 996                            아기바라클라바
# 997                             베어파우키즈
# 998                                올드솔
# 999                           아레나키즈수영복
# 1000                             아기수영복
# 1001                          아레나남아수영복
# 1002                           주니어래쉬가드
# 1003                            아기래쉬가드
# 1004                          아레나여아수영복
# 1005                          배럴키즈래쉬가드
# 1006                             유아수영복
# 1007                            여아래쉬가드
# 1008                           남아실내수영복
# 1009                               점퍼루
# 1010                                쏘서
# 1011                               바운서
# 1012                           베이비뵨바운서
# 1013                             바운서대여
# 1014                             뉴나바운서
# 1015                             아마존쏘서
# 1016                         피셔프라이스바운서
# 1017                            어라운드위고
# 1018                         베이비뵨바운서대여
# 1019                            포맘스바운서
# 1020                              졸리점퍼
# 1021                              쏘서대여
# 1022                             콤비보행기
# 1023                            신생아바운서
# 1024                             아기바운서
# 1025                             보행기대여
# 1026                            졸리점퍼대여
# 1027                           세이지폴바운서
# 1028                            스쿳앤라이드
# 1029                             유아킥보드
# 1030                               치발기
# 1031                              베이비룸
# 1032                             푸바오인형
# 1033                              실바니안
# 1034                         스키비디토일렛인형
# 1035                           실바니안패밀리
# 1036                             그로밋인형
# 1037                           젤리캣애착인형
# 1038                             춘식이인형
# 1039                            카피바라인형
# 1040                              종이인형
# 1041                              파라필름
# 1042                               소마셈
# 1043                            원소주기율표
# 1044                              소중한글
# 1045                           매직트리하우스
# 1046                              고무마개
# 1047                               구리판
# 1048                           바람개비만들기
# 1049                              핀덴베베
# 1050                            영어보드게임
# 1051                           엘리펀트앤피기
# 1052                              한글공부
# 1053                               쇠구슬
# 1054                               플라토
# 1055                              닭다리살
# 1056                            하누카세육포
# 1057                              한우육포
# 1058                            사세버팔로윙
# 1059                          햄지대왕소갈비찜
# 1060                               김부각
# 1061                              고추부각
# 1062                              명이나물
# 1063                               단무지
# 1064                              무말랭이
# 1065                            반찬정기배송
# 1066                             궁채장아찌
# 1067                             절임알타리
# 1068                             본죽장조림
# 1069                             푸른회식당
# 1070                              반찬배달
# 1071                           종가집무말랭이
# 1072                              홍어무침
# 1073                                콩잎
# 1074                               오이지
# 1075                             종가집김치
# 1076                           안동학가산김치
# 1077                               묵은지
# 1078                            김치10KG
# 1079                           고랭지절임배추
# 1080                           맥심화이트골드
# 1081                              G7커피
# 1082                             할로윈사탕
# 1083                            꽃보다오징어
# 1084                              앵커버터
# 1085                            모짜렐라치즈
# 1086                            슬라이스치즈
# 1087                             스트링치즈
# 1088                           라꽁비에뜨버터
# 1089                            구워먹는치즈
# 1090                              체다치즈
# 1091                         필라델피아크림치즈
# 1092                             지라그라타
# 1093                   아그리폼지라그라타그라나파다노
# 1094                            서울우유버터
# 1095                              무염버터
# 1096                             이즈니버터
# 1097                             부라타치즈
# 1098                                연유
# 1099                             중고노트북
# 1100                        갤럭시북3프로360
# 1101                            서피스프로9
# 1102                     NT550XEZ-A58A
# 1103                        뮤패드K10PLUS
# 1104                       아이뮤즈K10PLUS
# 1105                           엘지전자모니터
# 1106                           24인치모니터
# 1107                           32인치모니터
# 1108                             벤큐모니터
# 1109                            스마트모니터
# 1110                         LG27GP750
# 1111                          27UP550N
# 1112                            일회용앞치마
# 1113                            강아지유산균
# 1114                               펫생각
# 1115                          커즈와일KA50
# 1116                         야마하디지털피아노
# 1117                         커즈와일KA120
# 1118                             현금바인더
# 1119                              대맛조개
# 1120                              사과대추
# 1121                          하이브리드자전거
# 1122                           자이언트자전거
# 1123                              티티카카
# 1124                            데상트스키복
# 1125                            스노우보드복
# 1126                           스노우보드부츠
# 1127                            골드윈스키복
# 1128                               숏스키
# 1129                             스키에이트
# 1130                            온요네스키복
# 1131                            사우스플레이
# 1132                             요즈리틴셀
# 1133                              세네에기
# 1134                            야마시타AJ
# 1135                            다이와낚시복
# 1136                            야마시타에기
# 1137                              YL에기
# 1138                             텅스텐봉돌
# 1139                             쪼꼬미에기
# 1140                            르망고수영복
# 1141                            차량용소화기
# 1142                              어싱양말
# 1143                       써스데이아일랜드원피스
# 1144                          오르시떼여성잠옷
# 1145                            피치기모잠옷
# 1146                          오르시떼남성잠옷
# 1147                              탑텐잠옷
# 1148                          캘빈클라인드로즈
# 1149                           아디다스드로즈
# 1150                            락포트남성화
# 1151                           족저근막염깔창
# 1152                             지비츠세트
# 1153                              평발깔창
# 1154                              발열깔창
# 1155                             신발끈클립
# 1156                             겨울지비츠
# 1157                              캉골백팩
# 1158                            캉골메신저백
# 1159                             캉골슬링백
# 1160                           나이키크로스백
# 1161                            로우로우백팩
# 1162                           16인치캐리어
# 1163                             밤켈캐리어
# 1164                         루이까또즈카드지갑
# 1165                           루이까또즈지갑
# 1166                             몽블랑벨트
# 1167                            페라가모벨트
# 1168                              닥스벨트
# 1169                              구찌벨트
# 1170                              듀퐁벨트
# 1171                             헤지스벨트
# 1172                            리바이스벨트
# 1173                            루이비통벨트
# 1174                            에르메스벨트
# 1175                             톰포드벨트
# 1176                              폴로모자
# 1177                             화이트샌즈
# 1178                        비비안웨스트우드장갑
# 1179                              어그장갑
# 1180                              요술장갑
# 1181                            작업용팔토시
# 1182                           질스튜어트장갑
# 1183                            캐시미어장갑
# 1184                              닥스장갑
# 1185                           톰포드선글라스
# 1186                            크롬하츠안경
# 1187                             안경코받침
# 1188                              안경닦이
# 1189                             구찌안경테
# 1190                           셀린느선글라스
# 1191                              무테안경
# 1192                              바나나핀
# 1193                             정수리가발
# 1194                             벨벳머리띠
# 1195                             벨벳리본핀
# 1196                             닥스스카프
# 1197                           카시오수능시계
# 1198                          프레드릭콘스탄트
# 1199                           로렉스남자시계
# 1200                             로즈몽시계
# 1201                           카시오전자시계
# 1202                           로렉스여성시계
# 1203                              구찌시계
# 1204                           골드바3.75
# 1205                             순금골드바
# 1206                           골드바100G
# 1207                           골드바37.5
# 1208                               순금바
# 1209                          골드바1000G
# 1210                             미니골드바
# 1211                          골드바11.25
# 1212                        순금골드바3.75G
# 1213                               실버바
# 1214                             골드바1G
# 1215                            골드바50G
# 1216                                금괴
# 1217                           클라란스넥크림
# 1218                             헤라썬크림
# 1219                             헤라선크림
# 1220                            닥터지선크림
# 1221                         자작나무수분선크림
# 1222                             달바선크림
# 1223                             랑콤선크림
# 1224                             톤업선크림
# 1225                           아이오페선크림
# 1226                           셀퓨전씨선크림
# 1227                               선스틱
# 1228                               썬스틱
# 1229                          이니스프리선크림
# ...
# 27269                           돼지갈비양념
# 27270                             열정농부
# 27271                            할랄가이즈
# 27272                            엄지네꼬막
# 27273                         엄지네꼬막비빔밥
# 27274                             문어솥밥
# 27275                           감바스밀키트
# 27276                             야채곱창
# 27277                           닭갈비밀키트
# 27278                          마라샹궈밀키트
# 27279                             곱창볶음
# 27280                           순대곱창볶음
# 27281                             프레시지
# 27282                            영암무화과
# 27283                             청무화과
# 27284                            남도의식탁
# 27285                          코스트코무화과
# 27286                            무화과제철
# 27287                             국산귀리
# 27288                              귀리쌀
# 27289                           구수한사람들
# 27290                           풀무원단무지
# 27291                            꼬들단무지
# 27292                            김밥단무지
# 27293                            유자단무지
# 27294                            얇은단무지
# 27295                            치자단무지
# 27296                            일본단무지
# 27297                          고추장멸치볶음
# 27298                            잔멸치볶음
# 27299                            마카다프룻
# 27300                              포도즙
# 27301                          김재식헬스푸드
# 27302                          참앤들황토농원
# 27303                               배즙
# 27304                          한살림도라지청
# 27305                           착즙하는남자
# 27306                             줄스클럽
# 27307                           누렁이과수원
# 27308                            블루베리즙
# 27309                               오터
# 27310                           머스타드소스
# 27311                          하인즈머스타드
# 27312                             홀그레인
# 27313                           허니머스타드
# 27314                         허니머스타드소스
# 27315                            증류식소주
# 27316                            가무치소주
# 27317                             토끼소주
# 27318                             진맥소주
# 27319                           안동소주가격
# 27320                              문배술
# 27321                           느린마을소주
# 27322                              가무치
# 27323                           명인안동소주
# 27324                             병영소주
# 27325                           안동소주일품
# 27326                             소주다움
# 27327                              려소주
# 27328                           귀주마오타이
# 27329                              고량주
# 27330                             우주고래
# 27331                           공부가주자약
# 27332                           공부가주가격
# 27333                            우리술상회
# 27334                           내변산양조장
# 27335                             칼바도스
# 27336                               뉴룩
# 27337                              전통주
# 27338                             안동소주
# 27339                             복분자주
# 27340                             동해소주
# 27341                            한산소곡주
# 27342                            고흥유자주
# 27343                              원소주
# 27344                             너디호프
# 27345                           백종원막걸리
# 27346                              소곡주
# 27347                            골목막걸리
# 27348                              담금주
# 27349                            담은막걸리
# 27350                          우도땅콩막걸리
# 27351                         해창막걸리12도
# 27352                           송명섭막걸리
# 27353                         복순도가손막걸리
# 27354                          금정산성막걸리
# 27355                         해창막걸리18도
# 27356                           호랑이막걸리
# 27357                             우곡생주
# 27358                            팔팔막걸리
# 27359                             스톰탁주
# 27360                              청명주
# 27361                              청주술
# 27362                           한영석청명주
# 27363                          경주법주초특선
# 27364                             경주법주
# 27365                              니모메
# 27366                              석탄주
# 27367                            전주이강주
# 27368                             도원결의
# 27369                              빙탄복
# 27370                           스파클링와인
# 27371                            댄싱사이더
# 27372                              매취순
# 27373                             단감명작
# 27374                             영동와인
# 27375                             사과와인
# 27376                            복숭아와인
# 27377                              혼디주
# 27378                            스위트와인
# 27379                           고창복분자주
# 27380                          내장산복분자주
# 27381                             복분자술
# 27382                            명작복분자
# 27383                           복분자주도수
# 27384                             담금소주
# 27385                            담금주소주
# 27386                               강주
# 27387                            담금주도수
# 27388                              문배주
# 27389                          박재서안동소주
# 27390                          전통주선물세트
# 27391                             오나이릭
# 27392                              우주술
# 27393                          오나이릭우주술
# 27394                            오나이릭술
# 27395                              솔송주
# 27396                              고운달
# 27397                           우렁이쌀청주
# 27398                              술선물
# 27399                              두견주
# 27400                             오미나라
# 27401                             러시안잭
# 27402                            토카이와인
# 27403                            보르도와인
# 27404                        칸티모스카토다스티
# 27405                           아마로네와인
# 27406                         헝가리토카이와인
# 27407                           1924와인
# 27408                           모스카토와인
# 27409                           1887와인
# 27410                           웨스트와일더
# 27411           1865셀렉티드빈야드까베르네소비뇽2017
# 27412                     말보로뉴질랜드화이트와인
# 27413                            마주앙와인
# 27414                              마주앙
# 27415                             모스카토
# 27416                            보테가와인
# 27417                         아이스와인캐나다
# 27418                              산토리
# 27419                             글렌피딕
# 27420                           조니워커블루
# 27421                          야마자키12년
# 27422                         발렌타인글렌버기
# 27423                              깔루아
# 27424                            로얄살루트
# 27425                           조니워커블랙
# 27426                              카발란
# 27427                      발렌타인글렌버기12년
# 27428                            일본위스키
# 27429                           카발란위스키
# 27430                          준마이다이긴죠
# 27431                           츠루우메유즈
# 27432                           간바레오또상
# 27433                           월계관준마이
# 27434                              해지람
# 27435                              준마이
# 27436                            몽지람M6
# 27437                            쿠보타사케
# 27438                              몽지람
# 27439                             유자사케
# 27440                         북극곰의눈물사케
# 27441                             유즈사케
# 27442                            몽지람M9
# 27443                            월계관사케
# 27444                             화요53
# 27445                            비잔클리어
# 27446                            준마이사케
# 27447                             센노유메
# 27448                            서봉주가격
# 27449                         아사히슈퍼드라이
# 27450                           바이엔슈테판
# 27451                             써머스비
# 27452                          기네스콜드브루
# 27453                           몰슨캐네디언
# 27454                         아사이슈퍼드라이
# 27455                         슈퍼드라이아사히
# 27456                          아사이생맥주캔
# 27457                             코젤다크
# 27458                           제주펠롱에일
# 27459                         아사히수퍼드라이
# 27460                            머드쉐이크
# 27461                              빽라거
# 27462                          어라운드뷰시공
# 27463                          어라운드뷰가격
# 27464                             비트레오
# 27465                          티젠콤부차레몬
# 27466                           이디야콤부차
# 27467                        티젠콤부차파인애플
# 27468                          티젠콤부차피치
# 27469                           오설록콤부차
# 27470                            담터콤부차
# 27471                           작심랩콤부차
# 27472                            콤부차레몬
# 27473                            티젠콤푸차
# 27474                            쟈뎅콤부차
# 27475                           아워티콤부차
# 27476                            요소수가격
# 27477                         현대모비스요소수
# 27478                           요소컴요소수
# 27479                              요소컴
# 27480                           요소수첨가제
# 27481                           에탄올워셔액
# 27482                           불스원워셔액
# 27483                          발수코팅워셔액
# 27484                           소낙스워셔액
# 27485                           자동차워셔액
# 27486                          프레스톤워셔액
# 27487                              와셔액
# 27488                            소낙스더뷰
# 27489                            워셔액추천
# 27490                           BMW워셔액
# 27491                          아임반콘솔쿠션
# 27492                           루젠콘솔쿠션
# 27493                          봉고3연료필터
# 27494                          포터2연료필터
# 27495                        올뉴카니발연료필터
# 27496                        올뉴쏘렌토연료필터
# 27497                             호박팥차
# 27498                              호박차
# 27499                           호박팥차효능
# 27500                            방앗간청년
# 27501                            퉁퉁이별티
# 27502                               팥차
# 27503                           불스원와이퍼
# 27504                          와이퍼리필고무
# 27505                           이제트코리아
# 27506                        렉스턴스포츠와이퍼
# 27507                            국산작두콩
# 27508                             작두콘차
# 27509                         불스원에어컨필터
# 27510                          K5에어컨필터
# 27511                       팰리세이드에어컨필터
# 27512                         QM6에어컨필터
# 27513                          레이에어컨필터
# 27514                         쏘렌토에어컨필터
# 27515                          모닝에어컨필터
# 27516                       그랜저IG에어컨필터
# 27517                              만필터
# 27518                         MQ4에어컨필터
# 27519                       싼타페TM에어컨필터
# 27520                         스파크에어컨필터
# 27521                      쏘렌토MQ4에어컨필터
# 27522                          산도깨비방향제
# 27523                           차량냄새제거
# 27524                              훈증캔
# 27525                         자동차에어컨냄새
# 27526                         차량담배냄새제거
# 27527                            오사카배편
# 27528                             부관훼리
# 27529                            이코카카드
# 27530                          시모노세키배편
# 27531                          오키나와렌트카
# 27532                         보라카이픽업샌딩
# 27533                         부산후쿠오카배편
# 27534                          부산대마도배편
# 27535                           인천공항콜밴
# 27536                               콜밴
# 27537                            인천공항벤
# 27538                          나트랑공항픽업
# 27539                            나트랑픽업
# 27540                           다낭공항픽업
# 27541                             방콕픽업
# 27542                           대만공항픽업
# 27543                             공항콜밴
# 27544                           보라카이샌딩
# 27545                          나트랑픽업샌딩
# 27546                           세부공항픽업
# 27547                           방콕공항픽업
# 27548                            인천공항밴
# 27549                           인천공항픽업
# 27550                           김포공항콜밴
# 27551                        스포티지트렁크매트
# 27552                           TPE카매트
# 27553                            레이평탄화
# 27554                          카니발차박매트
# 27555                         셀토스트렁크매트
# 27556                      싼타페MX5트렁크매트
# 27557                       팰리세이드트렁크매트
# 27558                        GV70트렁크매트
# 27559                         아임반헤드레스트
# 27560                           BMW목쿠션
# 27561                            벤츠목쿠션
# 27562                            의자목쿠션
# 27563                         스파크점화플러그
# 27564                              락폴딩
# 27565                            메모리시트
# 27566                              혜주파
# 27567                          아임반허리쿠션
# 27568                          히어로인라이프
# 27569                            아임반방석
# 27570                          차량용온열방석
# 27571                             열선방석
# 27572                              진이샵
# 27573                           패러글라이딩
# 27574                         양평패러글라이딩
# 27575                         제주패러글라이딩
# 27576                        제주도패러글라이딩
# 27577                       단양패러글라이딩체험
# 27578                         페러글라이딩체험
# 27579                        코리아패러글라이딩
# 27580                         용인패러글라이딩
# 27581                             열선시트
# 27582                          12V전기장판
# 27583                          자동차열선시트
# 27584                          차량용전기장판
# 27585                          자동차시트교체
# 27586                            리무진시트
# 27587                       폴레드카시트보호매트
# 27588                          차량용전기매트
# 27589                          자동차온열시트
# 27590                       메이튼카시트보호매트
# 27591                          풍절음고무몰딩
# 27592                           자동차풍절음
# 27593                            신슐레이터
# 27594                            흡음테이프
# 27595                              풍절음
# 27596                            테사테이프
# 27597                              윈드킹
# 27598                             방음패드
# 27599                            웨더스트립
# 27600                          부산후쿠오카배
# 27601                           뉴카멜리아호
# 27602                            후쿠오카배
# 27603                              퀸비틀
# 27604                            카멜리아호
# 27605                          대마도당일치기
# 27606                             대마도배
# 27607                          부산오사카배편
# 27608                          퀸비틀후쿠오카
# 27609                            스이카카드
# 27610                          후쿠오카렌트카
# 27611                           대마도렌트카
# 27612                            다낭렌트카
# 27613                           나트랑렌트카
# 27614                           베트남렌트카
# 27615                            일본렌트카
# 27616                           하와이렌트카
# 27617                            세부렌트카
# 27618                           사이판렌트카
# 27619                            태국렌트카
# 27620                        일본후쿠오카렌트카
# 27621                          후쿠오카렌터카
# 27622                  유니버셜스튜디오재팬익스프레스
# 27623                 오사카유니버셜스튜디오익스프레스
# 27624                           바나힐입장권
# 27625                   오사카유니버셜스튜디오입장권
# 27626                         시부야스카이예약
# 27627                 유니버셜스튜디오재팬익스프레스4
# 27628                       하루카스300입장권
# 27629                        도쿄디즈니랜드티켓
# 27630                        디즈니랜드도쿄티켓
# 27631                        후쿠오카타워입장권
# 27632               유니버셜스튜디오재팬닌텐도월드확약권
# 27633                              큐재팬
# 27634                       나고야지브리파크예약
# 27635                          하루카스300
# 27636                        시부야스카이입장권
# 27637                          도쿄스카이트리
# 27638                       하루카스300전망대
# 27639                       타이베이101입장권
# 27640                           후쿠오카타워
# 27641                       타이베이101전망대
# 27642                          타이베이101
# 27643                         도쿄시부야스카이
# 27644                          아베노하루카스
# 27645                            스카이트리
# 27646                           소라니와온천
# 27647                        오사카소라니와온천
# 27648                          다낭패스트트랙
# 27649                       츄라우미수족관입장권
# 27650                         호치민패스트트랙
# 27651                            한바다호핑
# 27652                          페더데일동물원
# 27653                        하우스텐보스입장권
# 27654                         대마도자전거대여
# 27655                             뭉클레어
# 27656                          도쿄자전거대여
# 27657                            세부사파리
# 27658                          파리뮤지엄패스
# 27659                            뮤지엄패스
# 27660                         뮤지엄패스2일권
# 27661                          팀랩플래닛도쿄
# 27662                            진리의성전
# 27663                             생트샤펠
# 27664                       사그라다파밀리아예약
# 27665                           메르시에코백
# 27666                           연예인에코백
# 27667                            캉골에코백
# 27668                         메종키츠네에코백
# 27669                          스타벅스에코백
# 27670                         이자벨마랑에코백
# 27671                           키플링에코백
# 27672                             볼앤체인
# 27673                           EMIS가방
# 27674                           나이키에코백
# 27675                           아페쎄에코백
# 27676                           이미스호보백
# 27677                            명품에코백
# Name: relative_keyword, dtype: object

# %% [markdown]
# **이상치 처리**

# %%
# 사분위수
def get_outlier(price_arr, weight=1.5):
  # target 값과 상관관계가 높은 열을 우선적으로 진행
    quantile_25 = np.percentile(price_arr, 25)
    quantile_75 = np.percentile(price_arr, 75)

    IQR = quantile_75 - quantile_25
    IQR_weight = IQR*weight
  
    lowest = quantile_25 - IQR_weight
    highest = quantile_75 + IQR_weight
  
    excluded_prices = price_arr[(price_arr < lowest) | (price_arr > highest)]
    price_arr = price_arr[(price_arr >=lowest) & (price_arr <= highest)]
    
    return price_arr,excluded_prices

# Z-score
def outlier_remove_z(data, threshold=3):
    z_scores = np.abs(data - np.mean(data)) / np.std(data) # Z-score 계산
    outlier = data[z_scores>threshold]
    removed_data = data[z_scores < threshold]
    
    return removed_data, outlier

# %%
# tmp = pd.DataFrame(columns=["relative_keyword", "avg_price"])
# tmp.to_csv("conditionedData/data/tmp.csv",index=False)

# %%
tmp = pd.DataFrame({"relative_keyword":keyword,"avg_price":3}, index=[0])
tmp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 tmp = pd.DataFrame({"relative_keyword":keyword,"avg_price":3}, index=[0])
#       2 tmp
#
# NameError: name 'keyword' is not defined

# %%
import requests
import json

avg_price = pd.read_csv("conditionedData/data/tmp.csv")
num = 6831

for keyword in keywords[num:]:
    cookies = {
        'NNB': '6TTK2RJU3JPWG',
        'autocomplete': 'use',
        'AD_SHP_BID': '23',
        '_ga': 'GA1.2.1198469368.1669035888',
        'NV_WETR_LOCATION_RGN_M': '"MDUxMTAxMTE="',
        'ASID': '6f5bbfa400000184fa368e5f00000067',
        'SHP_BUCKET_ID': '4',
        'NV_WETR_LAST_ACCESS_RGN_M': '"MDUxMTAxMTE="',
        'NID_AUT': 'xDAIttoc1Atdn7rAs4Y+rogecRjh3p1xevXbJnm0Nr0CEioRQ5/hhmRFwExAG7+T',
        'NID_JKL': 'b+0nlz0gwdbCoxClpc3utji+0en89OQHe0BEDbaUv/Y=',
        'nx_ssl': '2',
        'Viking_Rise_visit_time': '1695077035991',
        'page_uid': 'ifYbMdprvTVsse385PlssssssE0-160453',
        'spage_uid': 'ifYbMdprvTVsse385PlssssssE0-160453',
        'NID_SES': '...',
        'sus_val': 'oosk3W1yUa/jXC7KKHHcV8KC',
        'ncpa': '5114254|lnq2oiag|6088f8339ff87318d5466310aa33bd3df5f4ee8e|s_21a15037d5896|4a037b7e1ad4f4b2b46b7552bf557d83d6e09c69:4801924|lnq2r5yw|252c45b5b1c89d88d92fb4fd42bf99065652c3d4|s_1aec08c8356c9|4a0769694c3e60ffa7b878ff1e700b5ee7a31a93:95694|lnq2t46o|8f47110d725d91bc72e3083c0376c78965d77ffe|95694|28deee716df4986a1bc2f535eccb8e15165491ff:114|lnrg1u34|6c1e428c1fdcf6109a6e368afd36c2c6547842b5|s_1f0b6dd34481|0d9a8a153a4fd6f9e60247ee72a897423e0d11c7',
    }

    headers = {
        'authority': 'search.shopping.naver.com',
        'accept': 'application/json, text/plain, */*',
        'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
        # 'cookie': 'NNB=6TTK2RJU3JPWG; autocomplete=use; AD_SHP_BID=23; _ga=GA1.2.1198469368.1669035888; NV_WETR_LOCATION_RGN_M="MDUxMTAxMTE="; ASID=6f5bbfa400000184fa368e5f00000067; SHP_BUCKET_ID=4; NV_WETR_LAST_ACCESS_RGN_M="MDUxMTAxMTE="; NID_AUT=xDAIttoc1Atdn7rAs4Y+rogecRjh3p1xevXbJnm0Nr0CEioRQ5/hhmRFwExAG7+T; NID_JKL=b+0nlz0gwdbCoxClpc3utji+0en89OQHe0BEDbaUv/Y=; nx_ssl=2; Viking_Rise_visit_time=1695077035991; page_uid=ifYbMdprvTVsse385PlssssssE0-160453; spage_uid=ifYbMdprvTVsse385PlssssssE0-160453; NID_SES=...; sus_val=oosk3W1yUa/jXC7KKHHcV8KC; ncpa=5114254|lnq2oiag|6088f8339ff87318d5466310aa33bd3df5f4ee8e|s_21a15037d5896|4a037b7e1ad4f4b2b46b7552bf557d83d6e09c69:4801924|lnq2r5yw|252c45b5b1c89d88d92fb4fd42bf99065652c3d4|s_1aec08c8356c9|4a0769694c3e60ffa7b878ff1e700b5ee7a31a93:95694|lnq2t46o|8f47110d725d91bc72e3083c0376c78965d77ffe|95694|28deee716df4986a1bc2f535eccb8e15165491ff:114|lnrg1u34|6c1e428c1fdcf6109a6e368afd36c2c6547842b5|s_1f0b6dd34481|0d9a8a153a4fd6f9e60247ee72a897423e0d11c7',
        'logic': 'PART',
        'referer': 'https://search.shopping.naver.com/search/all?frm=NVSCPRO&origQuery&pagingSize=80&&productSet=total&query=%EC%84%B8%EC%A0%9C&sort=rel&timestamp=&viewType=list',
        'sbth': 'd222b49238bd2b7f29803e2ed2f08d01eedaa3d14d24417197e36287d8d5eae0ca4c01288a05847bfed167eb56487188',
        'sec-ch-ua': '"Chromium";v="118", "Google Chrome";v="118", "Not=A?Brand";v="99"',
        'sec-ch-ua-arch': '"x86"',
        'sec-ch-ua-bitness': '"64"',
        'sec-ch-ua-full-version-list': '"Chromium";v="118.0.5993.70", "Google Chrome";v="118.0.5993.70", "Not=A?Brand";v="99.0.0.0"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-model': '""',
        'sec-ch-ua-platform': '"Windows"',
        'sec-ch-ua-platform-version': '"15.0.0"',
        'sec-ch-ua-wow64': '?0',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36',
    }

    params = {
        'frm': 'NVSCPRO',
        'pagingIndex': '1',
        'pagingSize': '100',
        'productSet': 'total',
        'query': f"{keyword}",
        'sort': 'rel',
        'viewType': 'list',
    }

    try : 
        response = requests.get('https://search.shopping.naver.com/api/search/all', params=params, cookies=cookies, headers=headers)
        itemlist = json.loads(response.text)
        price_lst = []
        for idx,i in enumerate(itemlist['shoppingResult']['products']):
            price = i['price'],
            price =  int(price[0])
            price_lst.append(price)

        # 이상치 처리
        price_arr = np.array(price_lst)
        removed_arr,excluded_prices = get_outlier(price_arr, weight=1.5)
        print(f"{num}.{keyword}: {int(removed_arr.mean())} / {removed_arr.shape[0]} ")
        print(f"이상치 제거: {excluded_prices}\n")
        print(f"--------------------------------------------------------------------------------------\n")

        tmp = pd.DataFrame({"relative_keyword":keyword,"avg_price":[int(removed_arr.mean())]})    
        avg_price = pd.concat([avg_price,tmp],axis=0)
        
    except : 
        print(f"{num}.{keyword}")
        print(f"결측값\n")
        print(f"--------------------------------------------------------------------------------------\n")

        tmp = pd.DataFrame({"relative_keyword":[None],"avg_price":[None]})    
        avg_price = pd.concat([avg_price,tmp],axis=0)
        
    avg_price.to_csv("conditionedData/data/tmp.csv",index=False)    
    num += 1
# Out:
# 6831.갤럭시탭S9필름: 18384 / 95
# 이상치 제거: [48770 59900 54890 49900 69900]
#
# --------------------------------------------------------------------------------------
#
# 6832.갤럭시탭S9플러스필름: 14571 / 96
# 이상치 제거: [54890 49900 62900 50900]
#
# --------------------------------------------------------------------------------------
#
# 6833.갤럭시탭S7FE필름: 11352 / 93
# 이상치 제거: [31460 26820 34800 33120 30420 27420 35000]
#
# --------------------------------------------------------------------------------------
#
# 6834.아이패드종이필름: 11324 / 93
# 이상치 제거: [28720 28040 28040 28040 26800 26320 26330]
#
# --------------------------------------------------------------------------------------
#
# 6835.로지텍G304: 40964 / 98
# 이상치 제거: [124770 139000]
#
# --------------------------------------------------------------------------------------
#
# 6836.로지텍G102: 23916 / 86
# 이상치 제거: [  8900  38900    800  13000 103000   2500   2500  40970 101300  42920
#   37300  39730  35930  45370]
#
# --------------------------------------------------------------------------------------
#
# 6837.레이저포인터: 26673 / 94
# 이상치 제거: [119000  89000 160000  88000 149800  99000]
#
# --------------------------------------------------------------------------------------
#
# 6838.MXMASTER3S: 100702 / 98
# 이상치 제거: [233900 234630]
#
# --------------------------------------------------------------------------------------
#
# 6839.무접점키보드: 137901 / 90
# 이상치 제거: [465000    100 319700 460000 365000    100    100 340000 353970 306000]
#
# --------------------------------------------------------------------------------------
#
# 6840.로지텍K380: 46648 / 96
# 이상치 제거: [144550 326800 119400 134120]
#
# --------------------------------------------------------------------------------------
#
# 6841.로지텍무선키보드: 86388 / 97
# 이상치 제거: [278990 299000 279000]
#
# --------------------------------------------------------------------------------------
#
# 6842.로지텍블루투스키보드: 85741 / 96
# 이상치 제거: [278990 299000 279000 279000]
#
# --------------------------------------------------------------------------------------
#
# 6843.한성키보드: 83631 / 100
# 이상치 제거: []
#
# --------------------------------------------------------------------------------------
#
# 6844.K380: 36611 / 75
# 이상치 제거: [ 68800  69800  68800  69800  69600   1750 194600  77400   3000  70790
#    2500   3890   1000  71950   1070   2300   1800   2880    930  80450
#   80770   2210   2500  86450   1500]
#
# --------------------------------------------------------------------------------------
#
# 6845.MXKEYS: 101812 / 94
# 이상치 제거: [249000 273990 249530 298000 342300 576100]
#
# --------------------------------------------------------------------------------------
#
# 6846.엠스톤: 159811 / 87
# 이상치 제거: [ 72580  49000   9900 192400  19000  15900  12900  19000   9900  13900
#   10900  50120  14870]
#
# --------------------------------------------------------------------------------------
#
# 6847.액정타블렛: 641732 / 87
# 이상치 제거: [3640000 4290000 2790000 4679000 3240000 4290000 3640000 4679000 4989000
#  3640000 3640000 4340000 4290000]
#
# --------------------------------------------------------------------------------------
#
# 6848.와콤타블렛: 233541 / 85
# 이상치 제거: [1434400 3640000 4290000 4679000 4679000 2790000 1434400 3240000 1898000
#  1434400 4340000 4679000 3640000 5390000 4290000]
#
# --------------------------------------------------------------------------------------
#
# 6849.와콤: 346069 / 85
# 이상치 제거: [2790000 3640000 4290000 4679000 3240000 4679000 4340000 2790000 3240000
#  4679000 3640000 3190000 4290000 4690000 4989000]
#
# --------------------------------------------------------------------------------------
#
# 6850.전자노트: 29818 / 89
# 이상치 제거: [ 561100  565900  174500  361080  115010  160000  166080  133200 1392840
#   358110  160560]
#
# --------------------------------------------------------------------------------------
#
# 6851.신티크: 2077198 / 99
# 이상치 제거: [36960000]
#
# --------------------------------------------------------------------------------------
#
# 6852.신티크22: 1810710 / 93
# 이상치 제거: [4989000 4989000 4989000 5521040 4989000 8281560 4984000]
#
# --------------------------------------------------------------------------------------
#
# 6853.와콤인튜어스: 170547 / 98
# 이상치 제거: [ 652000 1072320]
#
# --------------------------------------------------------------------------------------
#
# 6854.PTH-660: 461353 / 100
# 이상치 제거: []
#
# --------------------------------------------------------------------------------------
#
# 6855.와콤액정타블렛: 2180035 / 100
# 이상치 제거: []
#
# --------------------------------------------------------------------------------------
#
# 6856.펜타블렛: 176399 / 91
# 이상치 제거: [ 699000  683100  699000  711000  759000  897000 4290000 3640000  683100]
#
# --------------------------------------------------------------------------------------
#
# 6857.드로잉장갑: 4207 / 91
# 이상치 제거: [24900 12900 13900 25860 24900 29502 12900 15290 15290]
#
# --------------------------------------------------------------------------------------
#
# 6858.트랙패드: 119578 / 100
# 이상치 제거: []
#
# --------------------------------------------------------------------------------------
#
# 6859.XPPEN: 346991 / 100
# 이상치 제거: []
#
# --------------------------------------------------------------------------------------
#
# 6860.와콤원펜: 27625 / 96
# 이상치 제거: [101000 133100 101000 707900]
#
# --------------------------------------------------------------------------------------
#
# 6861.판타블렛: 76275 / 86
# 이상치 제거: [ 253000  259000  199000  732000  523900  239000  199000  289000  199500
#   350000  233080  517000  316700 1020360]
#
# --------------------------------------------------------------------------------------
#
# 6862.와콤원: 184945 / 88
# 이상치 제거: [779000 779000 779000 779000 950300 799000 779000 863890 779000 779000
#  779000 792290]
#
# --------------------------------------------------------------------------------------
#
# 6863.엑스피펜: 348611 / 100
# 이상치 제거: []
#
# --------------------------------------------------------------------------------------
#
# 6864.SL-C563W: 300892 / 81
# 이상치 제거: [ 25000 409000 159810  33500  27500 425000 143380 408980 128830 128830
#  128830 135510 425000 408000 482400 443810 822410 687400 669930]
#
# --------------------------------------------------------------------------------------
#
# 6865.SL-C563FW: 387864 / 82
# 이상치 제거: [279000  25000 279000 254100  33500 522740  27500 159810 128830 128830
#  143380 128830 135510  19635  27500  22720 522740 581080]
#
# --------------------------------------------------------------------------------------
#
# 6866.SL-J1680: 57612 / 100
# 이상치 제거: []
#
# --------------------------------------------------------------------------------------
#
# 6867.SL-J1780W: 133614 / 82
# 이상치 제거: [  22500   30580   58000  196460   22500    7400 1129000  218320  222190
#   215170  215170  198750  197850  189000  197010  199000  200000  189050]
#
# --------------------------------------------------------------------------------------
#
# 6868.SL-M2030: 100167 / 83
# 이상치 제거: [134700 135000 135000 135000 174000  25300 130760 156600  66000 132500
#   68200  25300 132120 132120 136800 177470 177470]
#
# --------------------------------------------------------------------------------------
#
# 6869.엡손라벨프린터: 102451 / 90
# 이상치 제거: [ 548890  578700 2129900 1975490 2129800  339000 2129900  531280  777100
#  1270000]
#
# --------------------------------------------------------------------------------------
#
# 6870.사진인화기: 121649 / 93
# 이상치 제거: [ 549000  829000 3990590 8250000 1376000  480000  690800]
#
# --------------------------------------------------------------------------------------
#
# 6871.캐논포토프린터: 150624 / 94
# 이상치 제거: [ 829000 1790000  699000  829000 1790000  690000]
#
# --------------------------------------------------------------------------------------
#
# 6872.브라더라벨기: 123672 / 92
# 이상치 제거: [825000 987300 476800 922600 472350 567000 947700 885600]
#
# --------------------------------------------------------------------------------------
#
# 6873.CLT-K404S: 13904 / 80
# 이상치 제거: [ 69900  66900 249200  45000  77850  37500  58400  75350  77000  29000
#   48200  77850  78400  77000  84900  74600 285000 170990  75000  79000]
#
# --------------------------------------------------------------------------------------
#
# 6874.MLT-D111S: 14495 / 83
# 이상치 제거: [ 59790  65200  66300  64000  65300  64300  60600  69500  57570  67200
#   68000  69000  69500  57310 109700  66500  59900]
#
# --------------------------------------------------------------------------------------
#
# 6875.CLT-K510S: 34474 / 96
# 이상치 제거: [249300 285500 285500 141600]
#
# --------------------------------------------------------------------------------------
# 6876.MLT-D115L: 42766 / 94
# 이상치 제거: [211189 203800 231500 231500 201600 203500]
#
# --------------------------------------------------------------------------------------
#
# 6877.MLT-K250L: 20725 / 79
# 이상치 제거: [115480 124800 122000 122600 122800 123800 116000  83540 121850 114730
#  126000  71300  71300  71300 122000 135800 118190 126000 146000 125520
#  132000]
#
# --------------------------------------------------------------------------------------
#
# 6878.CLT-K515S: 29530 / 91
# 이상치 제거: [185000 185000 189000 192200 243600 192200 182000 196000 182000]
#
# --------------------------------------------------------------------------------------
#
# 6879.엡손라벨테이프: 6977 / 99
# 이상치 제거: [17800]
#
# --------------------------------------------------------------------------------------
#
# 6880.MLT-K200L: 19888 / 82
# 이상치 제거: [ 79440  86500  85500  87800  87000  85850  91000 141000  92100  92100
#   92100  85500 162300 139100  92700  92100  87000  92100]
#
# --------------------------------------------------------------------------------------
#
# 6881.INK-M185: 21626 / 93
# 이상치 제거: [ 63100  67500  71900 100150  67500 119900  63100]
#
# --------------------------------------------------------------------------------------
#
# 6882.K510S: 44559 / 98
# 이상치 제거: [285500 249300]
#
# --------------------------------------------------------------------------------------
#
# 6883.북스캐너: 248310 / 93
# 이상치 제거: [1008000 1970000 1341000 1298900 1193940 1364000 1398100]
#
# --------------------------------------------------------------------------------------
#
# 6884.필름스캐너: 200312 / 89
# 이상치 제거: [ 2305000   982850 20055800   872000  2221900   847370  2051300  1496550
#   1083200   988600   859700]
#
# --------------------------------------------------------------------------------------
#
# 6885.택배스캐너: 76865 / 87
# 이상치 제거: [260000 360000 439000 198000 405000 565500 635670 220000 516300 555200
#  280000 407000 222700]
#
# --------------------------------------------------------------------------------------
#
# 6886.3D스캐너: 4709656 / 93
# 이상치 제거: [195391300  27500000  36500900 154197130  54000000  55000000  28974680]
#
# --------------------------------------------------------------------------------------
#
# 6887.엡손스캐너: 532160 / 94
# 이상치 제거: [4410000 2957020 2945190 4400000 2207080 2751870]
#
# --------------------------------------------------------------------------------------
#
# 6888.캐논스캐너: 568770 / 84
# 이상치 제거: [ 4500000  6000000  6300000  3110810  2890000  3200000  6300000  8500000
#   3200000  2922480  3200000 12500000 11000000 12500000  6000000  6300000]
#
# --------------------------------------------------------------------------------------
#
# 6889.PDA: 669989 / 96
# 이상치 제거: [2670000 2750000 3168000 3300000]
#
# --------------------------------------------------------------------------------------
#
# 6890.CCTV녹화기: 199395 / 95
# 이상치 제거: [2607000  550000  865000  594000  594000]
#
# --------------------------------------------------------------------------------------
#
# 6891.스카이렉스: 256671 / 98
# 이상치 제거: [999990 600000]
#
# --------------------------------------------------------------------------------------
#
# 6892.포커스라이트: 362138 / 87
# 이상치 제거: [2342300 1340000 1340000 1340000 3200000 1930000 1340000 1930000 1340000
#  1930000 1340000 1340000 1340000]
#
# --------------------------------------------------------------------------------------
#
# 6893.스칼렛4세대: 321080 / 100
# 이상치 제거: []
#
# --------------------------------------------------------------------------------------
#
# 6894.오인페: 528197 / 91
# 이상치 제거: [2180000 2390000 4364130 4069680 2884520 6530000 2119780 2390000 2294000]
#
# --------------------------------------------------------------------------------------
#
# 6895.스칼렛2I2: 344259 / 97
# 이상치 제거: [979400 799100 707600]
#
# --------------------------------------------------------------------------------------
#
# 6896.사운드블라스터: 162373 / 96
# 이상치 제거: [630000 510000 864550 500000]
#
# --------------------------------------------------------------------------------------
#
# 6897.외장사운드카드: 48303 / 90
# 이상치 제거: [259350 319000 238000 282500 338000 319000 362400 398000 239000 229000]
#
# --------------------------------------------------------------------------------------
#
# 6898.사운드블라스터G6: 266206 / 94
# 이상치 제거: [810500 778080 778080 778080 750500 955000]
#
# --------------------------------------------------------------------------------------
#
# 6899.캡쳐보드: 75067 / 93
# 이상치 제거: [486700 879000 381120 879000 528000 444900 879000]
#
# --------------------------------------------------------------------------------------
#
# 6900.스트림덱: 256259 / 97
# 이상치 제거: [1684500 1617120  762150]
#
# --------------------------------------------------------------------------------------
#
# 6901.외장ODD: 36161 / 98
# 이상치 제거: [127500 139000]
#
# --------------------------------------------------------------------------------------
#
# 6902.블루레이ODD: 85430 / 88
# 이상치 제거: [226800 209400 192000 296400 205800 208500 432150 215600 203600 243600
#  198500 197300]
#
# --------------------------------------------------------------------------------------
#
# 6903.외장CD롬: 34628 / 91
# 이상치 제거: [ 79800  82000  90960  85000  85800  79560 329700  96900  96900]
#
# --------------------------------------------------------------------------------------
#
# 6904.CD롬: 32323 / 93
# 이상치 제거: [ 82000  86210  90960  85800 139000 133600  85000]
#
# --------------------------------------------------------------------------------------
#
# 6905.CD리더기: 39540 / 88
# 이상치 제거: [ 95520  87200  85000  81600  79900  87090  87090  95700  83500 133500
#  137050  99500]
#
# --------------------------------------------------------------------------------------
#
# 6906.비디오테이프USB변환: 26086 / 94
# 이상치 제거: [ 66300  95240  95240  95240 248200  69340]
#
# --------------------------------------------------------------------------------------
#
# 6907.비디오테이프변환: 22454 / 89
# 이상치 제거: [ 54700 124420 129600  56500  56500  55600  54400 175340 120530 117940
#  117940]
#
# --------------------------------------------------------------------------------------
#
# 6908.공CD: 9629 / 92
# 이상치 제거: [27000 90000 30000 50060 51060 36800 56800 35400]
#
# --------------------------------------------------------------------------------------
#
# 6909.CD보관함: 11313 / 94
# 이상치 제거: [ 59100  56270 105430  53280  70500  56100]
#
# --------------------------------------------------------------------------------------
#
# 6910.CD케이스: 11068 / 97
# 이상치 제거: [61310 40380 59100]
#
# --------------------------------------------------------------------------------------
#
# 6911.비디오변환: 21995 / 96
# 이상치 제거: [124420  66100  63460 129600]
#
# --------------------------------------------------------------------------------------
#
# 6912.CD제작: 2663 / 78
# 이상치 제거: [ 100000 1050000  800000   15600   23000   31600 1050000  600000  690000
#    14340   16320  110000  620000 1225000   55000  120000   11640   26900
#   400000   30225   17080   18150]
#
# --------------------------------------------------------------------------------------
#
# 6913.DDR38GB: 32393 / 93
# 이상치 제거: [ 91680 110000 114200 114200 171170 119000 109980]
#
# --------------------------------------------------------------------------------------
#
# 6914.DDR48G: 30712 / 94
# 이상치 제거: [56000 59220 99590 64250 63650 55170]
#
# --------------------------------------------------------------------------------------
#
# 6915.DDR416G: 45858 / 93
# 이상치 제거: [ 94500 142560 148500 142560  95000  95000  95000]
#
# --------------------------------------------------------------------------------------
#
# 6916.DDR34G: 16587 / 96
# 이상치 제거: [ 62390  73400  50000 117570]
#
# --------------------------------------------------------------------------------------
#
# 6917.DDR48GB: 240511 / 100
# 이상치 제거: []
#
# --------------------------------------------------------------------------------------
#
# 6918.DDR432G: 145455 / 84
# 이상치 제거: [605300 605300 624100 624100 653800 586400 634900 634900 605300 586400
#  605300 653800 621400 567400 621400 567400]
#
# --------------------------------------------------------------------------------------
#
# 6919.DDR516G: 146656 / 86
# 이상치 제거: [ 998270 1030470 1645250 1247790 1645250 1645250 1593840 1247790 1593840
#   706760  684670  684670 1247790 1247790]
#
# --------------------------------------------------------------------------------------
#
# 6920.삼성램8기가: 21118 / 86
# 이상치 제거: [76700 60000 60000 51040 56010 56010 64900 56010 56010 76900 75560 50400
#  55000 55010]
#
# --------------------------------------------------------------------------------------
# 6921.DDR416GB: 68142 / 95
# 이상치 제거: [383580 526710 526710 274800 487660]
#
# --------------------------------------------------------------------------------------
#
# 6922.DDR316G: 41492 / 87
# 이상치 제거: [152460 200000 120210 120210 121550 132600 153560 144450 144450 159390
#  162840 162740 151880]
#
# --------------------------------------------------------------------------------------
#
# 6923.RTX4080: 1804192 / 90
# 이상치 제거: [1111460  589000   11800 2450600  684000 2499000  959120  898300 1089900
#    11000]
#
# --------------------------------------------------------------------------------------
#
# 6924.4080: 1819756 / 92
# 이상치 제거: [1111460 1106790 4099200  655100   11800  575910  311230 2499000]
#
# --------------------------------------------------------------------------------------
#
# 6925.RTX4060TI: 651116 / 90
# 이상치 제거: [ 291560 1417400 1328000 1170760 1073190 1168640 1034290 1060670 1306400
#  1147200]
#
# --------------------------------------------------------------------------------------
#
# 6926.RTX3060TI: 595709 / 83
# 이상치 제거: [2300000 2500000 2500000 2100000 1430000 3000000 3000000 1505810 3000000
#  2200000 3000000 3000000 3352100 2000000 1900000 1900000 2300000]
#
# --------------------------------------------------------------------------------------
#
# 6927.RTX4060: 534901 / 98
# 이상치 제거: [2400000  869000]
#
# --------------------------------------------------------------------------------------
#
# 6928.RTX4070: 1065424 / 97
# 이상치 제거: [4099200 2400000  219360]
#
# --------------------------------------------------------------------------------------
#
# 6929.RTX3070: 1628897 / 100
# 이상치 제거: []
#
# --------------------------------------------------------------------------------------
#
# 6930.4070: 1059896 / 98
# 이상치 제거: [4099200 2400000]
#
# --------------------------------------------------------------------------------------
#
# 6931.그래픽카드지지대: 13123 / 95
# 이상치 제거: [ 58000 270000  39460  45000  78800]
#
# --------------------------------------------------------------------------------------
#
# 6932.3060TI: 674203 / 91
# 이상치 제거: [2300000 2500000 2500000 2100000 1991900 1584900 2728880 4637200 3000000]
#
# --------------------------------------------------------------------------------------
#
# 6933.RTX3080: 2061192 / 100
# 이상치 제거: []
#
# --------------------------------------------------------------------------------------
#
# 6934.1660SUPER: 310334 / 87
# 이상치 제거: [1300000 1300000 1949990 1300000 1400000 1300000 1500000 1300000 1630000
#  1300000 1640000 1300000 1300000]
#
# --------------------------------------------------------------------------------------
#
# 6935.3070TI: 1078360 / 93
# 이상치 제거: [3500000 4637200 4710200 3500000 4006850 4500000 3544160]
#
# --------------------------------------------------------------------------------------
#
# 6936.B550: 242472 / 93
# 이상치 제거: [ 900000 1000000 1000000 1065000 1955000  940000 1038000]
#
# --------------------------------------------------------------------------------------
#
# 6937.B550M: 142087 / 90
# 이상치 제거: [700000 500000 457800 290000 422980 500000 300000 416500 499140 410000]
#
# --------------------------------------------------------------------------------------
#
# 6938.B650: 301198 / 97
# 이상치 제거: [3349000  600130  599910]
#
# --------------------------------------------------------------------------------------
#
# 6939.아두이노키트: 26253 / 88
# 이상치 제거: [103830 114300  96000 108000 124000 100000 105000  98290 124950  99130
#   97290  92830]
#
# --------------------------------------------------------------------------------------
#
# 6940.B650M: 214539 / 99
# 이상치 제거: [476160]
#
# --------------------------------------------------------------------------------------
#
# 6941.Z790: 478339 / 89
# 이상치 제거: [1089990 1190000  998000 1180000 1090000 1015480 1550000 1529000 1529000
#  6350000 1111870]
#
# --------------------------------------------------------------------------------------
#
# 6942.B450M: 170596 / 92
# 이상치 제거: [500000 520000 500000 500000 520000 500000 500000 574000]
#
# --------------------------------------------------------------------------------------
#
# 6943.B650MK: 179513 / 94
# 이상치 제거: [247500 240000 237600 280800 260930 230460]
#
# --------------------------------------------------------------------------------------
#
# 6944.A520M: 81119 / 80
# 이상치 제거: [136910 179000 179000 109700 164160 303060 108860 241830 179000 456710
#  183920 113280 188100 122000 109000 113280 119700 176000 179000 550000]
#
# --------------------------------------------------------------------------------------
#
# 6945.A620M: 159621 / 98
# 이상치 제거: [723430 672340]
#
# --------------------------------------------------------------------------------------
#
# 6946.B550M박격포: 222807 / 93
# 이상치 제거: [422980 416500 312390 336000 732190 350000 350000]
#
# --------------------------------------------------------------------------------------
#
# 6947.B450: 292023 / 98
# 이상치 제거: [1075730 1136400]
#
# --------------------------------------------------------------------------------------
#
# 6948.AM4메인보드: 150402 / 86
# 이상치 제거: [ 800000  514820  500000  800000  549800  509000  700000  991000 1200000
#   763840  600000  900000  492400  600000]
#
# --------------------------------------------------------------------------------------
#
# 6949.A320: 181727 / 99
# 이상치 제거: [800000]
#
# --------------------------------------------------------------------------------------
#
# 6950.A320M: 111776 / 93
# 이상치 제거: [800000 480000 400000 620000 520000 417000 420000]
#
# --------------------------------------------------------------------------------------
#
# 6951.B760M: 187982 / 99
# 이상치 제거: [1139000]
#
# --------------------------------------------------------------------------------------
#
# 6952.B760: 219343 / 98
# 이상치 제거: [409950 481000]
#
# --------------------------------------------------------------------------------------
#
# 6953.마이크로닉스파워: 83780 / 92
# 이상치 제거: [299000 210000 213500 249000 219000 499000 199000 239000]
#
# --------------------------------------------------------------------------------------
#
# 6954.APCUPS: 901028 / 90
# 이상치 제거: [7995000 4963000 7995000 4963000 5464000 7995000 4963000 6568000 4664000
#  6568000]
#
# --------------------------------------------------------------------------------------
#
# 6955.HDMITOVGA: 6922 / 92
# 이상치 제거: [20840 35200 72920 35300 24200 20700 26900 31920]
#
# --------------------------------------------------------------------------------------
#
# 6956.DPTOHDMI: 11414 / 97
# 이상치 제거: [35900 54000 54000]
#
# --------------------------------------------------------------------------------------
#
# 6957.HDMITODP: 11571 / 94
# 이상치 제거: [ 35900  38300  54100  54000  54000 729000]
#
# --------------------------------------------------------------------------------------
#
# 6958.DVITORGB: 11028 / 98
# 이상치 제거: [37000 35900]
#
# --------------------------------------------------------------------------------------
#
# 6959.SSD방열판: 7396 / 89
# 이상치 제거: [20900 27500 24890 27500 24900 24900 28000 28000 40000 24900 36000]
#
# --------------------------------------------------------------------------------------
#
# 6960.팔라딘400: 42406 / 99
# 이상치 제거: [88400]
#
# --------------------------------------------------------------------------------------
#
# 6961.JETDRY: 154828 / 100
# 이상치 제거: []
#
# --------------------------------------------------------------------------------------
#
# 6962.크라켄360: 335975 / 98
# 이상치 제거: [603500 612600]
#
# --------------------------------------------------------------------------------------
#
# 6963.램방열판: 9387 / 94
# 이상치 제거: [31020 32800 37200 64460 31020 40170]
#
# --------------------------------------------------------------------------------------
#
# 6964.공랭쿨러: 34815 / 95
# 이상치 제거: [168000 183600 154000 148000 107000]
#
# --------------------------------------------------------------------------------------
#
# 6965.RC1800: 63015 / 87
# 이상치 제거: [ 90600 109900  86330  97800  91100  95500  93300  97160  91080 103600
#  103900 103900 103600]
#
# --------------------------------------------------------------------------------------
#
# 6966.녹투아쿨러: 115781 / 97
# 이상치 제거: [402640 402630 400100]
#
# --------------------------------------------------------------------------------------
#
# 6967.A2004MU: 66052 / 85
# 이상치 제거: [  6000   8000 138240   6180   7600 130220   8000 124620   8000   6000
#    6000   6800   6000   6800   6800]
#
# --------------------------------------------------------------------------------------
#
# 6968.에몬스침대: 665726 / 98
# 이상치 제거: [1460000 1528000]
#
# --------------------------------------------------------------------------------------
# 6969.저상형침대프레임: 222485 / 92
# 이상치 제거: [1161000 1341000  891000  962000  850000 1847000 1208000 1000000]
#
# --------------------------------------------------------------------------------------
#
# 6970.매트리스깔판: 136883 / 98
# 이상치 제거: [624600 576000]
#
# --------------------------------------------------------------------------------------
#
# 6971.시몬스매트리스: 1675106 / 99
# 이상치 제거: [6000000]
#
# --------------------------------------------------------------------------------------
#
# 6972.3단매트리스: 99603 / 99
# 이상치 제거: [319000]
#
# --------------------------------------------------------------------------------------
#
# 6973.에이스매트리스: 1089065 / 100
# 이상치 제거: []
#
# --------------------------------------------------------------------------------------
#
# 6974.3단접이식매트리스: 98111 / 99
# 이상치 제거: [319000]
#
# --------------------------------------------------------------------------------------
#
# 6975.한샘붙박이장: 1037843 / 98
# 이상치 제거: [2403000 3021000]
#
# --------------------------------------------------------------------------------------
#
# 6976.한샘옷장: 434562 / 97
# 이상치 제거: [1131870 1425000 1206680]
#
# --------------------------------------------------------------------------------------
#
# 6977.이케아옷장: 168084 / 94
# 이상치 제거: [ 621300  706750  719910 1357750 1299460  659200]
#
# --------------------------------------------------------------------------------------
#
# 6978.리바트옷장: 504070 / 93
# 이상치 제거: [1839000 1280000 1622000 1550000 2077000 2671000 1232870]
#
# --------------------------------------------------------------------------------------
#
# 6979.낮은옷장: 151055 / 94
# 이상치 제거: [407520 419970 475230 485450 442800 449000]
#
# --------------------------------------------------------------------------------------
#
# 6980.슬라이드옷장: 334576 / 92
# 이상치 제거: [1772100 1380000 1430000 2300000 2190000 1080000 1207906 4224000]
#
# --------------------------------------------------------------------------------------
#
# 6981.10자장롱: 637217 / 92
# 이상치 제거: [1553000 2066350 3820000 1844990 1690000 2597000 1690000 3150000]
#
# --------------------------------------------------------------------------------------
#
# 6982.전신거울화장대: 110191 / 95
# 이상치 제거: [320000 320000 279000 292560 372490]
#
# --------------------------------------------------------------------------------------
#
# 6983.벽난로콘솔: 127904 / 88
# 이상치 제거: [429000 360000 780000 489000 397000 780000 559700 538000 950000 429000
#  390000 385000]
#
# --------------------------------------------------------------------------------------
#
# 6984.한샘화장대: 329707 / 93
# 이상치 제거: [3820000 2264800 2130000 1324000 1995000 2045000 1359000]
#
# --------------------------------------------------------------------------------------
#
# 6985.이케아화장대: 155849 / 99
# 이상치 제거: [399000]
#
# --------------------------------------------------------------------------------------
#
# 6986.일룸화장대: 332711 / 100
# 이상치 제거: []
#
# --------------------------------------------------------------------------------------
#
# 6987.화장대600: 100851 / 94
# 이상치 제거: [329600 261990 380000 263055 256580 262160]
#
# --------------------------------------------------------------------------------------
#
# 6988.리바트화장대: 356864 / 100
# 이상치 제거: []
#
# --------------------------------------------------------------------------------------
#
# 6989.샤넬거울: 71659 / 98
# 이상치 제거: [133410 149000]
#
# --------------------------------------------------------------------------------------
#
# 6990.수납전신거울: 127725 / 99
# 이상치 제거: [329320]
#
# --------------------------------------------------------------------------------------
#
# 6991.미드센츄리타원형거울: 169005 / 97
# 이상치 제거: [390200 697700 753800]
#
# --------------------------------------------------------------------------------------
#
# 6992.리프트업테이블: 156310 / 95
# 이상치 제거: [449000 491400 653000 629000 452500]
#
# --------------------------------------------------------------------------------------
#
# 6993.코타츠테이블: 106424 / 89
# 이상치 제거: [395000 386300 707700 345700 529990 555990 494030 324000 316530 522500
#  482780]
#
# --------------------------------------------------------------------------------------
#
# 6994.모션데스크: 367905 / 97
# 이상치 제거: [1250000 1850000 1524000]
#
# --------------------------------------------------------------------------------------
#
# 6995.리바트책상: 243985 / 98
# 이상치 제거: [659000 836000]
#
# --------------------------------------------------------------------------------------
#
# 6996.한샘책상: 302264 / 93
# 이상치 제거: [ 949000 1240000  942000 1872000 1114000 1126000 1157000]
#
# --------------------------------------------------------------------------------------
#
# 6997.시디즈T50: 259394 / 100
# 이상치 제거: []
#
# --------------------------------------------------------------------------------------
#
# 6998.서울대의자: 116494 / 97
# 이상치 제거: [398000 389000 399000]
#
# --------------------------------------------------------------------------------------
#
# 6999.린백의자: 101830 / 86
# 이상치 제거: [329000 309000 998000 339000 899000 399000 899000 276300 506500 289000
#  699000 374850 309000 282640]
#
# --------------------------------------------------------------------------------------
#
# 7000.바이네르볼링화: 114060 / 100
# 이상치 제거: []
#
# --------------------------------------------------------------------------------------
#
# 7001.트루다이브: 226591 / 98
# 이상치 제거: [735700 744500]
#
# --------------------------------------------------------------------------------------
#
# 7002.더블케이슈트: 390066 / 90
# 이상치 제거: [  50250   32400  711000  790000  740000  790000  840000 2880000   10000
#    10000]
#
# --------------------------------------------------------------------------------------
#
# 7003.헬시온: 909207 / 99
# 이상치 제거: [3622980]
#
# --------------------------------------------------------------------------------------
#
# 7004.엘프다이브: 306499 / 94
# 이상치 제거: [1274000 1272000 1024000 1128000 1167000 1024000]
#
# --------------------------------------------------------------------------------------
#
# 7005.SMB: 71165 / 95
# 이상치 제거: [354200 455400 256500 608000 242970]
#
# --------------------------------------------------------------------------------------
#
# 7006.일본사람인형: 42951 / 92
# 이상치 제거: [137900 152000 128500 430250 161340 309750 304700 409000]
#
# --------------------------------------------------------------------------------------
#
# 7007.발레바: 98091 / 97
# 이상치 제거: [185860 290000 227120]
#
# --------------------------------------------------------------------------------------
#
# 7008.스마트복싱머신: 107674 / 93
# 이상치 제거: [ 721990  967460 1010500  333600  959650  991100  792800]
#
# --------------------------------------------------------------------------------------
#
# 7009.뮤직복싱머신: 102747 / 91
# 이상치 제거: [ 721990 1010500  967460  333600  231600  991100  792800  228900  362200]
#
# --------------------------------------------------------------------------------------
#
# 7010.복싱기계: 94998 / 92
# 이상치 제거: [ 721990  333600  761800  792800 1370390  806100  788630  362200]
#
# --------------------------------------------------------------------------------------
#
# 7011.복싱마우스피스: 23879 / 96
# 이상치 제거: [125000  84000  99000 151000]
#
# --------------------------------------------------------------------------------------
#
# 7012.낭심보호대: 30142 / 84
# 이상치 제거: [320000 390600 176800 288000 249140 349000 149030 288800 288000 298490
#  330000 260700 210990 341000 298490 186690]
#
# --------------------------------------------------------------------------------------
#
# 7013.테니스엘보보호대: 18893 / 96
# 이상치 제거: [109100  80720  66000  82980]
#
# --------------------------------------------------------------------------------------
#
# 7014.헬스팔꿈치보호대: 19242 / 98
# 이상치 제거: [138800  50530]
#
# --------------------------------------------------------------------------------------
#
# 7015.엘보우보호대: 20406 / 93
# 이상치 제거: [109100  62890  81980 193590  65710  87900 101550]
#
# --------------------------------------------------------------------------------------
#
# 7016.골프엘보보호대: 20437 / 95
# 이상치 제거: [109100  80720 149000  66000 122800]
#
# --------------------------------------------------------------------------------------
#
# 7017.슈퍼비스트: 41135 / 89
# 이상치 제거: [449130 345090 438400 275000 255700 415690 571330 266400 495640 223400
#  236300]
#
# --------------------------------------------------------------------------------------
#
# 7018.슈퍼비스트팔꿈치보호대: 41565 / 18
# 이상치 제거: []
#
# --------------------------------------------------------------------------------------
#
# 7019.팔꿈치아대: 11484 / 93
# 이상치 제거: [33900 41000 44000 35000 64890 66000 60000]
#
# --------------------------------------------------------------------------------------
# 7020.SBD팔꿈치: 101163 / 100
# 이상치 제거: []
#
# --------------------------------------------------------------------------------------
#
# 7021.제로투히어로팔꿈치: 27969 / 99
# 이상치 제거: [58000]
#
# --------------------------------------------------------------------------------------
#
# 7022.환도: 96060 / 87
# 이상치 제거: [ 250000 1000000  340000  345400  351440  392000  370260  419000  368720
#   356150  356150  370260  374850]
#
# --------------------------------------------------------------------------------------
#
# 7023.칼리아르니스: 25077 / 95
# 이상치 제거: [69600 59310 84600 84600 58530]
#
# --------------------------------------------------------------------------------------
#
# 7024.불테리어도복: 261953 / 100
# 이상치 제거: []
#
# --------------------------------------------------------------------------------------
#
# 7025.쿠사쿠라유도복: 153842 / 96
# 이상치 제거: [689570 658100 728390 589350]
#
# --------------------------------------------------------------------------------------
#
# 7026.주짓수래쉬가드: 37837 / 94
# 이상치 제거: [119490  87980  88970 103490 135880  86200]
#
# --------------------------------------------------------------------------------------
#
# 7027.유도도복: 94593 / 91
# 이상치 제거: [350000 370000 600000 600000 328200 320300 643600 341700 304900]
#
# --------------------------------------------------------------------------------------
#
# 7028.다오유도복: 163587 / 46
# 이상치 제거: []
#
# --------------------------------------------------------------------------------------
#
# 7029.아식스레슬링화: 155124 / 100
# 이상치 제거: []
#
# --------------------------------------------------------------------------------------
#
# 7030.태권도띠: 10154 / 95
# 이상치 제거: [ 55000 220000  83520 139700  45600]
#
# --------------------------------------------------------------------------------------
#
# 7031.유도띠: 41072 / 97
# 이상치 제거: [118200 293600 118200]
#
# --------------------------------------------------------------------------------------
#
# 7032.주짓수벨트: 30350 / 87
# 이상치 제거: [164070 116280 107460 118830 140220 118830 125820 147730 125820 101410
#  111980 177200 152190]
#
# --------------------------------------------------------------------------------------
#
# 7033.주짓수띠: 35380 / 99
# 이상치 제거: [128700]
#
# --------------------------------------------------------------------------------------
#
# 7034.태권도검은띠: 9177 / 86
# 이상치 제거: [ 55000  78500  51810  49100  53210  41740  55000  61400  44040 112500
#   51810  51810  39900  96700]
#
# --------------------------------------------------------------------------------------
#
# 7035.품띠: 7868 / 89
# 이상치 제거: [55000 39900 38640 48500 99000 34900 59500 84150 51980 47090 53000]
#
# --------------------------------------------------------------------------------------
#
# 7036.태권도품띠: 9195 / 86
# 이상치 제거: [ 55000  39900  38640  99000  49700  51980  84150  71720 126400 126400
#  117000  49700  99000  51980]
#
# --------------------------------------------------------------------------------------
#
# 7037.송판: 23077 / 97
# 이상치 제거: [102150 118800  95000]
#
# --------------------------------------------------------------------------------------
#
# 7038.격파: 22182 / 97
# 이상치 제거: [440000 117730 253240]
#
# --------------------------------------------------------------------------------------
#
# 7039.루디선글라스: 165722 / 98
# 이상치 제거: [390000 380000]
#
# --------------------------------------------------------------------------------------
#
# 7040.오클리고글: 157661 / 83
# 이상치 제거: [ 18900  57000  70000  70000  60000 269000  26900  12900  26800  60000
#  291740  29000  70000 271150 330880 328000 310000]
#
# --------------------------------------------------------------------------------------
#
# 7041.변색고글: 101498 / 99
# 이상치 제거: [390000]
#
# --------------------------------------------------------------------------------------
#
# 7042.오클리수트로: 154409 / 85
# 이상치 제거: [ 57000  60000  39500  40000 269000  62000  60000  39000  70000  74000
#   39000 263000  45000  54000  60000]
#
# --------------------------------------------------------------------------------------
#
# 7043.루디프로젝트: 180247 / 98
# 이상치 제거: [390000 390000]
#
# --------------------------------------------------------------------------------------
#
# 7044.WTD고글: 143612 / 95
# 이상치 제거: [20000 20000 20000 20000 18000]
#
# --------------------------------------------------------------------------------------
#
# 7045.안경위에쓰는선글라스: 15587 / 86
# 이상치 제거: [ 55000  55000  55000  55000  55000  50800  54900 112600  55000  55000
#   61000  55000  75650  47900]
#
# --------------------------------------------------------------------------------------
#
# 7046.오클리레이다락: 143410 / 99
# 이상치 제거: [359000]
#
# --------------------------------------------------------------------------------------
#
# 7047.100%고글: 192662 / 99
# 이상치 제거: [501000]
#
# --------------------------------------------------------------------------------------
#
# 7048.등산선글라스: 44110 / 89
# 이상치 제거: [160000 180000 160000 261000 188000 169200 250000 230000 226000 219000
#  329000]
#
# --------------------------------------------------------------------------------------
#
# 7049.골프고글: 113394 / 100
# 이상치 제거: []
#
# --------------------------------------------------------------------------------------
#
# 7050.락브로스고글: 20211 / 85
# 이상치 제거: [  1500   1500  54830   2000  57060  42900 177510  81020 139320  40320
#   50830  92370  41590  38500  39820]
#
# --------------------------------------------------------------------------------------
#
# 7051.오클리스플릿샷: 242419 / 100
# 이상치 제거: []
#
# --------------------------------------------------------------------------------------
#
# 7052.러닝헤어밴드: 8003 / 94
# 이상치 제거: [45000 28400 28000 72390 27290 38680]
#
# --------------------------------------------------------------------------------------
#
# 7053.아디다스헤어밴드: 17086 / 80
# 이상치 제거: [52070 52070 52070 58500 58500 58500 54410 54410 58500 58500 58500 54410
#  58500 58500 58500 58500 58500 58500 58500 58500]
#
# --------------------------------------------------------------------------------------
#
# 7054.축구헤어밴드: 6425 / 95
# 이상치 제거: [31500 18240 27900 19800 19000]
#
# --------------------------------------------------------------------------------------
#
# 7055.등산헤어밴드: 8171 / 91
# 이상치 제거: [45000 57000 56050 81300 57000 75200 81300 50150 65000]
#
# --------------------------------------------------------------------------------------
#
# 7056.나이키헤드밴드: 19640 / 97
# 이상치 제거: [ 50000  70000 101000]
#
# --------------------------------------------------------------------------------------
#
# 7057.룰루레몬헤어밴드: 39150 / 99
# 이상치 제거: [96520]
#
# --------------------------------------------------------------------------------------
#
# 7058.파타고니아헤어밴드: 58868 / 99
# 이상치 제거: [156600]
#
# --------------------------------------------------------------------------------------
#
# 7059.니워머: 24684 / 95
# 이상치 제거: [110000  99750 141700  90020 107100]
#
# --------------------------------------------------------------------------------------
#
# 7060.골프팔토시: 7950 / 94
# 이상치 제거: [29900 31670 37000 38190 29500 41240]
#
# --------------------------------------------------------------------------------------
#
# 7061.골프발토시: 14221 / 88
# 이상치 제거: [  49800   48900   62070   54510   49760   51000   91080   59250   54900
#    59000   74800 2469700]
#
# --------------------------------------------------------------------------------------
#
# 7062.테니스토시: 8566 / 95
# 이상치 제거: [49800 27450 35600 27600 31450]
#
# --------------------------------------------------------------------------------------
#
# 7063.무릎토시: 14121 / 95
# 이상치 제거: [49800 49000 55000 56700 55000]
#
# --------------------------------------------------------------------------------------
#
# 7064.종아리토시: 8541 / 88
# 이상치 제거: [49800 28000 91080 29784 33240 34490 31200 31200 31600 30500 59602 32490]
#
# --------------------------------------------------------------------------------------
#
# 7065.기모팔토시: 13735 / 98
# 이상치 제거: [41990 87070]
#
# --------------------------------------------------------------------------------------
#
# 7066.테니스방한토시: 10039 / 97
# 이상치 제거: [49800 20990 42280]
#
# --------------------------------------------------------------------------------------
#
# 7067.클라이밍초크: 23925 / 99
# 이상치 제거: [78200]
#
# --------------------------------------------------------------------------------------
#
# 7068.클라이밍초크백: 30575 / 99
# 이상치 제거: [85590]
#
# --------------------------------------------------------------------------------------
#
# 7069.다이니마파우치: 29555 / 88
# 이상치 제거: [157520 103000 118400 240000 141500 141500 118400 118400 139000 234900
#  240000 225000]
#
# --------------------------------------------------------------------------------------
# 7070.초크백: 28136 / 98
# 이상치 제거: [78200 72100]
#
# --------------------------------------------------------------------------------------
#
# 7071.클라이밍테이프: 7302 / 84
# 이상치 제거: [ 60000 300370 220200  68090  39060  38770 347200  65200  67500  44920
#  219320  42770  69550  65200  40310  44800]
#
# --------------------------------------------------------------------------------------
#
# 7072.액상초크: 14517 / 96
# 이상치 제거: [50100 34260 55850 55000]
#
# --------------------------------------------------------------------------------------
#
# 7073.클라이밍홀드: 55310 / 92
# 이상치 제거: [834600 368980 424300 399100 254920 432000 275900 879000]
#
# --------------------------------------------------------------------------------------
#
# 7074.중고캠핑카: 24571 / 77
# 이상치 제거: [64900000 11100000 11100000  7300000 45000000 27000000 77000000 65000000
#   8600000 16500000 46000000 92000000  4708100 57000000  3569560 85500000
#  70000000   271400   209900  5350110  5350110   271400   271400]
#
# --------------------------------------------------------------------------------------
#
# 7075.신일팬히터1200가방: 38283 / 90
# 이상치 제거: [ 78240  81500  76800  63800  93000  82200  63680  69000 125000  68000]
#
# --------------------------------------------------------------------------------------
#
# 7076.인산철파워뱅크: 921681 / 99
# 이상치 제거: [2990000]
#
# --------------------------------------------------------------------------------------
#
# 7077.인디언행어: 25979 / 96
# 이상치 제거: [ 95000 138800 214500 135000]
#
# --------------------------------------------------------------------------------------
#
# 7078.팬히터받침대: 29891 / 92
# 이상치 제거: [65000 79000 79000 64900 75520 88200 77060 81500]
#
# --------------------------------------------------------------------------------------
#
# 7079.데이지체인: 12910 / 99
# 이상치 제거: [65080]
#
# --------------------------------------------------------------------------------------
#
# 7080.스탠리워터저그: 31399 / 95
# 이상치 제거: [108100  88000  98530 110000 140500]
#
# --------------------------------------------------------------------------------------
#
# 7081.인디언즈파워뱅크: 984046 / 67
# 이상치 제거: []
#
# --------------------------------------------------------------------------------------
#
# 7082.미즈호등유통: 37668 / 99
# 이상치 제거: [150890]
#
# --------------------------------------------------------------------------------------
#
# 7083.빌트인가스레인지: 199541 / 96
# 이상치 제거: [502200 664050 534000 550000]
#
# --------------------------------------------------------------------------------------
#
# 7084.가스렌지2구: 170920 / 95
# 이상치 제거: [370420 351870 348170 360990 337370]
#
# --------------------------------------------------------------------------------------
#
# 7085.가스렌지3구: 198632 / 99
# 이상치 제거: [664050]
#
# --------------------------------------------------------------------------------------
#
# 7086.가스레인지3구: 200365 / 99
# 이상치 제거: [664050]
#
# --------------------------------------------------------------------------------------
#
# 7087.3구가스레인지: 196657 / 98
# 이상치 제거: [406600 664050]
#
# --------------------------------------------------------------------------------------
#
# 7088.2구가스레인지: 171426 / 95
# 이상치 제거: [370420 351870 348170 360990 337370]
#
# --------------------------------------------------------------------------------------
#
# 7089.SK매직가스레인지: 199504 / 95
# 이상치 제거: [  5860 550000   2520   8900   8900]
#
# --------------------------------------------------------------------------------------
#
# 7090.매립형가스레인지: 181892 / 98
# 이상치 제거: [2070000 3820000]
#
# --------------------------------------------------------------------------------------
#
# 7091.린나이가스레인지3구: 224119 / 98
# 이상치 제거: [664050 663570]
#
# --------------------------------------------------------------------------------------
#
# 7092.가스레인지2구: 171268 / 95
# 이상치 제거: [370420 351870 348170 360990 337370]
#
# --------------------------------------------------------------------------------------
#
# 7093.하츠가스레인지: 179386 / 98
# 이상치 제거: [450000 440000]
#
# --------------------------------------------------------------------------------------
#
# 7094.업소용화구: 181806 / 99
# 이상치 제거: [1000000]
#
# --------------------------------------------------------------------------------------
#
# 7095.린나이빌트인가스레인지: 213165 / 96
# 이상치 제거: [502200 664050 534000 663570]
#
# --------------------------------------------------------------------------------------
#
# 7096.린나이3구가스레인지: 224774 / 98
# 이상치 제거: [664050 663570]
#
# --------------------------------------------------------------------------------------
#
# 7097.빌트인가스렌지: 200614 / 96
# 이상치 제거: [502200 664050 534000 550000]
#
# --------------------------------------------------------------------------------------
#
# 7098.간택기: 206617 / 100
# 이상치 제거: []
#
# --------------------------------------------------------------------------------------
#
# 7099.저당밥솥: 106018 / 87
# 이상치 제거: [489400 379960 348588 420500 377440 389900 403260 484930 489400 884080
#  559000 495000 411360]
#
# --------------------------------------------------------------------------------------
#
# 7100.쿠첸6인용압력밥솥: 262231 / 96
# 이상치 제거: [620420 699000 626040 599000]
#
# --------------------------------------------------------------------------------------
#
# 7101.쿠쿠밥솥6인용: 244789 / 98
# 이상치 제거: [658000 579900]
#
# --------------------------------------------------------------------------------------
#
# 7102.쿠쿠밥솥10인용: 277333 / 99
# 이상치 제거: [758000]
#
# --------------------------------------------------------------------------------------
#
# 7103.쿠첸브레인: 314742 / 92
# 이상치 제거: [462010 465320 674190  13900  12900  12900  13900 484700]
#
# --------------------------------------------------------------------------------------
#
# 7104.쿠첸밥솥: 264394 / 99
# 이상치 제거: [620420]
#
# --------------------------------------------------------------------------------------
#
# 7105.쿠첸10인용압력밥솥: 278960 / 97
# 이상치 제거: [861380 698400 700500]
#
# --------------------------------------------------------------------------------------
#
# 7106.쿠쿠3인용압력밥솥: 206458 / 98
# 이상치 제거: [944660 634820]
#
# --------------------------------------------------------------------------------------
#
# 7107.인스턴트팟: 173431 / 93
# 이상치 제거: [489990 504000 734000 600000 541030 561610 552230]
#
# --------------------------------------------------------------------------------------
#
# 7108.이케아협탁: 46162 / 89
# 이상치 제거: [149000 149000 164000 149000 229000 139000 159000 149000 159000 164000
#  149000]
#
# --------------------------------------------------------------------------------------
#
# 7109.모듈협탁: 132775 / 98
# 이상치 제거: [1399000  996750]
#
# --------------------------------------------------------------------------------------
#
# 7110.라탄협탁: 111693 / 96
# 이상치 제거: [326400 440000 680000 273200]
#
# --------------------------------------------------------------------------------------
#
# 7111.한샘협탁: 157802 / 84
# 이상치 제거: [ 934000 1022400 1021500  996300 1047600  980000  791000  745000  944700
#  1005330  761000  753880  802590  802590  880300 1067840]
#
# ...
#
# 9819.비비고순살고등어
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9820.포두부
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9821.통밀또띠아
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9822.브리또
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9823.감자수제비
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9824.비비고고등어
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9825.핫앤쿡
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9826.도토리묵
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9827.라이스페이퍼
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9828.두부또띠아
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9829.양배추환
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9830.유기농양배추환
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9831.여주환
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9832.인셀덤딥톡스
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9833.유기농여주환
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9834.상쾌환
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9835.베트남침향
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9836.광동침향환
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9837.카미가벼운민들레처럼
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9838.가벼운민들레처럼
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9839.굼벵이환
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9840.딥톡플러스
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9841.홍화씨
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9842.우황청심환
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9843.술깸
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9844.아누카사과분말
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9845.아누카사과
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9846.미숫가루
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9847.새싹보리
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9848.황성주생식
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9849.강황가루
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9850.생강가루
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9851.차가버섯
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9852.새싹보리분말
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9853.생식
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9854.여주분말
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9855.계피가루
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9856.아누카사과추출분말
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9857.산삼
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9858.산양삼
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9859.장뇌삼
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9860.수삼
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9861.6년근인삼
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9862.새싹삼
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9863.금산인삼
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9864.풍기인삼
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9865.인삼정과
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9866.인삼차
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9867.산삼배양근
# 결측값
#
# --------------------------------------------------------------------------------------
# 9868.새싹인삼
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9869.산양산삼
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9870.파삼
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9871.인삼주
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9872.산양삼가격
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9873.꿀스틱
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9874.아카시아꿀
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9875.커클랜드꿀
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9876.밤꿀
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9877.벌집꿀
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9878.사양벌꿀
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9879.안상규벌꿀
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9880.토종꿀
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9881.스틱꿀
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9882.코스트코꿀
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9883.콤비타마누카꿀
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9884.마누카꿀스틱
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9885.태국꿀
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9886.벌꿀집
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9887.동서벌꿀
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9888.다이어트차
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9889.허벌라이프허벌티
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9890.태양의마테차
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9891.마테차
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9892.건조레몬
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9893.베라수
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9894.그라비올라
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9895.멜팅컷티
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9896.식욕억제차
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9897.허벌라이프
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9898.차전자피환
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9899.차전자피가루
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9900.대장사랑
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9901.차전자피식이섬유
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9902.종근당차전자피
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9903.황금구렁이
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9904.장박사
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9905.푸응다이어트
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9906.딥트피치번
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9907.딥트3일
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9908.차전차피
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9909.경성제약장박사
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9910.딥트3일피치번
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9911.피치번
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9912.칼로리바란스
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9913.닥터유프로단백질바
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9914.퀘스트프로틴바
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9915.닥터유에너지바
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9916.셀렉스프로틴바
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9917.닥터유단백질바미니
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9918.칼로리발란스
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9919.고단백하루견과바
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9920.견과류바
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9921.오늘든든고단백하루견과바
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9922.하루견과바
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9923.포스트에너지바
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9924.영양바
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9925.닥터유에너지바미니
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9926.단백질바미니
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9927.퀘스트바
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9928.다이어트커피
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9929.웰컷포맨
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9930.오늘부터슬림카페
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9931.투비컷
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9932.오늘부터
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9933.슬림카페
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9934.룰더핏
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9935.탄수화물컷팅제
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9936.오늘부터웰컷포맨
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9937.번앤번
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9938.슬림버니
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9939.2비컷
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9940.바이어트
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9941.오늘부터슬림핑크
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9942.공액리놀레산
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9943.CLA홍화씨
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9944.CLA홍화씨슬리밍
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9945.프레시내추럴슬리밍플러스다이어트
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9946.제로픽
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9947.비아벨로제로픽
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9948.하드코어버닝티
# 결측값
#
# --------------------------------------------------------------------------------------
# 9949.제로핏
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9950.피타니글루타치온
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9951.로즈힙엘라스틴
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9952.콩잎장아찌
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9953.매실장아찌
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9954.마늘장아찌
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9955.울외장아찌
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9956.우메보시
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9957.단풍콩잎
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9958.초석잠장아찌
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9959.콩잎김치
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9960.홍쌍리매실장아찌
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9961.삭힌콩잎
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9962.장조림
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9963.본죽메추리알장조림
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9964.계란장
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9965.돼지고기장조림
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9966.쇠고기장조림
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9967.뻥튀기
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9968.카라멜팝콘
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9969.강냉이
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9970.대파크림치즈팝콘
# 결측값
#
# --------------------------------------------------------------------------------------
#
# 9971.마카로니뻥튀기
# 결측값
#
# --------------------------------------------------------------------------------------
# KeyboardInterrupt

# %%
data["avg_price"] = avg_price

# %%
data.to_csv("data/category/sorted_total_store1.csv",index=False)

# %%
data
# Out:
#      relative_keyword  total_search  total_store_count  competitive_rate  \
# 0                 제모제        1250.0            50115.0             40.09
# 1              유아세탁세제        1410.0            50365.0             35.72
# 2              기저귀휴지통        3200.0            50428.0             15.76
# 3                 카테킨       12470.0            50519.0              4.05
# 4                파우더통        1500.0            50724.0             33.82
# ...               ...           ...                ...               ...
# 1607               잡화        4600.0        240755648.0          52338.18
# 1608               의류        5360.0        266761395.0          49768.92
# 1609               여성        6830.0        273371280.0          40025.08
# 1610               패션       20730.0        423405866.0          20424.79
# 1611               생활        4650.0        467694995.0         100579.57
#
#       avg_price
# 0         15649
# 1         19351
# 2         32578
# 3         27531
# 4          8217
# ...         ...
# 1607      49864
# 1608      32334
# 1609      41623
# 1610      43719
# 1611      18904
#
# [1612 rows x 5 columns]

# %% [markdown]
# # TEST용

# %%
import requests
import json

keyword = "갤럭시탭S9필름"

cookies = {
    'NNB': '6TTK2RJU3JPWG',
    'autocomplete': 'use',
    'AD_SHP_BID': '23',
    '_ga': 'GA1.2.1198469368.1669035888',
    'NV_WETR_LOCATION_RGN_M': '"MDUxMTAxMTE="',
    'ASID': '6f5bbfa400000184fa368e5f00000067',
    'SHP_BUCKET_ID': '4',
    'NV_WETR_LAST_ACCESS_RGN_M': '"MDUxMTAxMTE="',
    'NID_AUT': 'xDAIttoc1Atdn7rAs4Y+rogecRjh3p1xevXbJnm0Nr0CEioRQ5/hhmRFwExAG7+T',
    'NID_JKL': 'b+0nlz0gwdbCoxClpc3utji+0en89OQHe0BEDbaUv/Y=',
    'nx_ssl': '2',
    'Viking_Rise_visit_time': '1695077035991',
    'page_uid': 'ifYbMdprvTVsse385PlssssssE0-160453',
    'spage_uid': 'ifYbMdprvTVsse385PlssssssE0-160453',
    'NID_SES': '...',
    'sus_val': 'oosk3W1yUa/jXC7KKHHcV8KC',
    'ncpa': '5114254|lnq2oiag|6088f8339ff87318d5466310aa33bd3df5f4ee8e|s_21a15037d5896|4a037b7e1ad4f4b2b46b7552bf557d83d6e09c69:4801924|lnq2r5yw|252c45b5b1c89d88d92fb4fd42bf99065652c3d4|s_1aec08c8356c9|4a0769694c3e60ffa7b878ff1e700b5ee7a31a93:95694|lnq2t46o|8f47110d725d91bc72e3083c0376c78965d77ffe|95694|28deee716df4986a1bc2f535eccb8e15165491ff:114|lnrg1u34|6c1e428c1fdcf6109a6e368afd36c2c6547842b5|s_1f0b6dd34481|0d9a8a153a4fd6f9e60247ee72a897423e0d11c7',
}

headers = {
    'authority': 'search.shopping.naver.com',
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    # 'cookie': 'NNB=6TTK2RJU3JPWG; autocomplete=use; AD_SHP_BID=23; _ga=GA1.2.1198469368.1669035888; NV_WETR_LOCATION_RGN_M="MDUxMTAxMTE="; ASID=6f5bbfa400000184fa368e5f00000067; SHP_BUCKET_ID=4; NV_WETR_LAST_ACCESS_RGN_M="MDUxMTAxMTE="; NID_AUT=xDAIttoc1Atdn7rAs4Y+rogecRjh3p1xevXbJnm0Nr0CEioRQ5/hhmRFwExAG7+T; NID_JKL=b+0nlz0gwdbCoxClpc3utji+0en89OQHe0BEDbaUv/Y=; nx_ssl=2; Viking_Rise_visit_time=1695077035991; page_uid=ifYbMdprvTVsse385PlssssssE0-160453; spage_uid=ifYbMdprvTVsse385PlssssssE0-160453; NID_SES=...; sus_val=oosk3W1yUa/jXC7KKHHcV8KC; ncpa=5114254|lnq2oiag|6088f8339ff87318d5466310aa33bd3df5f4ee8e|s_21a15037d5896|4a037b7e1ad4f4b2b46b7552bf557d83d6e09c69:4801924|lnq2r5yw|252c45b5b1c89d88d92fb4fd42bf99065652c3d4|s_1aec08c8356c9|4a0769694c3e60ffa7b878ff1e700b5ee7a31a93:95694|lnq2t46o|8f47110d725d91bc72e3083c0376c78965d77ffe|95694|28deee716df4986a1bc2f535eccb8e15165491ff:114|lnrg1u34|6c1e428c1fdcf6109a6e368afd36c2c6547842b5|s_1f0b6dd34481|0d9a8a153a4fd6f9e60247ee72a897423e0d11c7',
    'logic': 'PART',
    'referer': 'https://search.shopping.naver.com/search/all?frm=NVSCPRO&origQuery&pagingSize=80&&productSet=total&query=%EC%84%B8%EC%A0%9C&sort=rel&timestamp=&viewType=list',
    'sbth': 'd222b49238bd2b7f29803e2ed2f08d01eedaa3d14d24417197e36287d8d5eae0ca4c01288a05847bfed167eb56487188',
    'sec-ch-ua': '"Chromium";v="118", "Google Chrome";v="118", "Not=A?Brand";v="99"',
    'sec-ch-ua-arch': '"x86"',
    'sec-ch-ua-bitness': '"64"',
    'sec-ch-ua-full-version-list': '"Chromium";v="118.0.5993.70", "Google Chrome";v="118.0.5993.70", "Not=A?Brand";v="99.0.0.0"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': '""',
    'sec-ch-ua-platform': '"Windows"',
    'sec-ch-ua-platform-version': '"15.0.0"',
    'sec-ch-ua-wow64': '?0',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36',
}

params = {
    'frm': 'NVSCPRO',
    'pagingIndex': '1',
    'pagingSize': '100',
    'productSet': 'total',
    'query': f"{keyword}",
    'sort': 'rel',
    'viewType': 'list',
}

response = requests.get('https://search.shopping.naver.com/api/search/all', params=params, cookies=cookies, headers=headers)
itemlist = json.loads(response.text)
itemlist
# sum = 0
# price_lst = []
# print(itemlist)
# # for idx,i in enumerate(itemlist['shoppingResult']['products']):
# #     price = i['price'],
# #     price =  int(price[0])
# #     price_lst.append(price)
    
# # price_arr = np.array(price_lst)
# # removed_arr,excluded_prices = get_outlier(price_arr, weight=1.5)
# # print(f"{keyword} \t {int(removed_arr.mean())} \t {removed_arr.shape[0]} ")
# # print(f"이상치 제거 {excluded_prices}\n")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[14], line 60
#      49 params = {
#      50     'frm': 'NVSCPRO',
#      51     'pagingIndex': '1',
#    (...)
#      56     'viewType': 'list',
#      57 }
#      59 response = requests.get('https://search.shopping.naver.com/api/search/all', params=params, cookies=cookies, headers=headers)
# ---> 60 itemlist = json.loads(response.text)
#      61 itemlist
#
# File ~\AppData\Local\Programs\Python\Python310\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~\AppData\Local\Programs\Python\Python310\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
{'searchParam': {'sort': 'rel', 'pagingIndex': 1, 'pagingSize': '100', 'viewType': 'list', 'productSet': 'total', 'frm': 'NVSCPRO', 'query': '가습기오일', 'origQuery': '가습기오일', 'adQuery': '가습기오일', 'iq': [], 'eq': [], 'xq': [], 'timestamp': ''}, 'searchBanInfo': {'id': '62fb3e37c88eab787f1dafe6', 'keyword': '가습기용오일', 'handlingReason': 'SELL_STOP', 'banInfoType': 'BAN', 'serviceYn': 'Y', 'serviceEndDate': None, 'content1': '가습기용으로 광고/판매되는 오일/향료는 인체유해성 이슈로 관련 검색결과를 노출하지 않고 있으니 서비스 이용에 참고부탁드립니다.', 'content2': None, 'content3': None, 'linkContent': None, 'linkUrl': None, 'subkeywords': ['가습기용아로마오일', '가습기용아로마', '가습기용방향제', '아로마디퓨저가습기', '가습기에센셜', '가습기오일', '가습기아로마', '가습기아로마오일', '가습기방향제', '가습기용향료', '가습기향료', '가습기용에센셜']}, 'surls': [], 'nClick': {'code': 'svc.shopping.v3', 'codeType': 'ssc', 'pageUid': 'iTPJ1sqWc1U1nwtu5MC-277981', 'susVal': 'oosk3W1yUa/jXC7KKHHcV8KC', 'query': '%EA%B0%80%EC%8A%B5%EA%B8%B0%EC%98%A4%EC%9D%BC'}}

# %%
fig, axs = plt.subplots(1, 2, figsize=(10,6))
axs[0].boxplot(price_lst);
axs[1].hist(price_lst, bins=100);

# %%
fig, axs = plt.subplots(1, 2, figsize=(10,6))
axs[0].boxplot(removed_arr);
axs[1].hist(removed_arr, bins=100);

# %%
def get_outlier(price_arr, weight=1.5):
  # target 값과 상관관계가 높은 열을 우선적으로 진행
    quantile_25 = np.percentile(price_arr, 25)
    quantile_75 = np.percentile(price_arr, 75)

    IQR = quantile_75 - quantile_25
    IQR_weight = IQR*weight
  
    lowest = quantile_25 - IQR_weight
    highest = quantile_75 + IQR_weight
  
    price_arr = price_arr[(price_arr >=lowest) & (price_arr <= highest)]
    return price_arr

# %%
get_outlier(price_arr)
# Out:
# array([ 8330,  8200,  6100,  6500,  5100, 19500, 12000, 11900,  4550,
#         4500, 27200, 10980, 30170,  4600, 23600,  1250,  2880,  7900,
#         6400,  1000, 12000, 14900,  8000,  2830,  5300,  6090, 17900,
#        23600,  1300, 19900,  6900, 13900,  5100, 12700,  7900,   640,
#         8160,  1000, 12200, 12500, 21920,  1800,  5900,  8000, 13500,
#         2610,  5580,  1560,  2920,  4500,   840,  6720,   890,  6410,
#        27200,  8320,  6900,  6400,  7000,  8100, 20020,  7900, 30170,
#         6150, 17900,  5370,  6930,  8000,  7000,  5580,   890,  3170,
#         8070,  7350,  8400,   890,  1500,  6440, 23440,  4600, 15500,
#         5580,  6700, 23200, 16900,  8500, 21000,  8300, 18740,   800,
#         3190,  5000, 11360,  7460, 19900, 10200,  5300,   840,  1920])

# %%
plt.boxplot(get_outlier(price_arr));

# %%
arr = price_arr

def remove_outliers(arr) :
    mean = arr.mean()
    std = arr.std()
    upper_bound = mean + (3 * std)
    lower_bound = mean - (3 * std)
    return (upper_bound,lower_bound)

upper_bound,lower_bound = remove_outliers(arr)

removed_arr = arr[(arr <=upper_bound) & (arr >= lower_bound)]
print(arr[(arr >=upper_bound) | (arr <= lower_bound)])
print(removed_arr.shape)
int(removed_arr.mean())
# Out:
# [160000 154000 200000]
# (97,)
# 16774
