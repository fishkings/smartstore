# %% [markdown]
# <font color="firebrick" size="6"><b>cid 분석</b></font>

# %%
import pandas as pd
import numpy as np

# %%
cid = pd.read_csv("primaryCategoryDate/cid/cid_keyword.csv",index_col=0)
cid
# Out:
#              title
# cid
# 50000001      패션잡화
# 50000002    화장품/미용
# 50000003    디지털/가전
# 50000004   가구/인테리어
# 50000005     출산/육아
# ...            ...
# 50015260  기타/이동서비스
# 50015280   박물관/미술관
# 50015300      테마파크
# 50015320   역사/관광명소
# 50015340       에코백
#
# [5209 rows x 1 columns]

# %%
# cid를 컬럼으로 넘주고 0부터 오름차순으로 인덱스 생성
cid["cid"] = cid.index 
cid = cid[["cid","title"]]
cid.index = np.arange(0,len(cid["title"]))
cid
# Out:
#            cid     title
# 0     50000001      패션잡화
# 1     50000002    화장품/미용
# 2     50000003    디지털/가전
# 3     50000004   가구/인테리어
# 4     50000005     출산/육아
# ...        ...       ...
# 5204  50015260  기타/이동서비스
# 5205  50015280   박물관/미술관
# 5206  50015300      테마파크
# 5207  50015320   역사/관광명소
# 5208  50015340       에코백
#
# [5209 rows x 2 columns]

# %%
top20 = pd.read_csv("primaryCategoryDate/top20_keywords/category_search_top20.csv")
top20
# Out:
#            cid                0              1           2           3  \
# 0     50000001           나이키운동화          어그슬리퍼         운동화         캐리어
# 1     50000002               샴푸           바디워시       마데카크림     ahc아이크림
# 2     50000003              가습기           탄소매트        전기매트      가열식가습기
# 3     50000004               행거          침대프레임          쇼파          침대
# 4     50000005            베베드피노            물티슈      키즈경량패딩        키즈패딩
# ...        ...              ...            ...         ...         ...
# 5179  50015260         대마도자전거대여       대마도전동자전거      세부택시투어     히타카츠자전거
# 5180  50015280          파리뮤지엄패스          뮤지엄패스  도쿄지브리미술관예약     팀랩플래닛도쿄
# 5181  50015300  유니버셜스튜디오재팬익스프레스  유니버셜스튜디오재팬입장권  유니버셜스튜디오재팬      바나힐입장권
# 5182  50015320         진리의성전입장권       바티칸패스트트랙     콜로세움입장권  바티칸투어패스트트랙
# 5183  50015340              에코백         이미스에코백       이미스가방       미니에코백
#
#                      4               5                 6            7  \
# ...

# %%
# 공통된 cid 부분만 추출 
data = pd.merge(cid,top20,on="cid")

# %%
# 공통되지 않은 cid의 title  추출
merged = pd.merge(cid, top20, on="cid", how="left", indicator=True)  # indicator로 병합 작업 확인 가능 
excluded = merged[merged["_merge"] != "both"]
excluded["title"]
# Out:
# 617           신발
# 1248        언더웨어
# 1249       우산/양산
# 1250        여행소품
# 1251    노트북/주변기기
# 1306         라이터
# 1307        크리스탈
# 1308     수첩/다이어리
# 1310          발찌
# 1311          헤어
# 1312        넥타이핀
# 1313        장식소품
# 1852      칠파장스탠드
# 2244       스페셜케어
# 2245      네일메이크업
# 2252       소품/기타
# 2255        소품지갑
# 2260       USB토이
# 2295       DVR카드
# 2386     MP3/PMP
# 2396     미디어전용라벨
# 3622        태닝티슈
# 4087        여성복지
# 4208         그래픽
# 4209           웹
# Name: title, dtype: object

# %% [markdown]
# <font color="firebrick" size="6"><b>키워드 분석</b></font>

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data = pd.read_csv("conditionedData/data/4_avg_sale.csv")
data.sort_values("avg_sale")
# Out:
#      relative_keyword  total_search  total_store_count  competitive_rate  \
# 816               여과기        9590.0           855785.0             89.24
# 453              호루라기       14700.0           297485.0             20.24
# 231               컵보드         430.0           136965.0            318.52
# 154              대나무발        4170.0           101509.0             24.34
# 101                겨자        7610.0            78640.0             10.33
# 657               보안기         190.0           528207.0           2780.04
# 360               양념장        3060.0           215700.0             70.49
# 238               제빵기        8990.0           138225.0             15.38
# 1333              수납장       80300.0          5688983.0             70.85
# 415                푸딩       25610.0           259249.0             10.12
# 206            고슴도치용품         260.0           125771.0            483.73
# 300             디지털액자        9520.0           174471.0             18.33
# ...
