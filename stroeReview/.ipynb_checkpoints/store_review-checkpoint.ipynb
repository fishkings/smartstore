# %%
import requests
import json

# %%
import requests

shopping_cookies = {
    'NNB': 'BZQEKFFD3ZGWG',
    'ASID': '75100b1e000001840cfb852400000053',
    'NV_WETR_LOCATION_RGN_M': '"MDUxMTAxMTg="',
    'NaverSuggestUse': 'unuse%26use',
    'autocomplete': 'use',
    'NV_WETR_LAST_ACCESS_RGN_M': '"MDUxMTAxMTg="',
    '_ga': 'GA1.1.687219659.1669681140',
    '_ga_K2ECMCJBFQ': 'GS1.1.1686294140.1.0.1686294145.0.0.0',
    '_ga_SQ24F7Q7YW': 'GS1.1.1686294140.1.0.1686294145.0.0.0',
    'SHP_BUCKET_ID': '9',
    'nx_ssl': '2',
    'nid_inf': '817842596',
    'NID_AUT': 'BEIDBXT986GCzggDVdz/yyBv3C1/IgECgIfkmYt5ccWFwXErFV4u3e9loTqeYU3P',
    'NID_JKL': 'KG8H1DNSm6LRAP9EWlbJRNS4gSnyL9kDK6ljPSL4pW8=',
    'NID_SES': '...',
    'page_uid': 'iUsmwwqo1LVssvjC520ssssstlw-520838',
    'spage_uid': 'iUsmwwqo1LVssvjC520ssssstlw-520838',
    'sus_val': '1b6RBD1FZDOomWMxEDN3LEto',
    'ncpa': '95694|lprzjkoo|079082572a94ce3307d7ce5cfa1f98813527a107|95694|db6a4b03a9b918f109a3c9db4ab41365ce293096:3776448|lptga01s|069acf4d4c0848a9f7d3f7eb08f7a7ab611c795a|s_66064036b8ff|bf5bf28a9ec0203926e799e66342acd8ed27cbe1:2425958|lptgd8k8|14b72a5fdf30cbee497146a9fe750836dfa594c1|s_9f074674dd2f|7282ac0e8c8f8b9f7d6c46777e2fa18d5635b45b',
}

shopping_headers = {
    'authority': 'search.shopping.naver.com',
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    # 'cookie': 'NNB=BZQEKFFD3ZGWG; ASID=75100b1e000001840cfb852400000053; NV_WETR_LOCATION_RGN_M="MDUxMTAxMTg="; NaverSuggestUse=unuse%26use; autocomplete=use; NV_WETR_LAST_ACCESS_RGN_M="MDUxMTAxMTg="; _ga=GA1.1.687219659.1669681140; _ga_K2ECMCJBFQ=GS1.1.1686294140.1.0.1686294145.0.0.0; _ga_SQ24F7Q7YW=GS1.1.1686294140.1.0.1686294145.0.0.0; SHP_BUCKET_ID=9; nx_ssl=2; nid_inf=817842596; NID_AUT=BEIDBXT986GCzggDVdz/yyBv3C1/IgECgIfkmYt5ccWFwXErFV4u3e9loTqeYU3P; NID_JKL=KG8H1DNSm6LRAP9EWlbJRNS4gSnyL9kDK6ljPSL4pW8=; NID_SES=...; page_uid=iUsmwwqo1LVssvjC520ssssstlw-520838; spage_uid=iUsmwwqo1LVssvjC520ssssstlw-520838; sus_val=1b6RBD1FZDOomWMxEDN3LEto; ncpa=95694|lprzjkoo|079082572a94ce3307d7ce5cfa1f98813527a107|95694|db6a4b03a9b918f109a3c9db4ab41365ce293096:3776448|lptga01s|069acf4d4c0848a9f7d3f7eb08f7a7ab611c795a|s_66064036b8ff|bf5bf28a9ec0203926e799e66342acd8ed27cbe1:2425958|lptgd8k8|14b72a5fdf30cbee497146a9fe750836dfa594c1|s_9f074674dd2f|7282ac0e8c8f8b9f7d6c46777e2fa18d5635b45b',
    'logic': 'PART',
    'referer': 'https://search.shopping.naver.com/search/all?query=%ED%95%B8%EB%93%9C%ED%8F%B0%EC%BC%80%EC%9D%B4%EC%8A%A4&bt=1&frm=NVSCPRO',
    'sbth': '61ff126fbd21a88b6bace776dd23d34efd87def2d766df5aff1deab09745f670b9df6df189e81e7ad88a80749392c2be',
    'sec-ch-ua': '"Google Chrome";v="119", "Chromium";v="119", "Not?A_Brand";v="24"',
    'sec-ch-ua-arch': '"x86"',
    'sec-ch-ua-bitness': '"64"',
    'sec-ch-ua-full-version-list': '"Google Chrome";v="119.0.6045.202", "Chromium";v="119.0.6045.202", "Not?A_Brand";v="24.0.0.0"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': '""',
    'sec-ch-ua-platform': '"Windows"',
    'sec-ch-ua-platform-version': '"10.0.0"',
    'sec-ch-ua-wow64': '?0',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36',
}

# %%
keyword = "핸드폰케이스"

shopping_params = {
    'adQuery': f'{keyword}',
    'eq': '',
    'frm': 'NVSCPRO',
    'iq': '',
    'origQuery': f'{keyword}',
    'pagingIndex': '1',
    'pagingSize': '40',
    'productSet': 'total',
    'query': f'{keyword}',
    'sort': 'rel',
    'viewType': 'list',
    'xq': '',
}

shopping_response = requests.get('https://search.shopping.naver.com/api/search/all', params=shopping_params, cookies=shopping_cookies, headers=shopping_headers)

# %%
shopping_result = json.loads(shopping_response.text)
products = result["shoppingResult"]["products"]

for product in products :
    print(product["productTitle"])
# Out:
# 갤럭시 Z플립5 케이스 링 카드 수납 힌지 밴드 지플립5
# 아이엠듀 아이폰15 프로 MAX 케이스 이지스 슬림 크리스탈 투명 케이스
# 갤럭시 S23 울트라 맥세이프 케이스 투명 마그네틱
# 갤럭시 Z폴드5 케이스 힌지 보호 마그네틱 슬림 제트폴드5
# 신지모루 갤럭시Z플립3용 투명 슬림 케이스
# 신지모루 갤럭시 A34 케이스 4DX 범퍼강화 TPU 젤리 에어쉴드
# 갤럭시 Z플립5 케이스 투명 클리어 링 제트플립5
# 멕시드 아이폰 15 포스쉴드 카드수납 케이스
# 갤럭시 Z플립5 케이스 카드 수납 힌지보호 링 투명 제트플립5
# 미아크 아이폰 13 프로 MAX 케이스 맥세이프 V2 렌즈보호 풀커버
# 미아크 아이폰 12 프로 MAX 맥세이프 V2 렌즈보호 케이스
# 갤럭시 z플립5케이스 힌지보호 링케이스 슬림 변색없는 투명 하드 제트플립5
# 갤럭시 Z플립3 케이스 자석 힌지 보호 매트
# 신지모루 아이폰 14 프로 에어로핏 슬림 투명 케이스
# 갤럭시 Z플립5 케이스 힌지보호 투명 슬림 생폰
# 신지모루 갤럭시S21용 에어로핏 케이스
# 삼성전자 갤럭시 S23 실리콘케이스 EF-PS911T
# ESR 아이폰15 프로 할로락 클래식 케이스
# 갤럭시 Z플립5 케이스 맥세이프 슬림 하드 생폰 변색없는 제트플립5
# 아이폰14 프로 맥스 케이스 변색없는 투명 슬림 에어제트
# 불사신 투명범퍼케이스 아이폰13 프로 맥스
# 삼성 정품 갤럭시 S23 울트라 케이스 스마트뷰 커버 카드 수납
# 갤럭시 S22 울트라 (S908) 빌란 가죽 핸드폰 지갑 다이어리 케이스
# 갤럭시 Z폴드4 케이스 힌지보호 자석 마그네틱 슬림
# 삼성전자 갤럭시 Z플립5 실리콘 케이스 With 링 EF-PF731
# 방수케이스 + 구명팔찌 물놀이 핸드폰 스마트폰 방수팩 아이폰14 프로 맥스
# 갤럭시 Z폴드5 케이스 GKK 슬림 제트폴드5
# 로랜텍 갤럭시S23맥세이프 케이스 카툭튀 커버
# 갤럭시 Z폴드5 케이스 변색없는 슬림 생폰 하드 투명 폴드5
# ...

# %%
product_cookies = {
    'NNB': 'BZQEKFFD3ZGWG',
    'ASID': '75100b1e000001840cfb852400000053',
    'NV_WETR_LOCATION_RGN_M': '"MDUxMTAxMTg="',
    'NaverSuggestUse': 'unuse%26use',
    'NV_WETR_LAST_ACCESS_RGN_M': '"MDUxMTAxMTg="',
    '_ga': 'GA1.1.687219659.1669681140',
    '_ga_K2ECMCJBFQ': 'GS1.1.1686294140.1.0.1686294145.0.0.0',
    '_ga_SQ24F7Q7YW': 'GS1.1.1686294140.1.0.1686294145.0.0.0',
    'nx_ssl': '2',
    '_fwb': '93q9grDQUebvMRC57RGY3G.1701774255856',
    'nid_inf': '817842596',
    'NID_AUT': 'BEIDBXT986GCzggDVdz/yyBv3C1/IgECgIfkmYt5ccWFwXErFV4u3e9loTqeYU3P',
    'NID_JKL': 'KG8H1DNSm6LRAP9EWlbJRNS4gSnyL9kDK6ljPSL4pW8=',
    '_naver_usersession_': '4od3zcb0O5LWCipxKkmxPA==',
    'NID_SES': '...',
    'page_uid': 'iUsmwwqo1LVssvjC520ssssstlw-520838',
    }

product_headers = {
        'authority': 'smartstore.naver.com',
        'accept': 'application/json, text/plain, */*',
        'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
        'content-type': 'application/json;charset=UTF-8',
        # 'cookie': 'NNB=BZQEKFFD3ZGWG; ASID=75100b1e000001840cfb852400000053; NV_WETR_LOCATION_RGN_M="MDUxMTAxMTg="; NaverSuggestUse=unuse%26use; NV_WETR_LAST_ACCESS_RGN_M="MDUxMTAxMTg="; _ga=GA1.1.687219659.1669681140; _ga_K2ECMCJBFQ=GS1.1.1686294140.1.0.1686294145.0.0.0; _ga_SQ24F7Q7YW=GS1.1.1686294140.1.0.1686294145.0.0.0; nx_ssl=2; _fwb=93q9grDQUebvMRC57RGY3G.1701774255856; nid_inf=817842596; NID_AUT=BEIDBXT986GCzggDVdz/yyBv3C1/IgECgIfkmYt5ccWFwXErFV4u3e9loTqeYU3P; NID_JKL=KG8H1DNSm6LRAP9EWlbJRNS4gSnyL9kDK6ljPSL4pW8=; _naver_usersession_=4od3zcb0O5LWCipxKkmxPA==; NID_SES=...; page_uid=iUsmwwqo1LVssvjC520ssssstlw-520838',
        'origin': 'https://smartstore.naver.com',
        'referer': 'https://smartstore.naver.com/vrsdesign/products/8939105474?n_media=11068&n_query=%ED%95%B8%EB%93%9C%ED%8F%B0%EC%BC%80%EC%9D%B4%EC%8A%A4&n_rank=4&n_ad_group=grp-a001-02-000000039139583&n_ad=nad-a001-02-000000276661482&n_campaign_type=2&n_mall_id=ncp_1o9hqx_01&n_mall_pid=8939105474&n_ad_group_type=2&n_match=3&NaPm=ct%3Dlptg2b1k%7Cci%3D0za0003f8l1zCwmJyfkp%7Ctr%3Dpla%7Chk%3D27f494023fd38325fe40f1e45ad8ca3b7d458f9e',
        'sec-ch-ua': '"Google Chrome";v="119", "Chromium";v="119", "Not?A_Brand";v="24"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36',
    }

# %%
shopping_result = json.loads(shopping_response.text)
products = result["shoppingResult"]["products"]
cnt = 0 

for idx,product in enumerate(products):
    mallProdMblUrl =  product["mallProdMblUrl"]
    MerchantNo =  product["chnlSeq"]
    originProductNo =  product["originalMallProductId"]
    
    print(f"{idx+1} {mallProdMblUrl} {MerchantNo} {originProductNo}")
    
   
    json_data = {
    'checkoutMerchantNo': MerchantNo,
    'originProductNo': originProductNo,
    'page': 1,
    'pageSize': 20,
    'reviewSearchSortType': 'REVIEW_RANKING',
    }

    product_response = requests.post(
        'https://smartstore.naver.com/i/v1/contents/reviews/query-pages',
        cookies=product_cookies,
        headers=product_headers,
        json=json_data,
    )
    
    try:
        print(product_response)
#         data = json.loads(product_response.text)
#         for content in data["contents"]:
#             print(content["reviewContent"])
#             print("----------------------------------------")
#             cnt += 1
    except:
        pass
print(cnt)
# Out:
# 1 https://m.smartstore.naver.com/main/products/8912303336 101048640 8870284159
# <Response [204]>
# 2
# <Response [204]>
# 3 https://m.smartstore.naver.com/main/products/9178002888 500112679 9134938605
# <Response [200]>
# 4 https://m.smartstore.naver.com/main/products/8979188288 500112679 8936898831
# <Response [200]>
# 5
# <Response [204]>
# 6
# <Response [204]>
# 7 https://m.smartstore.naver.com/main/products/8939468222 500112679 8897328575
# <Response [200]>
# 8
# <Response [204]>
# 9 https://m.smartstore.naver.com/main/products/9390518876 100816720 9346454070
# <Response [204]>
# 10
# <Response [204]>
# 11
# <Response [204]>
# 12 https://m.smartstore.naver.com/main/products/9019819979 100675389 8977398505
# <Response [204]>
# 13 https://m.smartstore.naver.com/main/products/7630861846 500112679 7593956994
# <Response [200]>
# 14
# <Response [204]>
# 15 https://m.smartstore.naver.com/main/products/9242563318 500229383 9199221556
# <Response [200]>
# 16
# <Response [204]>
# 17
# ...

# %%
for content in data["contents"]:
    print(content["reviewContent"])
    print("----------------------------------------")
# Out:
# 떨어뜨렷더니 액정보호 유리 파이고 힌지 보호커버 깨먹어서 추가주문합니다.
# 기존에 일반 젤리케이스 써보고 정품 슬림펜케이스 써봤는데 의미없더라구요. 얘가 보호해줫다 생각드니까 폰도 멀쩡하고 만족스럽네요. 보호력은 증명됬고 스탠딩 서포트도 단계별로 조절되고 디자인이나 그립감도, 가격조 다 맘에들어서 추가주문 안할 이유가 없더라구요. 추천합니다
# ----------------------------------------
# 정품 커버 못지않게 퀄리티가 아주 좋네요
# 들뜸없이 딱 맞아요
# 색상은 다크그레이인데 아주 밝지도 어둡지도 않은 고급진 색상이며 매트한 표면이라 지문도 묻지않아 깔끔한 관리가 가능하네요
# 동영상 볼때 화면을 완전히 편채로 세워서 볼수 있어서 마음에 쏙 드네요
# ----------------------------------------
# 힌지보호 좋아요
# 전면 풀커버 좋아요
# 무선충전 잘돼요
# 이격이나 벌어짐 없어요
# 완전 좋아요
#
# 전면커버 때문에 터치감이 살짝 아쉬워요
# 그래도 좋아요
# ----------------------------------------
# 현장일 하는데 아주 이만한 케이스가 없는거같아요
# 실버 블랙 구매해서 블랙은 아버지드리고 실버쓰다가 하단이 아주 작살이나서 앞케이스가 자꾸 빠지는 바람에 블랙으로 하나더 구매 합니다
# 역시 블랙이 실버보다 깔끔하고 고급져보여요
# ----------------------------------------
# 그린색 너무 이뻐요
# 배송도 빠르고요 손때 걱정안해도
# 될거 같아요 힌지부분 맘에 딱 들어요
# 구매 강추합니다
# ----------------------------------------
# (남편에게 케이스 선물했습니다!)
# 앞쪽 투명 커버 쪽 액정 터치가 아쉽다고 하네요!
# 나머지 보호되는 부분이나 디자인은
# 아주 마음에 든다고 합니다!😆
# ----------------------------------------
# 한달후기씁니다
# ...

# %%
mallProdMblUrl = ""

cookies = {
    'NNB': 'BZQEKFFD3ZGWG',
    'ASID': '75100b1e000001840cfb852400000053',
    'NV_WETR_LOCATION_RGN_M': '"MDUxMTAxMTg="',
    'NaverSuggestUse': 'unuse%26use',
    'NV_WETR_LAST_ACCESS_RGN_M': '"MDUxMTAxMTg="',
    '_ga': 'GA1.1.687219659.1669681140',
    '_ga_K2ECMCJBFQ': 'GS1.1.1686294140.1.0.1686294145.0.0.0',
    '_ga_SQ24F7Q7YW': 'GS1.1.1686294140.1.0.1686294145.0.0.0',
    'nx_ssl': '2',
    '_fwb': '93q9grDQUebvMRC57RGY3G.1701774255856',
    'nid_inf': '817842596',
    'NID_AUT': 'BEIDBXT986GCzggDVdz/yyBv3C1/IgECgIfkmYt5ccWFwXErFV4u3e9loTqeYU3P',
    'NID_JKL': 'KG8H1DNSm6LRAP9EWlbJRNS4gSnyL9kDK6ljPSL4pW8=',
    '_naver_usersession_': '4od3zcb0O5LWCipxKkmxPA==',
    'NID_SES': '...',
    'page_uid': 'iUsmwwqo1LVssvjC520ssssstlw-520838',
}

headers = {
    'authority': 'smartstore.naver.com',
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    'content-type': 'application/json;charset=UTF-8',
    # 'cookie': 'NNB=BZQEKFFD3ZGWG; ASID=75100b1e000001840cfb852400000053; NV_WETR_LOCATION_RGN_M="MDUxMTAxMTg="; NaverSuggestUse=unuse%26use; NV_WETR_LAST_ACCESS_RGN_M="MDUxMTAxMTg="; _ga=GA1.1.687219659.1669681140; _ga_K2ECMCJBFQ=GS1.1.1686294140.1.0.1686294145.0.0.0; _ga_SQ24F7Q7YW=GS1.1.1686294140.1.0.1686294145.0.0.0; nx_ssl=2; _fwb=93q9grDQUebvMRC57RGY3G.1701774255856; nid_inf=817842596; NID_AUT=BEIDBXT986GCzggDVdz/yyBv3C1/IgECgIfkmYt5ccWFwXErFV4u3e9loTqeYU3P; NID_JKL=KG8H1DNSm6LRAP9EWlbJRNS4gSnyL9kDK6ljPSL4pW8=; _naver_usersession_=4od3zcb0O5LWCipxKkmxPA==; NID_SES=...; page_uid=iUsmwwqo1LVssvjC520ssssstlw-520838',
    'origin': 'https://smartstore.naver.com',
    'referer': 'https://smartstore.naver.com/vrsdesign/products/8939105474?n_media=11068&n_query=%ED%95%B8%EB%93%9C%ED%8F%B0%EC%BC%80%EC%9D%B4%EC%8A%A4&n_rank=4&n_ad_group=grp-a001-02-000000039139583&n_ad=nad-a001-02-000000276661482&n_campaign_type=2&n_mall_id=ncp_1o9hqx_01&n_mall_pid=8939105474&n_ad_group_type=2&n_match=3&NaPm=ct%3Dlptg2b1k%7Cci%3D0za0003f8l1zCwmJyfkp%7Ctr%3Dpla%7Chk%3D27f494023fd38325fe40f1e45ad8ca3b7d458f9e',
    'sec-ch-ua': '"Google Chrome";v="119", "Chromium";v="119", "Not?A_Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36',
}

# %%
MerchantNo =  ""
originProductNo =  ""

json_data = {
    'checkoutMerchantNo': MerchantNo,
    'originProductNo': originProductNo,
    'page': 1,
    'pageSize': 20,
    'reviewSearchSortType': 'REVIEW_RANKING',
}

response = requests.post(
    'https://smartstore.naver.com/i/v1/contents/reviews/query-pages',
    cookies=cookies,
    headers=headers,
    json=json_data,
)

# %%
response.text
# Out:
# '{"contents":[{"id":4378340431,"reviewType":"AFTER_USE","reviewServiceType":"SELLBLOG","reviewContentClassType":"PHOTO","reviewScore":5,"reviewContent":"잘쓰고있어요 감사합니다","contentsStatusType":"NORMAL","createDate":"2023-11-28T10:10:34.524+00:00","freeTrial":false,"repurchase":false,"parentReviewId":4356487965,"reviewRankingScore":-67.130356,"writerId":"hllc*****","maskedWriterId":"hllc*****","writerIdNo":"","writerMemberNo":0,"writerProfileImageUrl":"https://profile-phinf.pstatic.net/404/default.png","storeType":"STOREFARM","storeNo":101299699,"checkoutMerchantId":"","checkoutMerchantNo":0,"orderNo":"","productOrderNo":"2023102180681351","productNo":"8939105474","productName":"베루스 갤럭시 폴드5 케이스 Z 폴드5 케이스 자동 힌지보호 모던 비스포크","productUrl":"https://smartstore.naver.com/main/products/8939105474","largeCategorizeCategoryId":"50000003","middleCategorizeCategoryId":"50000205","smallCategorizeCategoryId":"50001377","detailCategorizeCategoryId":"50004594","productOptionContentNoDisplay":false,"product
# ...

# %%
import requests

cookies = {
    'NNB': 'BZQEKFFD3ZGWG',
    'ASID': '75100b1e000001840cfb852400000053',
    'NV_WETR_LOCATION_RGN_M': '"MDUxMTAxMTg="',
    'NaverSuggestUse': 'unuse%26use',
    'NV_WETR_LAST_ACCESS_RGN_M': '"MDUxMTAxMTg="',
    '_ga': 'GA1.1.687219659.1669681140',
    '_ga_K2ECMCJBFQ': 'GS1.1.1686294140.1.0.1686294145.0.0.0',
    '_ga_SQ24F7Q7YW': 'GS1.1.1686294140.1.0.1686294145.0.0.0',
    'nx_ssl': '2',
    '_fwb': '93q9grDQUebvMRC57RGY3G.1701774255856',
    'nid_inf': '817842596',
    'NID_AUT': 'BEIDBXT986GCzggDVdz/yyBv3C1/IgECgIfkmYt5ccWFwXErFV4u3e9loTqeYU3P',
    'NID_JKL': 'KG8H1DNSm6LRAP9EWlbJRNS4gSnyL9kDK6ljPSL4pW8=',
    'NID_SES': '...',
    'page_uid': 'iUsmwwqo1LVssvjC520ssssstlw-520838',
}

headers = {
    'authority': 'smartstore.naver.com',
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    'content-type': 'application/json;charset=UTF-8',
    # 'cookie': 'NNB=BZQEKFFD3ZGWG; ASID=75100b1e000001840cfb852400000053; NV_WETR_LOCATION_RGN_M="MDUxMTAxMTg="; NaverSuggestUse=unuse%26use; NV_WETR_LAST_ACCESS_RGN_M="MDUxMTAxMTg="; _ga=GA1.1.687219659.1669681140; _ga_K2ECMCJBFQ=GS1.1.1686294140.1.0.1686294145.0.0.0; _ga_SQ24F7Q7YW=GS1.1.1686294140.1.0.1686294145.0.0.0; nx_ssl=2; _fwb=93q9grDQUebvMRC57RGY3G.1701774255856; nid_inf=817842596; NID_AUT=BEIDBXT986GCzggDVdz/yyBv3C1/IgECgIfkmYt5ccWFwXErFV4u3e9loTqeYU3P; NID_JKL=KG8H1DNSm6LRAP9EWlbJRNS4gSnyL9kDK6ljPSL4pW8=; NID_SES=...; page_uid=iUsmwwqo1LVssvjC520ssssstlw-520838',
    'origin': 'https://smartstore.naver.com',
    'referer': 'https://smartstore.naver.com/i-mall/products/9178002888',
    'sec-ch-ua': '"Google Chrome";v="119", "Chromium";v="119", "Not?A_Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36',
}

json_data = {
    'checkoutMerchantNo': 500112679,
    'originProductNo': 9134938605,
    'page': 1,
    'pageSize': 20,
    'reviewSearchSortType': 'REVIEW_RANKING',
}

response = requests.post(
    'https://smartstore.naver.com/i/v1/contents/reviews/query-pages',
    cookies=cookies,
    headers=headers,
    json=json_data,
)

# Note: json_data will not be serialized by requests
# exactly as it was in the original request.
#data = '{"checkoutMerchantNo":500112679,"originProductNo":9134938605,"page":1,"pageSize":20,"reviewSearchSortType":"REVIEW_RANKING"}'
#response = requests.post(
#    'https://smartstore.naver.com/i/v1/contents/reviews/query-pages',
#    cookies=cookies,
#    headers=headers,
#    data=data,
#)
