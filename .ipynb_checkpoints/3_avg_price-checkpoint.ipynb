# %% [markdown]
# # 키워드 평균 가격 구하기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup
import requests
import time

# %%
data = pd.read_csv("data/category/sorted_total_store0.csv")
keywords = data["relative_keyword"]

# %%
data
# Out:
#      relative_keyword  total_search  total_store_count  competitive_rate
# 0                 제모제        1250.0            50115.0             40.09
# 1              유아세탁세제        1410.0            50365.0             35.72
# 2              기저귀휴지통        3200.0            50428.0             15.76
# 3                 카테킨       12470.0            50519.0              4.05
# 4                파우더통        1500.0            50724.0             33.82
# ...               ...           ...                ...               ...
# 1607               잡화        4600.0        240755648.0          52338.18
# 1608               의류        5360.0        266761395.0          49768.92
# 1609               여성        6830.0        273371280.0          40025.08
# 1610               패션       20730.0        423405866.0          20424.79
# 1611               생활        4650.0        467694995.0         100579.57
#
# [1612 rows x 4 columns]

# %%
keywords
# Out:
# 0          제모제
# 1       유아세탁세제
# 2       기저귀휴지통
# 3          카테킨
# 4         파우더통
#          ...
# 1607        잡화
# 1608        의류
# 1609        여성
# 1610        패션
# 1611        생활
# Name: relative_keyword, Length: 1612, dtype: object

# %% [markdown]
# **이상치 처리**

# %%
# 사분위수
def get_outlier(price_arr, weight=1.5):
  # target 값과 상관관계가 높은 열을 우선적으로 진행
    quantile_25 = np.percentile(price_arr, 25)
    quantile_75 = np.percentile(price_arr, 75)

    IQR = quantile_75 - quantile_25
    IQR_weight = IQR*weight
  
    lowest = quantile_25 - IQR_weight
    highest = quantile_75 + IQR_weight
  
    excluded_prices = price_arr[(price_arr < lowest) | (price_arr > highest)]
    price_arr = price_arr[(price_arr >=lowest) & (price_arr <= highest)]
    
    return price_arr,excluded_prices

# Z-score
def outlier_remove_z(data, threshold=3):
    z_scores = np.abs(data - np.mean(data)) / np.std(data) # Z-score 계산
    outlier = data[z_scores>threshold]
    removed_data = data[z_scores < threshold]
    
    return removed_data, outlier

# %%
import requests
import json

avg_price = []

for keyword in keywords:
    cookies = {
        'NNB': '6TTK2RJU3JPWG',
        'autocomplete': 'use',
        'AD_SHP_BID': '23',
        '_ga': 'GA1.2.1198469368.1669035888',
        'NV_WETR_LOCATION_RGN_M': '"MDUxMTAxMTE="',
        'ASID': '6f5bbfa400000184fa368e5f00000067',
        'SHP_BUCKET_ID': '4',
        'NV_WETR_LAST_ACCESS_RGN_M': '"MDUxMTAxMTE="',
        'NID_AUT': 'xDAIttoc1Atdn7rAs4Y+rogecRjh3p1xevXbJnm0Nr0CEioRQ5/hhmRFwExAG7+T',
        'NID_JKL': 'b+0nlz0gwdbCoxClpc3utji+0en89OQHe0BEDbaUv/Y=',
        'nx_ssl': '2',
        'Viking_Rise_visit_time': '1695077035991',
        'page_uid': 'ifYbMdprvTVsse385PlssssssE0-160453',
        'spage_uid': 'ifYbMdprvTVsse385PlssssssE0-160453',
        'NID_SES': '...',
        'sus_val': 'oosk3W1yUa/jXC7KKHHcV8KC',
        'ncpa': '5114254|lnq2oiag|6088f8339ff87318d5466310aa33bd3df5f4ee8e|s_21a15037d5896|4a037b7e1ad4f4b2b46b7552bf557d83d6e09c69:4801924|lnq2r5yw|252c45b5b1c89d88d92fb4fd42bf99065652c3d4|s_1aec08c8356c9|4a0769694c3e60ffa7b878ff1e700b5ee7a31a93:95694|lnq2t46o|8f47110d725d91bc72e3083c0376c78965d77ffe|95694|28deee716df4986a1bc2f535eccb8e15165491ff:114|lnrg1u34|6c1e428c1fdcf6109a6e368afd36c2c6547842b5|s_1f0b6dd34481|0d9a8a153a4fd6f9e60247ee72a897423e0d11c7',
    }

    headers = {
        'authority': 'search.shopping.naver.com',
        'accept': 'application/json, text/plain, */*',
        'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
        # 'cookie': 'NNB=6TTK2RJU3JPWG; autocomplete=use; AD_SHP_BID=23; _ga=GA1.2.1198469368.1669035888; NV_WETR_LOCATION_RGN_M="MDUxMTAxMTE="; ASID=6f5bbfa400000184fa368e5f00000067; SHP_BUCKET_ID=4; NV_WETR_LAST_ACCESS_RGN_M="MDUxMTAxMTE="; NID_AUT=xDAIttoc1Atdn7rAs4Y+rogecRjh3p1xevXbJnm0Nr0CEioRQ5/hhmRFwExAG7+T; NID_JKL=b+0nlz0gwdbCoxClpc3utji+0en89OQHe0BEDbaUv/Y=; nx_ssl=2; Viking_Rise_visit_time=1695077035991; page_uid=ifYbMdprvTVsse385PlssssssE0-160453; spage_uid=ifYbMdprvTVsse385PlssssssE0-160453; NID_SES=...; sus_val=oosk3W1yUa/jXC7KKHHcV8KC; ncpa=5114254|lnq2oiag|6088f8339ff87318d5466310aa33bd3df5f4ee8e|s_21a15037d5896|4a037b7e1ad4f4b2b46b7552bf557d83d6e09c69:4801924|lnq2r5yw|252c45b5b1c89d88d92fb4fd42bf99065652c3d4|s_1aec08c8356c9|4a0769694c3e60ffa7b878ff1e700b5ee7a31a93:95694|lnq2t46o|8f47110d725d91bc72e3083c0376c78965d77ffe|95694|28deee716df4986a1bc2f535eccb8e15165491ff:114|lnrg1u34|6c1e428c1fdcf6109a6e368afd36c2c6547842b5|s_1f0b6dd34481|0d9a8a153a4fd6f9e60247ee72a897423e0d11c7',
        'logic': 'PART',
        'referer': 'https://search.shopping.naver.com/search/all?frm=NVSCPRO&origQuery&pagingSize=80&&productSet=total&query=%EC%84%B8%EC%A0%9C&sort=rel&timestamp=&viewType=list',
        'sbth': 'd222b49238bd2b7f29803e2ed2f08d01eedaa3d14d24417197e36287d8d5eae0ca4c01288a05847bfed167eb56487188',
        'sec-ch-ua': '"Chromium";v="118", "Google Chrome";v="118", "Not=A?Brand";v="99"',
        'sec-ch-ua-arch': '"x86"',
        'sec-ch-ua-bitness': '"64"',
        'sec-ch-ua-full-version-list': '"Chromium";v="118.0.5993.70", "Google Chrome";v="118.0.5993.70", "Not=A?Brand";v="99.0.0.0"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-model': '""',
        'sec-ch-ua-platform': '"Windows"',
        'sec-ch-ua-platform-version': '"15.0.0"',
        'sec-ch-ua-wow64': '?0',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36',
    }

    params = {
        'frm': 'NVSCPRO',
        'pagingIndex': '1',
        'pagingSize': '100',
        'productSet': 'total',
        'query': f"{keyword}",
        'sort': 'rel',
        'viewType': 'list',
    }

    response = requests.get('https://search.shopping.naver.com/api/search/all', params=params, cookies=cookies, headers=headers)
    itemlist = json.loads(response.text)
    
    price_lst = []
    for idx,i in enumerate(itemlist['shoppingResult']['products']):
        price = i['price'],
        price =  int(price[0])
        price_lst.append(price)

    # 이상치 처리
    price_arr = np.array(price_lst)
    removed_arr,excluded_prices = get_outlier(price_arr, weight=1.5)
    print(f"{keyword} \t {int(removed_arr.mean())} \t {removed_arr.shape[0]} ")
    print(f"이상치 제거 {excluded_prices}\n")
    avg_price.append(int(removed_arr.mean()))
# Out:
# 제모제 	 15649 	 98
# 이상치 제거 [46000 57000]
#
# 유아세탁세제 	 19351 	 97
# 이상치 제거 [47900 71800 46900]
#
# 기저귀휴지통 	 32578 	 94
# 이상치 제거 [128000  89900 129000 113800  96180  87000]
#
# 카테킨 	 27531 	 96
# 이상치 제거 [ 88000 178800 166680 165000]
#
# 파우더통 	 8217 	 91
# 이상치 제거 [27300 34570 26900 26400 33130 58690 25500 76000 20620]
#
# 코인티슈 	 14845 	 94
# 이상치 제거 [160000 154000  89700  42500 100600 200000]
#
# 업소용냉온풍기 	 1080058 	 98
# 이상치 제거 [2440000 2730000]
#
# 혈당계 	 45070 	 91
# 이상치 제거 [ 196840  209000  276000  276000  249000 1943600  254690  202400  300000]
#
# 시서스 	 59928 	 97
# 이상치 제거 [329000 217160 220000]
#
# 휘핑크림 	 6612 	 89
# 이상치 제거 [ 23190  43000  74400  18950  76600  20970  51750  17670  44870  36900
#  109200]
#
# 동치미 	 19032 	 99
# 이상치 제거 [42680]
#
# 임산부보호대 	 9084 	 94
# 이상치 제거 [50900 29800 66000 42770 24870 36980]
#
# 볼링의류 	 38337 	 98
# 이상치 제거 [495800 900147]
#
# 속눈썹영양제 	 26876 	 92
# 이상치 제거 [ 77000 112000 192000  78000 100000  92000  95900 149000]
#
# 황도 	 5077 	 88
# 이상치 제거 [27000 30700 35980 49680 28680 23990 24150 30000 31500 36750 33320 42000]
#
# 필오프팩 	 19605 	 90
# 이상치 제거 [69000 98000 73000 69000 93100 55000 99000 98000 98000 99000]
#
# 유아비누 	 10571 	 97
# 이상치 제거 [35600 48000 33000]
#
# 천연감미료 	 8686 	 90
# 이상치 제거 [ 25730  22900  26500  35000 129800  26500  39800  25730  22000  23500]
#
# 샤워코롱 	 9317 	 98
# 이상치 제거 [35000 67830]
#
# 혈당측정지 	 18454 	 97
# 이상치 제거 [60000 62470 50990]
#
# 백신 	 25690 	 82
# 이상치 제거 [ 459900  579900  199000 3360000  150000  850000  647300 1460000 1296000
#   486000 2975500  882700  530000  140010  125750  469230  335610  430760]
#
# 배구네트 	 155269 	 91
# 이상치 제거 [1964000 1926400 1587520 1422960 1609270  656600  605000 2433900 1197800]
#
# 발싸개 	 6638 	 100
# 이상치 제거 []
#
# 체온계 	 45703 	 100
# 이상치 제거 []
#
# 전기매트커버 	 25132 	 93
# 이상치 제거 [222400  60000 230400  64900  70000  64900 169000]
#
# 포도씨유 	 17097 	 96
# 이상치 제거 [102320 110110  56330  55390]
#
# 파벽돌 	 20321 	 94
# 이상치 제거 [107710 231000  78600  80350  92000 103540]
#
# 임산부바디필로우 	 53294 	 97
# 이상치 제거 [139000 136390 133300]
#
# 수유쿠션 	 52703 	 100
# 이상치 제거 []
#
# 곤 	 22783 	 94
# 이상치 제거 [102200 107705  83005  95030  85930  84110]
#
# 발사믹드레싱 	 8330 	 94
# 이상치 제거 [102250  34500  27500  35000  44900  27500]
#
# 헤어젤 	 6604 	 94
# 이상치 제거 [28000 28152 27900 28000 24000 32300]
#
# 아기띠 	 114675 	 97
# 이상치 제거 [324000 563000 341990]
#
# 유아오일 	 18602 	 94
# 이상치 제거 [68400 76000 68400 68500 68400 75000]
#
# 선스프레이 	 15030 	 92
# 이상치 제거 [ 50000  49900 220000  42550 159100 117020  59900  49700]
#
# 국어 	 12610 	 92
# 이상치 제거 [24670 26170 21280 44820 24300 28780 26230 26100]
#
# 기저귀정리함 	 28733 	 93
# 이상치 제거 [ 97900 100720  73870  82900  71320  72600  95030]
#
# 비즈발 	 42254 	 94
# 이상치 제거 [161080 338850 177890 322750 137640 166910]
#
# 장조림 	 11186 	 97
# 이상치 제거 [38900 42750 40740]
#
# 문예 	 32432 	 88
# 이상치 제거 [179700 131410 106910  96050 100310  96490  87200  97730  87200  86760
#  217670  91620]
#
# 치석제거기 	 15427 	 93
# 이상치 제거 [ 89000  89000 129000  68800  68800  69700  69200]
#
# 음식물처리기 	 505439 	 100
# 이상치 제거 []
#
# 야구보호대 	 40310 	 96
# 이상치 제거 [168210 220500 131430 154310]
#
# 레몬밤 	 13553 	 87
# 이상치 제거 [ 42900  79100  60000 115080  49459  53350 109900  36900  44460  47520
#   44840  49500  44300]
#
# 테마여행 	 19729 	 91
# 이상치 제거 [134830 150000 229000 113100  75000 119970  85000  73000  80000]
#
# 시간관리 	 6260 	 99
# 이상치 제거 [29880]
#
# 승마운동기 	 648221 	 95
# 이상치 제거 [2856000 3096330 3318000 2835000 3570690]
#
# SKT 	 478657 	 97
# 이상치 제거 [1778480 1733300 1832300]
#
# 개발툴 	 81882 	 90
# 이상치 제거 [ 798400  821700 1284200  481600  814000  509500  546700 1040510 1063530
#   584600]
#
# 통장지갑 	 7130 	 99
# 이상치 제거 [39800]
#
# 좌욕기 	 53307 	 96
# 이상치 제거 [ 649000  286000 1199700  604500]
#
# 선파우더 	 15882 	 93
# 이상치 제거 [55990 38610 79900 38900 89280 39900 99000]
#
# 거꾸리 	 210064 	 92
# 이상치 제거 [1579190  740000 1428600 1090000 1455000  943740  826600 1087110]
#
# 케틀벨 	 23436 	 88
# 이상치 제거 [169000 135000  99850 112000 138000 184500 224000 165100  82800 112000
#  204000 186380]
#
# 청진기 	 37659 	 88
# 이상치 제거 [229620 283800 229560 369800 385000 292500 282380 349780 300340 450000
#  219240 314000]
#
# 국내분유 	 25611 	 91
# 이상치 제거 [ 75000 109900 118900  79900  89000  67470 118800  75400  79800]
#
# 함박 	 14395 	 95
# 이상치 제거 [45810 48970 50900 54190 49600]
#
# 어린이영어 	 43416 	 95
# 이상치 제거 [176400 229000 197600 173050 210000]
#
# 머스타드소스 	 6852 	 94
# 이상치 제거 [38000 42500 37900 22500 47000 36040]
#
# 욕창방지용품 	 47176 	 93
# 이상치 제거 [ 250000  488970 1100000  212770  549850  239400  305490]
#
# 죽제조기 	 87822 	 94
# 이상치 제거 [380040 256800 282270 254900 427900 300000]
#
# 클렌징로션 	 28223 	 95
# 이상치 제거 [106900  90000  92150  83800  80600]
#
# 얼룩제거제 	 9448 	 82
# 이상치 제거 [31000 19500 19700  1040  1000 22300 23500 18900   790 20900  1000 19700
#  19900 18800 44650 22120   890   930]
#
# 하이패스 	 52654 	 96
# 이상치 제거 [320000 130000 230000 150000]
#
# 의류관리기 	 1066120 	 100
# 이상치 제거 []
#
# 미트볼 	 7107 	 87
# 이상치 제거 [ 25900  26400 130000  39810  39810  39810  50400  39810  39810  50400
#   36900  71700  26200]
#
# 게살 	 8082 	 95
# 이상치 제거 [23280 57810 38710 41390 56570]
#
# DVD장 	 55765 	 94
# 이상치 제거 [ 201970  259550  198300  440430  480980 1126760]
#
# 립앤아이리무버 	 8327 	 92
# 이상치 제거 [24500 32400 37360 29970 25000 24870 86490 31000]
#
# 바베큐소스 	 13525 	 85
# 이상치 제거 [   60000    50000    60500    49000    77100    65800    74950    52600
#  16416300    82080   159000    53800    86700    67850   122000]
#
# 전병 	 9897 	 86
# 이상치 제거 [65000 40000 36710 35000 28000 33130 40000 62700 29900 33920 55000 33120
#  30600 54450]
#
# 톤업크림 	 17263 	 95
# 이상치 제거 [55100 68900 77786 72000 45000]
#
# 메주 	 16832 	 88
# 이상치 제거 [ 51000  99750  65000 100000  73880 115000  49900 110710 115000  77310
#   80000 115000]
#
# 커피자판기 	 1734018 	 86
# 이상치 제거 [12000000 13500000 39000000 22000000 20600000 15000000 15000000 13200000
#  75000000 35000000 17500000 17960310 13000000 19800000]
#
# 볼링가방 	 98257 	 98
# 이상치 제거 [819003 736164]
#
# 딤섬 	 10411 	 91
# 이상치 제거 [ 33600  32010  35810 117350  44300  31200  48000  39920  31970]
#
# 혀클리너 	 7852 	 96
# 이상치 제거 [27400 25600 49500 54390]
#
# 스쿼시라켓 	 143789 	 100
# 이상치 제거 []
#
# 금연용품 	 17357 	 91
# 이상치 제거 [124000  98900 124000  99000 136000 124000 398000 495000  80000]
#
# 부츠키퍼 	 3958 	 88
# 이상치 제거 [25800 15900 19900 29800 18800 71100 37900 29900 22800 15600 14240 31600]
#
# 보이스레코더 	 89077 	 94
# 이상치 제거 [548000 307000 342000 569050 418000 498000]
#
# 작전판 	 32633 	 94
# 이상치 제거 [112560 139310 107690 273730 222860 179520]
#
# 쌈장 	 12681 	 99
# 이상치 제거 [71400]
#
# 쿠션안마기 	 31314 	 85
# 이상치 제거 [128970 268000 109980 120040  99000 112590 299000 116500  84400  68300
#   85000  70950  68070 158400  79000]
#
# 발냄새제거제 	 10673 	 89
# 이상치 제거 [29800 28900 45000 45000 29130 59000 31680 31950 31800 29120 77600]
#
# 유아목욕가운 	 23998 	 97
# 이상치 제거 [62790 62790 52040]
#
# 에어커튼 	 240980 	 84
# 이상치 제거 [  5000 657450 604200  15000 489720   9000 685720 493570 529298  13000
#  565026   2900 489720  16100  10000   8500]
#
# 석션기 	 152531 	 94
# 이상치 제거 [1650000 1150000 1159680  786500  733340  789600]
#
# 손소독기 	 64297 	 87
# 이상치 제거 [ 258860  719760  385000  279370  368500  368400  352000  590898 1800000
#  4180000  829000  432000  330000]
#
# 판화용품 	 13666 	 83
# 이상치 제거 [105970 224450 260650 117460 185890 300000 473810 109100 217170 763920
#  237170 446160 245790 271970 115420 125600 424800]
#
# 수산가공식품 	 18981 	 98
# 이상치 제거 [60000 76200]
#
# 키재기 	 12100 	 95
# 이상치 제거 [ 99000 157470  49400 108410  48600]
#
# 번역 	 184503 	 95
# 이상치 제거 [ 634800 1025200 1128000 1459790  790900]
#
# 요이불세트 	 81933 	 96
# 이상치 제거 [511500 598000 200880 842000]
#
# 화과자 	 32577 	 95
# 이상치 제거 [102600 103500 135170 123670 177500]
#
# 세탁솔 	 2405 	 95
# 이상치 제거 [18770 32780  9220 15070 21950]
#
# 흔들침대 	 117228 	 96
# 이상치 제거 [499000 397000 532530 318750]
#
# 골뱅이 	 17755 	 86
# 이상치 제거 [109000  56800  56100 189000 136800 104000  94700 180000 223000 183000
#  104000 150400 104000 201600]
#
# 혼합곡 	 13442 	 95
# 이상치 제거 [41900 39900 43900 54500 40740]
#
# 청국장 	 14037 	 90
# 이상치 제거 [46665 50890 47630 41800 47390 38170 45680 43200 46000 39900]
#
# 수유복 	 22667 	 100
# 이상치 제거 []
#
# 소설 	 10292 	 99
# 이상치 제거 [83730]
#
# 유아욕조 	 35357 	 95
# 이상치 제거 [191000 100230 109000 108000 106010]
#
# 허브식물 	 5537 	 96
# 이상치 제거 [24000 26000 19000 36000]
#
# 의학 	 78476 	 93
# 이상치 제거 [287600 836000 638800 566570 566570 310420 489330]
#
# 세일즈 	 21030 	 82
# 이상치 제거 [ 692200  572400  786000  772000  640000  572400  772000  339700  133560
#   114300  935900  168300  121000 1210000  137500   99710  242800  243100]
#
# 마요네즈 	 7697 	 94
# 이상치 제거 [35820 35800 45480 44800 42990 51980]
#
# 겨자 	 4447 	 83
# 이상치 제거 [ 18470  16870  22300  22400  21550  19800  74300 174000 141460  55500
#   25600 104016  18900  16900  22600  46340  21810]
# 어학 	 202974 	 99
# 이상치 제거 [3336000]
#
# 운영체제 	 145063 	 92
# 이상치 제거 [1450000 1337100  499000 1024960  611420  498130 4237380  589970]
#
# 족탕기 	 47473 	 95
# 이상치 제거 [195000 251880 384590 442160 198590]
#
# 콩가루 	 8710 	 96
# 이상치 제거 [22000 41700 63000 43980]
#
# 벨트마사지 	 168642 	 99
# 이상치 제거 [718020]
#
# 유아치약 	 8635 	 95
# 이상치 제거 [27200 30170 27200 30170 54680]
#
# 업소용자외선소독기 	 1410210 	 96
# 이상치 제거 [15732640  8376060 13530440  8024940]
#
# 콘센트안전커버 	 1635 	 87
# 이상치 제거 [11000 10200  6800  5380  7000  7149  5500  5520  7270  5781  5370  8021
#   5350]
#
# 볼링화 	 116510 	 100
# 이상치 제거 []
#
# 실커튼 	 22302 	 93
# 이상치 제거 [63080 64570 56970 66240 63000 61700 82500]
#
# 카팩 	 27819 	 97
# 이상치 제거 [179990  54500  69000]
#
# 물엿 	 12399 	 91
# 이상치 제거 [ 70000  35000  70000  60000  35000  35000  37500 105000  35000]
#
# 네일영양제 	 20088 	 99
# 이상치 제거 [64900]
#
# 카놀라유 	 9333 	 88
# 이상치 제거 [52950 54800 57660 61000 59000 58600 63900 58650 67500 58000 53460 57900]
#
# 전자책 	 166975 	 94
# 이상치 제거 [ 679000  559000 1145000  739000  596900  538000]
#
# 파마약 	 7830 	 95
# 이상치 제거 [64900 38440 69000 75000 59700]
#
# 제빵믹스 	 11739 	 100
# 이상치 제거 []
#
# 속싸개 	 28197 	 91
# 이상치 제거 [ 85800  75800  99000  85000  99000 121270  75800 146140  78800]
#
# 핫소스 	 8504 	 93
# 이상치 제거 [55360 36410 32400 48690 29450 32000 36640]
#
# 무선모뎀 	 71556 	 88
# 이상치 제거 [ 391900 3300000  449660  273330 1426500  358360  299350  449660  325130
#   444170  339300  284800]
#
# 탁구대 	 417539 	 96
# 이상치 제거 [ 4950000  3300000 13242070  2524500]
#
# 보존화 	 15705 	 94
# 이상치 제거 [ 79000  73000  89000  82000  89000 300000]
#
# 사회 	 12542 	 85
# 이상치 제거 [395000  26000  40050 395000  36450  34050  26730  41850  36450  43260
#   49800  38500  56070  28800  24840]
#
# 액젓 	 13669 	 94
# 이상치 제거 [56920 80000 49600 64000 45000 55000]
#
# 클렌징티슈 	 9080 	 100
# 이상치 제거 []
#
# 립라이너 	 10638 	 95
# 이상치 제거 [38240 38000 32900 58650 49500]
#
# 볼링공 	 206203 	 99
# 이상치 제거 [450000]
#
# 수면팩 	 19922 	 90
# 이상치 제거 [ 64600 102200 147300 147900  86000  69210  62740  74000 150000  63350]
#
# 회계 	 22544 	 96
# 이상치 제거 [206220 203280 219580  68400]
#
# 눈썹정리기 	 22494 	 98
# 이상치 제거 [70600 51550]
#
# 경제 	 13136 	 94
# 이상치 제거 [ 50000  27000  56430  26550 360000  27910]
#
# 수의 	 32214 	 81
# 이상치 제거 [ 229000  250000 1060290  387000  430000  750671  859370  709000  270000
#   846000  645570  952260  260000  450000 1156990  982100  734520  420000
#   550000]
#
# 혈압계 	 58387 	 91
# 이상치 제거 [1049970  199000  199000  318510  330000 1300000 1050000  174000 1099970]
#
# 업소용빙수기 	 208927 	 78
# 이상치 제거 [2860000 4850000 3718000 4850000 3381000 2355000 2860000 2427000 3960000
#  3381000 3960000 3279000 4400000 4950000 4950000 4950000 2570000 2355000
#  2860000 4950000 1455500 1455500]
#
# 스코어보드 	 26516 	 93
# 이상치 제거 [498500 112560 273730 434650 251740 297930 157760]
#
# 농구공가방 	 11946 	 93
# 이상치 제거 [ 49000 100700  48740  70560 455550  48000  49500]
#
# 만보계 	 7251 	 97
# 이상치 제거 [28970 45000 83000]
#
# USIM 	 3775 	 94
# 이상치 제거 [16800 34800 15300 22260 15300 17600]
#
# 핑거보드 	 16775 	 98
# 이상치 제거 [50900 43800]
#
# 배드민턴네트 	 32998 	 90
# 이상치 제거 [143180  90500 316800 147180 144020 239000 656500 100890 103400 935088]
#
# 로잉머신 	 260040 	 87
# 이상치 제거 [1850000 1452000 1590000  955740 1880000 1850000 1351520  920000 2211570
#  1731270 1877630 1190000 5580000]
#
# 영양보충식 	 28653 	 100
# 이상치 제거 []
#
# 깍두기 	 16522 	 93
# 이상치 제거 [50000 39060 37530 44810 49760 41770 39000]
#
# 천문 	 270363 	 85
# 이상치 제거 [ 2570100  3169200  5628220  2078800  1950000  2354090 10262410  3210250
#   2764610  1484700  5152600  4237580 11764480  3367680  7238860]
#
# 조경수 	 19718 	 90
# 이상치 제거 [55000000   450000    78400  1000000   200000   160000  2699890   202200
#     80000   150000]
#
# 유아로션 	 18796 	 98
# 이상치 제거 [68400 58000]
#
# 장기렌터카 	 384124 	 94
# 이상치 제거 [1311400 1525860 1113200 1329400  968770 1329400]
#
# 쏘서 	 126073 	 100
# 이상치 제거 []
#
# 노트북도난방지 	 10942 	 91
# 이상치 제거 [33660 43560 34200 45900 57560 41600 41580 70180 38900]
#
# 커피시럽 	 11020 	 95
# 이상치 제거 [66200 32410 73800 30080 49550]
#
# 여성청결제 	 19336 	 95
# 이상치 제거 [59000 69900 59000 58000 71530]
#
# 족욕 	 12990 	 85
# 이상치 제거 [129000 169000  98000 108000  87800 171690  99000  90110 143010  88100
#   72630  64530  98900 621180  69000]
#
# 유아소파 	 84794 	 92
# 이상치 제거 [189000 258000 198000 246000 549000 258000 222200 298000]
#
# 빨래판 	 4874 	 86
# 이상치 제거 [ 19440 128100  96750  23700 182590  30880  19200 115080 110830  44660
#   45890 104970  37350  94920]
#
# 딸기잼 	 11982 	 89
# 이상치 제거 [40400 47440 47170 52240 40540 52390 47200 47500 54900 50520 39340]
#
# 생선그릴 	 121046 	 92
# 이상치 제거 [ 415000  749500  940000  615350  377960  569000  453840 2398660]
#
# 취업 	 14990 	 91
# 이상치 제거 [ 83870 112900 105200 122300  89000 111830 139000  71300 234600]
#
# 방수요 	 19008 	 94
# 이상치 제거 [100940 108960 115000  81180  93070  91490]
#
# 대나무발 	 26964 	 99
# 이상치 제거 [101850]
#
# 유아책상 	 102442 	 98
# 이상치 제거 [485000 590000]
#
# 스포츠만화 	 25262 	 96
# 이상치 제거 [  72000   57200 1214530   92640]
#
# 선스틱 	 11296 	 88
# 이상치 제거 [24640 34900 24900 29000 26890 34790 32300 31980 29020 41250 34800 24900]
#
# 넥케이프 	 8898 	 92
# 이상치 제거 [29700 24750 22960 21063 24490 20250 20250 20100]
#
# 안마매트 	 229801 	 99
# 이상치 제거 [670520]
#
# 돌잔치용품 	 13467 	 94
# 이상치 제거 [61060 61060 55000 55000 55000 55000]
#
# 슬리핑백 	 45598 	 95
# 이상치 제거 [350550 144780 149000 194090 178230]
#
# 다이어트차 	 19738 	 91
# 이상치 제거 [ 85700  87500  89500  87780  88580  79790 115000 128000  88000]
#
# 로스트볼 	 13390 	 90
# 이상치 제거 [ 49900  45700  53700  85010  63750  84910 132050  67150  57700  49700]
#
# 모기밴드 	 5973 	 100
# 이상치 제거 []
#
# 수면조끼 	 19991 	 98
# 이상치 제거 [41800 56880]
#
# 환자식 	 27066 	 99
# 이상치 제거 [97820]
#
# 필라테스링 	 6370 	 87
# 이상치 제거 [55000 21521 25650 23400 27900 23900 32600 27500 22360 26000 24310 24650
#  21170]
#
# 탁구화 	 85361 	 100
# 이상치 제거 []
#
# 수련화 	 70330 	 90
# 이상치 제거 [296000 258000 368800 336470 249800 290810 286000 254320 336000 449400]
#
# 저주파안마기 	 38339 	 89
# 이상치 제거 [240000 119270 376500 129000 127880 126920 149000 128000 168000 149000
#  167990]
#
# 마사지크림 	 12529 	 92
# 이상치 제거 [149000  33600  69900  54000  85900  97160 116000  96000]
#
# 조림 	 10367 	 91
# 이상치 제거 [51290 51150 84280 37630 33790 62000 38250 56800 63000]
#
# 유아변기 	 21943 	 97
# 이상치 제거 [234000  63830  69900]
#
# 들기름 	 18665 	 93
# 이상치 제거 [39900 54900 65800 44000 57510 36970 46000]
#
# 업소용튀김기 	 525313 	 96
# 이상치 제거 [3300000 2794000 5500000 3630000]
#
# 두피케어기기 	 70882 	 88
# 이상치 제거 [ 498000 1115300  990000  898000  937800 1140000  599000  473400 2400000
#   690000  497990 1120000]
#
# 요구르트제조기 	 31605 	 91
# 이상치 제거 [119000  85900 107000  98000 279000 119000  99000  85900 107000]
#
# 클렌징워터 	 13933 	 98
# 이상치 제거 [33750 99900]
#
# 카세트플레이어 	 66596 	 94
# 이상치 제거 [194400 241600 222150 183150 255200 450000]
#
# ODD 	 29511 	 95
# 이상치 제거 [128700  79800 100000 425000  79800]
#
# 핸드드라이어 	 394476 	 96
# 이상치 제거 [2359000 1679000 1679000 2359000]
#
# 기타인형 	 19798 	 97
# 이상치 제거 [59000 65000 72675]
#
# 볼캐리어 	 104723 	 93
# 이상치 제거 [376710 330000 315750 323400 366200 301570 290420]
#
# 매직기 	 42542 	 92
# 이상치 제거 [445180 599000 200000 240000 350790 232800 150000 240000]
#
# 유아과자 	 10551 	 98
# 이상치 제거 [44900 55900]
#
# 이민 	 25509 	 96
# 이상치 제거 [ 85700 113630 119540 119570]
#
# 디딤대 	 21796 	 99
# 이상치 제거 [202680]
#
# 연습용젓가락 	 5679 	 99
# 이상치 제거 [22000]
#
# 포스터컬러 	 10407 	 87
# 이상치 제거 [90500 73790 63079 79000 89100 73060 57590 74000 85980 83250 68510 64823
#  79870]
#
# 쉐이빙폼 	 7928 	 92
# 이상치 제거 [ 29700  29800  36000  28890  35890 150490  27900  28350]
#
# KVM케이블 	 29085 	 96
# 이상치 제거 [200000 124000 155000 109000]
#
# 생크림 	 6947 	 91
# 이상치 제거 [18900 58200 51000 49990 44660 43200 62500 62900 24280]
#
# 이온수기 	 64298 	 83
# 이상치 제거 [2490000 3390000 2365500  470000  714040 1740000 1540000 2190000 1580000
#  2705940 3400000  268250 1690000 2883460 1286610 1460750  412800]
#
# 국악기 	 59346 	 94
# 이상치 제거 [ 550000  500000  560970  690000  433100 1676970]
#
# 구강청정제 	 9891 	 99
# 이상치 제거 [50000]
#
# 온수매트 	 181305 	 99
# 이상치 제거 [434800]
#
# 골드바 	 1247262 	 93
# 이상치 제거 [ 90818190  10213250  90818190   7668720  10358710 107131800   9731650]
#
# 테이핑요법 	 4886 	 87
# 이상치 제거 [22900 45000 23500 33000 30000 22000 37590 45000 21500 35000 58410 45000
#  33000]
#
# 네트워크테스트기 	 36047 	 86
# 이상치 제거 [  234600   211600   241500   246240   194140  2567374   194040   278920
#    188860 10782100   503160   417580   316400   316400]
#
# 강정 	 11190 	 97
# 이상치 제거 [39800 40000 33000]
#
# 워시오프팩 	 21670 	 95
# 이상치 제거 [ 59800  68000 133380  65000  98100]
#
# 구둣주걱 	 6584 	 89
# 이상치 제거 [ 30000  36190 143000 143000  32820  28336  31400  30400  36580  36640
#   38030]
#
# 업소용진공포장기 	 1034880 	 97
# 이상치 제거 [ 8260000  5640000 10120000]
#
# 자급제폰 	 1047873 	 100
# 이상치 제거 []
#
# 파크골프 	 647849 	 97
# 이상치 제거 [2400000 1762200 2192000]
# 보컬 	 120059 	 94
# 이상치 제거 [ 480000  480000  900000  528000  792000 3966500]
#
# 아이스크림제조기 	 358531 	 77
# 이상치 제거 [ 7500000 12000000  5950000  7280000  5200000 44660000  5789960  9200000
#   4975000  7600000 28644000 15045800 12474000 13844600 11242000  9317000
#  13844600 17663800 12320000 24200000  9770000  9200000  7000000]
#
# 도복 	 118093 	 100
# 이상치 제거 []
#
# 헤어미스트 	 38145 	 100
# 이상치 제거 []
#
# 절임류 	 8049 	 92
# 이상치 제거 [30900 42900 30500 32900 31850 45000 32000 31650]
#
# 고슴도치용품 	 27808 	 89
# 이상치 제거 [717900 767900 675760 767900 767900 240900 240900 240900 140110 161380
#  156900]
#
# 매직블럭 	 4869 	 94
# 이상치 제거 [ 29930  36620  33830  32090  24500 297000]
#
# 젖병솔 	 7027 	 94
# 이상치 제거 [29500 41990 39900 29400 39000 44550]
#
# 렌즈세척기 	 25434 	 91
# 이상치 제거 [ 110000  123000  108000  155970  244830  289000  568550  135340 1403420]
#
# 야구화 	 56417 	 95
# 이상치 제거 [145000 239000 159000 154000 135000]
#
# 배구화 	 76945 	 92
# 이상치 제거 [209000 250000 270300 179000 174110 176000 182700 186400]
#
# 핫플레이트 	 32828 	 89
# 이상치 제거 [193700 195800 236900 232680 179360 139400 159410 130260 990400 149800
#  144000]
#
# 냉온풍기 	 935220 	 97
# 이상치 제거 [2440000 2730000 2879000]
#
# 콤비블라인드 	 15004 	 93
# 이상치 제거 [ 81900  60900  89050 148900 148900  59800  67830]
#
# 한자 	 2680 	 93
# 이상치 제거 [17490 15590 20850 99554 22190 20330 92171]
#
# 훌라후프 	 17542 	 99
# 이상치 제거 [67620]
#
# 요가링 	 5136 	 91
# 이상치 제거 [55000 21521 27900 32600 32600 24570 24310 21420 25650]
#
# 아이스스케이트 	 106768 	 94
# 이상치 제거 [374200 474900 540720 403790 718370 692640]
#
# 재활운동기구 	 122848 	 91
# 이상치 제거 [ 639000  430000 4000000 2750000 3649410 1034000  638000  460000 4510000]
#
# 메이크업베이스 	 23590 	 92
# 이상치 제거 [74390 74800 79100 73570 76800 80100 79000 71870]
#
# 네일리무버 	 5074 	 89
# 이상치 제거 [23000 26250 20000 16600 20000 23000 19990 17000 29000 25000 23000]
#
# 장아찌 	 16626 	 94
# 이상치 제거 [60000 60000 51000 48450 67810 47210]
#
# 볼링용품 	 6071 	 90
# 이상치 제거 [59000 40000 18000 17570 22680 25000 19000 35700 15800 25000]
#
# 포대기 	 39277 	 98
# 이상치 제거 [ 99470 123220]
#
# 공기계 	 159697 	 89
# 이상치 제거 [ 570750 1153020  508730  640000  739000  695000  549000  590000  944000
#   882280  614000]
#
# 올리고당 	 7906 	 84
# 이상치 제거 [ 70000  46410  35000  70000  60000  35000 105000  37230  47500  35000
#   33000  45000  60000  36440  35000  38500]
#
# 야구공 	 6886 	 88
# 이상치 제거 [ 49000  32800  36900  28890  24000  31500 106000  30000  37190  84000
#   69000  28600]
#
# 바디파우더 	 45916 	 98
# 이상치 제거 [150520 141200]
#
# 부부테이블 	 159642 	 87
# 이상치 제거 [ 790820  861000  773600  799840  808040  575610  854000 1436830  770000
#   707630  699970  905960  933750]
#
# 고가구 	 248608 	 86
# 이상치 제거 [4300000 1031960 6500000 7600000 1804430 2296900 1070700 9900000 2238060
#  1100000  997500 4064600 4500000 1461900]
#
# 컵보드 	 91341 	 88
# 이상치 제거 [1393000  489500  243310  766760 1260000  444600  762650  847500  946700
#   241900  945000 1250000]
#
# 건강슬리퍼 	 10208 	 91
# 이상치 제거 [29000 59000 31000 32000 59000 32000 62000 87000 29000]
#
# 미러리스디카 	 1564671 	 93
# 이상치 제거 [11600000  6771910  7089990  7046590 13660000  6400990 15501220]
#
# 암워머 	 3338 	 90
# 이상치 제거 [45400  9800 17670 16500 22480 13470 47000 16500 31520 12670]
#
# 일본어 	 5193 	 98
# 이상치 제거 [20850 27360]
#
# 보행차 	 111485 	 94
# 이상치 제거 [ 299120  561330  276000  399970  314100 1148970]
#
# 어깨보호대 	 11107 	 83
# 이상치 제거 [ 39000  30900  99000 235000  39310  99000  39000  99000  37000 127890
#   34900 112500 165000  35620  33666  51750  51000]
#
# 유아바스 	 15431 	 97
# 이상치 제거 [66500 42900 39900]
#
# 제빵기 	 124197 	 84
# 이상치 제거 [1260000  618000 2800000 1390000 1550000 1600000 1775000 1416090  928900
#  1860000  630000  366200 1560000 4950000 1979000 1430000]
#
# 지구본 	 51404 	 93
# 이상치 제거 [9900000  186000  573990  261410  246670  198000  161280]
#
# 녹즙기 	 205868 	 93
# 이상치 제거 [1969000  880000 2574000 3014000 3014000  737400 1979990]
#
# 낫토 	 21653 	 98
# 이상치 제거 [61960 54040]
#
# KVM스위치 	 77513 	 83
# 이상치 제거 [1850000  445500  338700  338000  433030  371200 1185000  364500  959000
#  1385000 1358000 1586000  852000  338000 1158000  400000 1100000]
#
# 실버카 	 138443 	 97
# 이상치 제거 [505000 293550 561330]
#
# 팔보호대 	 12742 	 92
# 이상치 제거 [45000 60000 45000 60000 60000 40100 39330 60000]
#
# PMP 	 145506 	 97
# 이상치 제거 [1762290 1703160 1631540]
#
# 스노보드장비 	 537748 	 96
# 이상치 제거 [2090000 2190000 2559290 1830500]
#
# 배구공 	 32295 	 100
# 이상치 제거 []
#
# 가스레인지후드 	 167880 	 98
# 이상치 제거 [2950000 1999000]
#
# 마케팅 	 258244 	 89
# 이상치 제거 [ 2640000  2200000  4980000  2980000  1480000  1595000  2100000 15000000
#   5000000  4200000  3000000]
#
# 가르시니아 	 17509 	 96
# 이상치 제거 [165000  98510 492420  49500]
#
# 속통 	 13701 	 92
# 이상치 제거 [62670 53000 55100 48000 49910 46880 52560 89890]
#
# 오리고기 	 16737 	 94
# 이상치 제거 [81000 59310 53570 84990 81900 69500]
#
# 장례용품 	 52457 	 97
# 이상치 제거 [255000 195600 199800]
#
# 고춧가루 	 22018 	 89
# 이상치 제거 [108070  93100 169800  73700 147000  62240 132610 112580 128110 106630
#  180000]
#
# 태닝 	 57817 	 97
# 이상치 제거 [400000 250000 175000]
#
# 스패츠 	 15803 	 90
# 이상치 제거 [ 72000  79340  65700  56950 115570  54390  80000  69000 109570  53820]
#
# 방석솜 	 5652 	 94
# 이상치 제거 [19460 31200 18930 18150 19400 19280]
#
# 지압기 	 9480 	 89
# 이상치 제거 [  89000   89000   64000  268000   92000 1890000   80000  200000   55000
#   160000   55000]
#
# 파스타소스 	 7737 	 95
# 이상치 제거 [55500 29000 37000 24900 30000]
#
# 케첩 	 4046 	 91
# 이상치 제거 [33900 33600 33900 33950 15700 35000 35500 30060 38640]
#
# 아동화장품 	 39502 	 96
# 이상치 제거 [129000 111000 131890 109000]
#
# 전설 	 38918 	 88
# 이상치 제거 [ 449000 1598000  318620  704000  490000 1680000  337500  290000  330000
#   153970  477200  436800]
#
# 탁구의류 	 38189 	 97
# 이상치 제거 [ 82500 119500  87560]
#
# 영상촬영 	 81688 	 87
# 이상치 제거 [ 504480 1750000 5286000 3750000  511920  565700 1558000  653700  439040
#   499000  505700  485480  505700]
#
# 안경줄 	 4840 	 97
# 이상치 제거 [19800 22000 37450]
#
# 모니터브라켓 	 26455 	 97
# 이상치 제거 [131000 105200 168200]
#
# NAS 	 625847 	 90
# 이상치 제거 [2969000 2176000 2993000 2799000 2321000 5810000 2111000 2409000 2030000
#  2177000]
#
# 발가락교정기 	 14670 	 91
# 이상치 제거 [ 50000  92000  69000  88000  49000  60000  69000 110000  49800]
#
# 슈트케이스 	 46590 	 91
# 이상치 제거 [169840 180400 760000 331860 802400 383520 449000 383520 200400]
#
# 클렌징세트 	 37804 	 95
# 이상치 제거 [204200 127800 122300 209000 114300]
#
# 낮잠이불 	 72165 	 100
# 이상치 제거 []
#
# 탁구공 	 6427 	 86
# 이상치 제거 [30800 27000 27470 42309 40000 41046 50000 49500 37390 20000 40000 21000
#  23760 25000]
#
# 신화 	 49978 	 96
# 이상치 제거 [173430 242340 409460 148320]
#
# 머리보호대 	 18577 	 93
# 이상치 제거 [44990 59000 46000 79100 78810 44990 59000]
#
# 패밀리룩 	 24437 	 94
# 이상치 제거 [69000 66000 66000 99000 66000 66000]
#
# 곤약 	 13436 	 100
# 이상치 제거 []
#
# 뜸 	 14470 	 95
# 이상치 제거 [  77000   55900 1210000  230000   64460]
#
# 한복소품 	 11681 	 88
# 이상치 제거 [ 74000  74100  69000  63050 142500  59800  98000  89000  67000  80000
#   51270  56000]
#
# 아이돌굿즈 	 14818 	 88
# 이상치 제거 [ 55800  52000  56700  48900  59000 210000  85500  48000  55000  49500
#   51600  54000]
#
# 회전청소기 	 21586 	 98
# 이상치 제거 [60570 65820]
#
# 다림판 	 26450 	 99
# 이상치 제거 [98000]
#
# 클렌징크림 	 15167 	 95
# 이상치 제거 [ 46800 189000  51000 119800  50130]
#
# 세탁볼 	 4426 	 93
# 이상치 제거 [23900 21900 19900 37700 23900 43990 39900]
#
# 웰트화 	 29659 	 90
# 이상치 제거 [104030 111850 163060  60190  67260  65000 147030  72560  62900  55083]
#
# 학습보드게임 	 19782 	 96
# 이상치 제거 [ 65650  68450 167190 131670]
#
# 코너장 	 87231 	 95
# 이상치 제거 [674000 249640 268400 267790 267540]
#
# 조리기 	 36486 	 88
# 이상치 제거 [ 218000  189000  218000  228000  206000  198000  245690  298330 4280900
#   290670  348930  162540]
#
# E쿠폰 	 18297 	 98
# 이상치 제거 [92000 97690]
#
# 목보호대 	 24238 	 94
# 이상치 제거 [262170 149850 170000 160000 129000 221610]
#
# 포기김치 	 33823 	 100
# 이상치 제거 []
#
# 선풍기커버 	 3894 	 95
# 이상치 제거 [14900 26800 13900 26480 12900]
#
# 액티비티 	 21029 	 91
# 이상치 제거 [134830 180000  70000 229000 180000  85000 113100  59000 119970]
#
# 보풀제거기 	 26408 	 97
# 이상치 제거 [74400 75000 79000]
#
# 유아목욕장난감 	 12916 	 98
# 이상치 제거 [43900 37370]
#
# 쉐이딩 	 18153 	 92
# 이상치 제거 [ 68620  59000  69230  75000 107130  72620  78000  66200]
#
# 수반 	 14667 	 96
# 이상치 제거 [674210  95000 111630  61110]
#
# BB크림 	 23761 	 96
# 이상치 제거 [99800 99000 97000 89100]
#
# 배냇저고리 	 25895 	 95
# 이상치 제거 [106120  61900  64800  85840  92016]
#
# 일반디카 	 539033 	 97
# 이상치 제거 [2399970 2900300 8908020]
#
# 무도복 	 88119 	 94
# 이상치 제거 [337350 464200 295000 279260 293870 307400]
#
# 사케 	 43710 	 85
# 이상치 제거 [179300 430000 575000 474000 365000 435100 629000 190000 576600 149100
#  199000 590000 495000 344000 147000]
#
# 유아청소년 	 32332 	 100
# 이상치 제거 []
#
# 디지털액자 	 152391 	 90
# 이상치 제거 [1125000  981000  586000 1990000 2140000 1090000  677830 1090000 1097960
#  1906170]
# 신생아모자 	 10894 	 89
# 이상치 제거 [37050 30980 31990 36610 64300 27020 35200 38000 28320 33280 35200]
#
# 연극 	 13615 	 87
# 이상치 제거 [29700 39600 28500 40000 52800 50300 79200 41500 29700 37500 40000 30000
#  50300]
#
# 유아크림 	 19201 	 97
# 이상치 제거 [89990 53000 69900]
#
# 야구장갑 	 27931 	 94
# 이상치 제거 [75000 75000 89300 85000 85000 70930]
#
# 짜장 	 4969 	 96
# 이상치 제거 [51000 18000 31500 20230]
#
# 대자리 	 33475 	 93
# 이상치 제거 [171900  94400 110000 110580 125000 179000  95220]
#
# 책상의자세트 	 139036 	 85
# 이상치 제거 [ 819000  739000  528580  535050  775000  384990  499000 1109000  635550
#   812780  571000  502550  490800  392500  614220]
#
# 유아칫솔 	 10823 	 96
# 이상치 제거 [41500 40000 42500 42000]
#
# 헤어롤 	 7167 	 93
# 이상치 제거 [ 39000  89000  49000  47000  40000 138000  79900]
#
# 야구배트 	 121983 	 100
# 이상치 제거 []
#
# 유아베개 	 31982 	 98
# 이상치 제거 [95000 83300]
#
# 업소용믹서기 	 441285 	 92
# 이상치 제거 [2120000 2290000 2118500 2840000 2120000 2420000 5390000 2100000]
#
# 선택기 	 18524 	 89
# 이상치 제거 [136000 195000  98000 325000  89000 100110  76400 423500  82500  68000
#  104000]
#
# 농구대 	 91222 	 84
# 이상치 제거 [ 1326000   979530  1007730  1643400  2050000  1957400  3226950  2259600
#   1825990  7698490  2167000  1276040   695860 15999990  1284190   942920]
#
# 우드락 	 9017 	 98
# 이상치 제거 [169930  44000]
#
# 컴퓨터공학 	 41660 	 87
# 이상치 제거 [ 246735  366160  646260 1650700  392790  194210  369000 1147000  373400
#   267170 1915200  585000  489000]
#
# 코털제거기 	 16614 	 94
# 이상치 제거 [45000 55000 48900 42000 39000 59000]
#
# 천주교용품 	 35660 	 87
# 이상치 제거 [ 380000 3282390  408240  284760 2847600  235200  175990 3016970  863740
#  1421860  897590  990790  150400]
#
# 토퍼커버 	 39941 	 97
# 이상치 제거 [323720 273210  96200]
#
# 즉석카메라 	 150110 	 97
# 이상치 제거 [680000 619000 704000]
#
# 관엽식물 	 30510 	 99
# 이상치 제거 [145000]
#
# 클렌징젤 	 24732 	 87
# 이상치 제거 [131000 125000 112000 107650 110000 116000 111900  78690  91800  85900
#  108900  87000 121000]
#
# 워크스테이션 	 1171228 	 97
# 이상치 제거 [13000000 20000000 32786000]
#
# 입욕제 	 15479 	 93
# 이상치 제거 [65120 66900 59500 57200 81720 98600 69470]
#
# 쥬서기 	 195060 	 96
# 이상치 제거 [ 880000 1979990  880000 4620000]
#
# 빙수기 	 71932 	 81
# 이상치 제거 [ 721540 1650000  769990 2800000 2160000 1584900 2600000  719430 2600000
#  3583990 3540000 1650000  938050 3060000 3650000 2190000 2070000  935000
#  3960000]
#
# 정자 	 559884 	 90
# 이상치 제거 [2100000 2180000 3900000 3898000 2901000 2011900 2200000 1700000 3728980
#  1893010]
#
# 반제품 	 17584 	 86
# 이상치 제거 [250000 120000 239000 350000 150000 154000 177800 370000 189000 505000
#  134300  98310 105000 132000]
#
# 커플시계 	 110300 	 89
# 이상치 제거 [3144000 2824000 3144000 2013590  756000  747000 3065400 3400000 1659990
#   684140  768400]
#
# 넝쿨식물 	 6108 	 90
# 이상치 제거 [22900 29500 19900 29900 25000 39900 22000 21120 38900 23900]
#
# 창작 	 13962 	 87
# 이상치 제거 [279000  94500  90250 389700  73710 447593  72460  94500 373400  56090
#   56090  94500  80000]
#
# 셔틀콕 	 14508 	 89
# 이상치 제거 [110000  82990 400000 178500 120000  78970 499000 424990 435000  42990
#   37000]
#
# 포셉 	 11558 	 94
# 이상치 제거 [114990  66290  55680  61900  79810  57880]
#
# 참기름 	 15857 	 94
# 이상치 제거 [123000  59900 136500 115900 127800  54900]
#
# 헤어왁스 	 14186 	 99
# 이상치 제거 [39570]
#
# 안마의자 	 1836037 	 94
# 이상치 제거 [6030000 5600000 5300000 6385500 8990000 5788000]
#
# 제수용품 	 145083 	 94
# 이상치 제거 [ 718200  876640  852030  719400 1316300 1500000]
#
# 성인용기저귀 	 28261 	 100
# 이상치 제거 []
#
# 폼보드 	 9687 	 95
# 이상치 제거 [ 40000  39990  74250 108000  58950]
#
# 문학 	 4126 	 85
# 이상치 제거 [ 20880  29000  18600  19490  15770 309240  18600  67350  15732 233490
#   17400  19710  16300 232680  28750]
#
# 롤러슈즈 	 53089 	 91
# 이상치 제거 [2581700 2572500  159000  270000  954470  851500  188620 2881400  316300]
#
# 모뎀 	 115402 	 91
# 이상치 제거 [ 459630 1060230 3753980  588960 3626040  457470 4686160 1060680  991080]
#
# 대화 	 20497 	 94
# 이상치 제거 [ 75330  66000  61000 365110  60000  69485]
#
# 고등어 	 21546 	 100
# 이상치 제거 []
#
# 소음방지귀마개 	 11105 	 96
# 이상치 제거 [58900 59000 52660 86850]
#
# 한과 	 19250 	 95
# 이상치 제거 [ 57000 117000  55000  54880  55000]
#
# 리피터장비 	 115471 	 91
# 이상치 제거 [ 866360  762370  465520  534330 1281860  472270 1072720  453500  641810]
#
# 바디스크럽 	 21862 	 99
# 이상치 제거 [66570]
#
# 올리브유 	 22458 	 92
# 이상치 제거 [143680  62000 175000  61200  95000  61420  69000  62000]
#
# 아기이불 	 43356 	 94
# 이상치 제거 [109000 107340 149000 110670 141000 129000]
#
# 칠리 	 6777 	 91
# 이상치 제거 [ 37770  26000  22750  25460  36960  26150  79700 132850  24570]
#
# 발레복 	 27372 	 98
# 이상치 제거 [65000 75000]
#
# 칫솔치약세트 	 4348 	 91
# 이상치 제거 [20020 23900 85000 68650 19900 19000 23360 93000 23160]
#
# 헤어스프레이 	 10529 	 96
# 이상치 제거 [34210 33000 32970 32790]
#
# 클렌징오일 	 15365 	 89
# 이상치 제거 [64880 75890 46500 35400 57000 66070 38220 67500 39000 32800 45220]
#
# 축구양말 	 6569 	 91
# 이상치 제거 [31500 20000 23400 22900 20000 36000 36000 17300 20290]
#
# 젓갈 	 16135 	 93
# 이상치 제거 [45000 44000 80000 54000 43300 49215 55000]
#
# 하이라이터 	 19520 	 92
# 이상치 제거 [ 68620  75000  69230  72620 107130  78000  63750  66200]
#
# 비누꽃 	 13587 	 100
# 이상치 제거 []
#
# 양념장 	 10678 	 97
# 이상치 제거 [33900 34900 38730]
#
# 종이꽃 	 25771 	 88
# 이상치 제거 [ 135170  165000  178200   98000 1265300  170700 1062860  107130  225900
#    95000  119000  597000]
#
# 데오드란트 	 8272 	 89
# 이상치 제거 [27870 24800 36000 29630 29410 28330 25500 50160 39000 33000 31990]
#
# 화폐 	 17944 	 94
# 이상치 제거 [ 245000  249900 4500000   72400  288000   85420]
#
# 그릇장 	 115750 	 92
# 이상치 제거 [1120000  280000  330190  272800  683970 1387570  310000  432000]
#
# 가글 	 10707 	 94
# 이상치 제거 [41500 34790 59000 75650 62500 33900]
#
# 문닫힘방지 	 3765 	 92
# 이상치 제거 [18450 14900 20500 21151 15010 15380 15000 16400]
#
# 바디미스트 	 23347 	 97
# 이상치 제거 [120000  70000  69880]
#
# 축구보호대 	 7878 	 92
# 이상치 제거 [35000 32600 29750 35000 45000 27000 64000 34150]
#
# 스키장비 	 575591 	 97
# 이상치 제거 [2098900 2052000 1940000]
#
# 김치냉장고 	 1326062 	 100
# 이상치 제거 []
#
# 아이스머플러 	 5887 	 96
# 이상치 제거 [40160 30460 22030 42700]
#
# 트램펄린 	 102119 	 97
# 이상치 제거 [ 440000 1100000 4960000]
#
# 욕실장 	 83934 	 100
# 이상치 제거 []
#
# 향수세트 	 60958 	 94
# 이상치 제거 [193000 185000 251000 255000 389000 169120]
#
# 반찬세트 	 25874 	 83
# 이상치 제거 [ 188000  520000  178000  850000  149000  222000 1150000  700000  256500
#   149000  420000  149000  680000 1270000  290000 1020000  950000]
#
# 블러셔 	 21519 	 95
# 이상치 제거 [72000 78900 70900 75900 68400]
#
# 배드민턴가방 	 66993 	 100
# 이상치 제거 []
#
# 국내패키지 	 35564 	 87
# 이상치 제거 [320000 299000 279000 355000 259000 299000 304000 245000 491500 221000
#  314200 335000 279000]
#
# 디지털도어록 	 138237 	 94
# 이상치 제거 [490000 400000 430000 489000 560000 400000]
#
# 다이어트바 	 14091 	 95
# 이상치 제거 [59900 39900 39900 55820 44064]
#
# 빨랫줄 	 6115 	 96
# 이상치 제거 [55700 34280 27900 25980]
#
# LGU+ 	 516482 	 99
# 이상치 제거 [2302700]
#
# 호각 	 12827 	 98
# 이상치 제거 [55200 71740]
#
# 튀김기 	 72338 	 94
# 이상치 제거 [300000 285000 260000 285000 672000 767970]
#
# 임부속옷 	 13140 	 97
# 이상치 제거 [51340 43890 43890]
#
# 돌기념품 	 4152 	 86
# 이상치 제거 [11900 14500 84000 31610 32440 32440 32440 82660 32440 39160 15900 12500
#  37125 39160]
#
# 와플제조기 	 39677 	 91
# 이상치 제거 [460000 326000 450000 598000 155000 330000 298000 330000 125000]
#
# 축구장갑 	 25076 	 93
# 이상치 제거 [ 79380 107300 122470 139000  89000 114240  91950]
#
# 기어백 	 78812 	 94
# 이상치 제거 [340200 517500 248000 276050 250000 317070]
#
# 속치마 	 8327 	 91
# 이상치 제거 [19800 34820 20090 27900 22050 21590 22500 22440 23080]
#
# 배드민턴화 	 95844 	 100
# 이상치 제거 []
#
# 토스터기 	 49066 	 93
# 이상치 제거 [184000 159000 165600 280900 209000 398500 191380]
#
# 유아마스크 	 7480 	 94
# 이상치 제거 [27500 24000 25000 24740 23500 25600]
#
# 군모 	 16737 	 97
# 이상치 제거 [56010 56310 72500]
#
# 바디슬리밍 	 25468 	 95
# 이상치 제거 [ 88800  76000  92000 109000 108900]
#
# 립케어 	 15374 	 93
# 이상치 제거 [68190 59000 60260 80260 63800 54800 56540]
#
# 페이스오일 	 26079 	 92
# 이상치 제거 [ 96340 112200 121500 176800  98000 105260 107700 269320]
#
# 헬스사이클 	 237721 	 91
# 이상치 제거 [ 690000 1790000  891000 1479970  838500 1040000 1100000 1383990 1399990]
#
# 식품건조기 	 189578 	 93
# 이상치 제거 [ 857000  795690  980520 2050000 1140410 1032570 4790000]
#
# 테라리엄 	 12214 	 88
# 이상치 제거 [ 60000  76920 150000  71250 280000  85200  65860 120000 172200  59900
#   88400  94500]
#
# 핫도그 	 16369 	 100
# 이상치 제거 []
#
# 유아침대 	 209630 	 99
# 이상치 제거 [1469000]
#
# 피클 	 6145 	 88
# 이상치 제거 [  26400   28400   35700   33500 5688000   35240   57000   39390   34200
#    37350   38680   38200]
#
# 천체망원경 	 478805 	 94
# 이상치 제거 [19550000 17000000  2400000  4920000  3890000  2540000]
#
# 마라톤용품 	 36059 	 98
# 이상치 제거 [169000 121830]
#
# 유아의자 	 89121 	 90
# 이상치 제거 [620000 390000 535000 340000 550000 340000 320000 338990 397500 418000]
#
# 여과제 	 7796 	 89
# 이상치 제거 [ 90000  85000  43000  59600  51900 174710 170400 343060 256570  84940
#  111380]
# 안대 	 12245 	 94
# 이상치 제거 [ 43800  55000 127000  48000  46750 298000]
#
# 고전 	 3457 	 88
# 이상치 제거 [25000 12000 15000 15500 15300 15500 40000 12600 13390 22600 13530 39000]
#
# 튜너 	 22613 	 92
# 이상치 제거 [109000 194000 108000 105900 145000 204460 182020 209380]
#
# 넥타이핀 	 32088 	 97
# 이상치 제거 [270550 131000 207200]
#
# 베어본PC 	 413361 	 91
# 이상치 제거 [1899840 2054970 2211700 1696300 4136640 1289000 1165000 1950000 3089900]
#
# 치간칫솔 	 7813 	 96
# 이상치 제거 [23980 23990 23990 23000]
#
# 행정 	 23346 	 97
# 이상치 제거 [66880 57500 59000]
#
# 도서 	 13486 	 88
# 이상치 제거 [46000 46000 97690 47000 47250 46500 46500 50000 47500 47500 48000 48500]
#
# 중국어 	 28550 	 92
# 이상치 제거 [ 99900 152700  90500 114500  92240 210240  97300 123280]
#
# 전자담배 	 41851 	 96
# 이상치 제거 [110000 110000 149000 119000]
#
# 전기요 	 66898 	 99
# 이상치 제거 [185000]
#
# 어패류 	 8106 	 88
# 이상치 제거 [  58200   31365   35900   27000   57000 2759450   84590  205520   40700
#    36820   36550   27630]
#
# 푸딩 	 7768 	 94
# 이상치 제거 [36140 31000 66800 28050 28930 48900]
#
# 러닝머신 	 632287 	 96
# 이상치 제거 [2890000 2849030 2246290 2133770]
#
# 교자상 	 47691 	 96
# 이상치 제거 [159000 126650 134000 173704]
#
# 물조리개 	 6783 	 98
# 이상치 제거 [22240 25560]
#
# 양고기 	 23996 	 94
# 이상치 제거 [149900 137500 134800 131900  79000  79900]
#
# 건과류 	 10574 	 94
# 이상치 제거 [  28900 1035000   75000   39000   59000   36900]
#
# 셀프촬영 	 31264 	 99
# 이상치 제거 [69000]
#
# 신발끈 	 1772 	 90
# 이상치 제거 [14900 19900  8700 10320 10900 10030  8360 20000  8500  9900]
#
# 워터볼 	 26960 	 98
# 이상치 제거 [95490 80700]
#
# 물리치료용품 	 55630 	 86
# 이상치 제거 [ 730000  700000 2880000 1633140  730000  690630  700000  799900  700000
#   636340  880000  660000  800000  720000]
#
# 탄산수 	 9687 	 90
# 이상치 제거 [24900 23900 23250 25000 24990 34500 23890 25400 24800 28590]
#
# 카레 	 2820 	 86
# 이상치 제거 [36900 18000 20800 14900 20890 17900 11500 19200 12700 13900 15280 19500
#  17990 62900]
#
# 드라마 	 50994 	 93
# 이상치 제거 [228870 155000 147840 255200 131300 169590 144100]
#
# 누룽지 	 12197 	 99
# 이상치 제거 [62220]
#
# 스키복 	 443079 	 100
# 이상치 제거 []
#
# CLA 	 30799 	 97
# 이상치 제거 [ 90910 136620 109000]
#
# 방울털모자 	 10340 	 95
# 이상치 제거 [31900 35000 48662 44460 26720]
#
# 고추장 	 15733 	 91
# 이상치 제거 [70465 72165 71180 61500 74715 79550 89900 60922 48970]
#
# 제빵재료 	 10453 	 98
# 이상치 제거 [145000  85000]
#
# 야구가방 	 80816 	 97
# 이상치 제거 [247000 288100 286600]
#
# 캐리어커버 	 10280 	 92
# 이상치 제거 [55900 45000 80000 35810 33320 35100 36000 39000]
#
# 햄버거 	 11908 	 96
# 이상치 제거 [128180  35400  90600 142061]
#
# 인라인용품 	 13151 	 86
# 이상치 제거 [ 65480  47260  49000  54200 272910  93000  48510  51420  57440  67760
#  346300 265000  66210 146720]
#
# 열쇠지갑 	 17657 	 86
# 이상치 제거 [ 59900  57150 202910 158000  95530 534760 159190  96500  60940 224360
#  152880  57190 178970 148190]
#
# 카드리더기 	 11904 	 96
# 이상치 제거 [57960 55000 71030 40500]
#
# 어묵 	 10939 	 95
# 이상치 제거 [40000 33340 36000 47880 40860]
#
# 판타지 	 98518 	 90
# 이상치 제거 [1298000  421600  623570 1087000 1198000  496100 1348000  439990  730000
#   510120]
#
# DAC 	 250949 	 84
# 이상치 제거 [5280000 1399000 1399000 1400000 1430000 1420000 1527320 1590000 1480000
#  1990000 1320000 1690000 1249000 1940000 1480000 1420000]
#
# 제모기 	 75268 	 85
# 이상치 제거 [389000 416500 404070 399000 395990 690000 449000 377100 389500 397440
#  349900 359900 729000 449000 429800]
#
# 마우스피스 	 17192 	 94
# 이상치 제거 [ 95000 149000  65000 100000  75000  62000]
#
# 헤어케어세트 	 47689 	 94
# 이상치 제거 [177110 280000 270000 186000 191100 200640]
#
# 자세교정용품 	 22804 	 88
# 이상치 제거 [ 78000  75650  85490  70800  79800 148000  76000  70000 100000 189000
#   69000  76780]
#
# 자외선소독기 	 70780 	 95
# 이상치 제거 [270000 368000 560000 349000 259000]
#
# 우표 	 17727 	 98
# 이상치 제거 [134870 239000]
#
# 조소 	 49193 	 94
# 이상치 제거 [1400000  251120  570100  295050  949900  697800]
#
# 발각질제거기 	 13389 	 86
# 이상치 제거 [ 87900 129000  89000 149000  59000 129000 139000  78900 119000 169000
#  139000  84000  77000  99000]
#
# 유아스푼 	 9018 	 93
# 이상치 제거 [26000 29000 26000 28500 23900 25900 29700]
#
# 유아학습 	 35440 	 92
# 이상치 제거 [315820 123600 119800 222150 328220 221570 225490 225620]
#
# 호루라기 	 11891 	 96
# 이상치 제거 [46900 44300 42430 55600]
#
# 여권지갑 	 18125 	 91
# 이상치 제거 [173360 520000 534400 265200  75000 133490 337000  73000 140399]
#
# 립틴트 	 13398 	 96
# 이상치 제거 [41080 42370 37490 40150]
#
# 장난감정리함 	 34995 	 96
# 이상치 제거 [164500 139000 281700 150560]
#
# 전통공예소품 	 8147 	 94
# 이상치 제거 [450000  91340  33000  56120  52170  43600]
#
# 히알루론산 	 23682 	 94
# 이상치 제거 [143400  79000 198000  69900  75800  94800]
#
# 립글로스 	 23678 	 99
# 이상치 제거 [73900]
#
# 한방재료 	 13942 	 92
# 이상치 제거 [ 42000  42000  82500  50000  56000  65000  40000 114000]
#
# 기저귀가방 	 50788 	 96
# 이상치 제거 [159000 143000 169000 138000]
#
# 하이라이트 	 99012 	 89
# 이상치 제거 [ 392380  369000  513290  390000  450000  990000  369000  399000  380000
#  2480000  369000]
#
# 털신 	 22792 	 89
# 이상치 제거 [ 75900 127160 100720  73800  99900 143550 132990 104320 159000  93900
#  129000]
#
# 머니클립 	 89239 	 96
# 이상치 제거 [562000 999000 879000 589150]
#
# 수경식물 	 7116 	 97
# 이상치 제거 [26900 23000 22900]
#
# 식이섬유 	 22186 	 96
# 이상치 제거 [62610 71700 71700 69300]
#
# 프라이머 	 23279 	 95
# 이상치 제거 [66500 70800 71060 81100 72670]
#
# 튀김류 	 9266 	 93
# 이상치 제거 [21590 28830 36940 28530 37900 28970 36710]
#
# 건강팔찌 	 75755 	 93
# 이상치 제거 [396300 396270 411510 402320 672000 600000 351650]
#
# 발마사지기 	 156256 	 95
# 이상치 제거 [399000 439000 408000 600000 437990]
#
# 아이브로 	 8336 	 92
# 이상치 제거 [27930 31540 27840 24790 28000 27460 25040 28000]
#
# 염료 	 5223 	 91
# 이상치 제거 [20000 16500 42500 13950 15000 31560 15540 27800 20820]
#
# 화분영양제 	 14498 	 98
# 이상치 제거 [53000 97400]
#
# 승용완구 	 83489 	 95
# 이상치 제거 [299000 640770 324830 405570 698000]
#
# 인삼 	 20846 	 89
# 이상치 제거 [ 69000  72000 145000 198000 119000 100000 130000  80980  97330 153990
#   73330]
#
# 남성화장품세트 	 33258 	 92
# 이상치 제거 [ 95800  95970 100440 148230  90900 117180  96810 152000]
#
# 스무디 	 12446 	 91
# 이상치 제거 [ 42800  51000  34900  45800  51590  32000 141000  50320  36000]
#
# 댄스소품 	 38501 	 92
# 이상치 제거 [795000 172970 151690 217340 260100 724760 264000 222020]
#
# 블루투스동글 	 7002 	 90
# 이상치 제거 [69900 59900 18500 40050 37900 33410 61900 30000 88860 37550]
#
# 컨실러 	 15114 	 98
# 이상치 제거 [57800 53900]
#
# 냉풍기 	 94865 	 91
# 이상치 제거 [590000 329130 440000 542900 358000 359000 358000 358000 379000]
#
# 발지압 	 14305 	 92
# 이상치 제거 [ 79000 880000  51300  70000  54910  64730  69510  56660]
#
# 손목받침대 	 14188 	 95
# 이상치 제거 [55000 79000 46000 49000 88000]
#
# 축구연습용품 	 30871 	 94
# 이상치 제거 [237590 265500 129080 151090 469300 198000]
#
# 된장 	 18150 	 96
# 이상치 제거 [60190 52360 50900 55000]
#
# 아동시계 	 14525 	 92
# 이상치 제거 [52540 48720 47340 55000 59000 52270 55370 49000]
#
# 핸드블렌더 	 50791 	 94
# 이상치 제거 [139800 215990 149800 216000 147000 159800]
#
# 공기정화식물 	 19052 	 95
# 이상치 제거 [ 153000 4800000  140000  103000   79000]
#
# 압축팩 	 7096 	 88
# 이상치 제거 [44690 68000 38900 69500 59800 47040 59000 40660 89000 37900 36490 39800]
#
# 살림 	 7372 	 89
# 이상치 제거 [34000 31900 25600 34300 26900 28000 29800 24900 24780 24510 23770]
#
# 홑이불 	 21439 	 97
# 이상치 제거 [ 65670 137830 169630]
#
# 쓰레받기 	 8225 	 95
# 이상치 제거 [39900 44900 29700 24700 32160]
#
# 우체통 	 24662 	 93
# 이상치 제거 [ 77900  72840  79000 110000  72590  80000  70290]
#
# 반죽기 	 256835 	 97
# 이상치 제거 [1300000 1300000 1650000]
#
# 버티컬 	 29379 	 90
# 이상치 제거 [ 153220 1605180  324470  180400  921290  169840  299720  426590  797630
#   155000]
#
# 브랜드PC 	 770977 	 95
# 이상치 제거 [2840500 6490000 2590000 4599000 2429000]
#
# 노트북보안기 	 25045 	 97
# 이상치 제거 [57410 51480 55550]
#
# 마스카라 	 11280 	 92
# 이상치 제거 [32000 32250 37394 37394 34517 49900 37480 33079]
#
# 발보호대 	 4861 	 94
# 이상치 제거 [18900 19800 19800 20580 23800 50730]
#
# 테니스가방 	 60236 	 94
# 이상치 제거 [222080 976000 155990 158000 239000 148780]
#
# 위생마스크 	 9547 	 94
# 이상치 제거 [56100 35800 56100 52000 60500 31100]
#
# 찜질기 	 37039 	 96
# 이상치 제거 [150000  85000 139000 125000]
#
# 영상플레이어 	 112906 	 99
# 이상치 제거 [443500]
#
# 캠핑왜건 	 94935 	 100
# 이상치 제거 []
#
# 티켓 	 78176 	 99
# 이상치 제거 [280000]
#
# 양주 	 79315 	 86
# 이상치 제거 [ 457900  619000  389900 4580000  467000 5549000  337800  339400  310000
#   319500  315500  458300  337700 1230000]
#
# 오디오믹서 	 371450 	 89
# 이상치 제거 [3299990 3880000 2749990 2546650 3619990 4689900 2436000 1950000 1950000
#  5199990 2500000]
#
# 목욕비누 	 8197 	 90
# 이상치 제거 [59770 65200 59770 64700 64900 64700 34900 65000 62040 63000]
#
# 돼지고기 	 15162 	 97
# 이상치 제거 [50000 52000 56000]
#
# 복근운동기구 	 26026 	 93
# 이상치 제거 [109000 260000  89000 139000 260000  91100  92070]
#
# 가정용게임기 	 358280 	 100
# 이상치 제거 []
#
# 가구설치 	 31283 	 96
# 이상치 제거 [190000 350000 668200 400970]
#
# 정원그네 	 185078 	 96
# 이상치 제거 [ 762290  621970  808000 1018900]
#
# 롤스크린 	 10290 	 90
# 이상치 제거 [148900 148900  49900  49010 135000  81750  40040  56000  78560  40800]
# 탈수기 	 88555 	 98
# 이상치 제거 [208030 227290]
#
# 묘목 	 19331 	 97
# 이상치 제거 [ 75000 100000  94770]
#
# 선글라스케이스 	 7964 	 98
# 이상치 제거 [53000 32650]
#
# 모서리보호대 	 4907 	 94
# 이상치 제거 [20140 26970 28000 28000 23220 21680]
#
# 안경케이스 	 6677 	 96
# 이상치 제거 [34000 35442 34960 27300]
#
# 놀이방매트 	 48581 	 92
# 이상치 제거 [287030 309000 479000 409000 225000 219000 363970 328970]
#
# 기포 	 19935 	 89
# 이상치 제거 [69400 52500 70900 70900 99000 55000 53520 53360 48600 75000 77900]
#
# 탈모케어 	 21299 	 93
# 이상치 제거 [79000 82000 59690 59000 56650 99000 98700]
#
# 보행기 	 98013 	 100
# 이상치 제거 []
#
# DVR 	 224934 	 95
# 이상치 제거 [1506500  757000 1464200 2400000 1321600]
#
# 풋케어 	 10035 	 92
# 이상치 제거 [32000 27000 28200 28410 28100 26400 29900 29900]
#
# 자동차TV 	 183565 	 92
# 이상치 제거 [ 920000  890000  790000  790000  800000  930750 1100000  697500]
#
# 외장SSD 	 89375 	 94
# 이상치 제거 [343000 310000 336000 575000 314000 575000]
#
# 사전 	 194123 	 99
# 이상치 제거 [755000]
#
# 모니터어댑터 	 7112 	 84
# 이상치 제거 [15000 14000 27440 17800 24500 14900 17300 17110 16000 16000 18000 13860
#  13860 13720 15800 13860]
#
# 사운드카드 	 117925 	 94
# 이상치 제거 [1430000  599000 1430000  578000 2790000 1450000]
#
# 발목보호대 	 21106 	 93
# 이상치 제거 [ 72000 128000  75000  97000 185000  72000 134000]
#
# 공포 	 17539 	 93
# 이상치 제거 [ 77680 132790  67770 111500 368600 126300 144500]
#
# 마네킹 	 30771 	 93
# 이상치 제거 [128880 117870 109400 109560 122500 133220 105110]
#
# 남아수영복 	 31539 	 96
# 이상치 제거 [69420 75050 70180 84990]
#
# 보드복 	 125776 	 98
# 이상치 제거 [499000 390150]
#
# 무용 	 23731 	 95
# 이상치 제거 [59900 83290 60000 60000 61100]
#
# 웹캠 	 41773 	 87
# 이상치 제거 [ 170440  189580 1163750 1148560  157260  339000  449000  328570  542060
#   429000  397990  755700  185000]
#
# 세탁망 	 3490 	 89
# 이상치 제거 [11400 11400 13900 20900 29000 11710 14000 13710 14200 12900 14900]
#
# 쌍안경 	 97092 	 91
# 이상치 제거 [ 470000 1001000 1249970  595160 2964000 3431750 3770000  882700  667500]
#
# 유아식기 	 17797 	 93
# 이상치 제거 [53830 57200 69000 59000 52650 69900 68000]
#
# 유아컵 	 16519 	 99
# 이상치 제거 [41490]
#
# 농구공 	 29987 	 96
# 이상치 제거 [ 98900  99000 198000  99000]
#
# 진공포장기 	 74012 	 91
# 이상치 제거 [ 294000 1650000  264000  880000  880000  270480  454900  363440  880000]
#
# 식기세척 	 669283 	 100
# 이상치 제거 []
#
# 잡지꽂이 	 37664 	 95
# 이상치 제거 [113990 127000 116620 107901 125830]
#
# 체중계 	 27682 	 90
# 이상치 제거 [ 200000  341000   99000  379500 2850000  139000  237200   76230   74900
#   269000]
#
# 건반악기 	 584148 	 94
# 이상치 제거 [4350000 7790000 4580000 3078000 6280000 6800000]
#
# 법 	 15909 	 83
# 이상치 제거 [230000  37800  36000 163300 168700 156400 133940 133940  83330  83330
#   36000  73480  73480  99200  99200  80570 519980]
#
# 글씨 	 4897 	 92
# 이상치 제거 [ 32000  27050  95120 489930  63170  22700  99000 136700]
#
# 코코아 	 9388 	 97
# 이상치 제거 [89790 35900 35440]
#
# 떡볶이 	 7062 	 90
# 이상치 제거 [26240 32030 19740 19800 22630 32580 23470 22000 33330 23900]
#
# 자갈 	 8234 	 95
# 이상치 제거 [155700  75000 100000  83000  33660]
#
# 밀가루 	 18024 	 98
# 이상치 제거 [ 75000 225300]
#
# 헌팅캡 	 39911 	 99
# 이상치 제거 [153210]
#
# 온수기 	 114724 	 89
# 이상치 제거 [279000 312000 289000 575000 308000 282900 283890 338580 420000 275040
#  663900]
#
# 여아수영복 	 31310 	 95
# 이상치 제거 [ 72090  65900 119000  66400  67500]
#
# 스프레드 	 62985 	 94
# 이상치 제거 [172190 172970 216240 223170 207000 184140]
#
# 시계수리용품 	 5366 	 92
# 이상치 제거 [ 23800  27050  27400  34900  69000 124000  38700  27520]
#
# 바디케어세트 	 41875 	 99
# 이상치 제거 [122760]
#
# 휴대폰젠더 	 5775 	 87
# 이상치 제거 [26930 59170 30000 23600 40910 47900 28000 22500 28000 24300 21250 38000
#  54900]
#
# 테니스공 	 57287 	 100
# 이상치 제거 []
#
# 수초 	 5046 	 94
# 이상치 제거 [59700 14480 14750 15790 15000 17150]
#
# 에어브러시 	 44077 	 96
# 이상치 제거 [389000 106800 184300 110000]
#
# 젖병 	 21333 	 91
# 이상치 제거 [53010 65700 60500 94500 57600 48100 79290 80400 79900]
#
# 전동휠 	 857159 	 95
# 이상치 제거 [3600000 3808800 4280000 3490000 4250000]
#
# 턱받이 	 11487 	 99
# 이상치 제거 [39500]
#
# 탁구라켓 	 127733 	 95
# 이상치 제거 [1200000  790000  490000  685000  491200]
#
# 아이라이너 	 8437 	 92
# 이상치 제거 [23860 29140 23380 26900 23400 25300 22950 22490]
#
# 풋살화 	 74827 	 98
# 이상치 제거 [190260 185000]
#
# 기능성음료 	 13238 	 94
# 이상치 제거 [ 61900 159000  67000  67000  61000  60960]
#
# 다리보호대 	 18513 	 97
# 이상치 제거 [99000 84900 69000]
#
# 건어물 	 19308 	 98
# 이상치 제거 [67000 84000]
#
# 치실 	 7497 	 99
# 이상치 제거 [32500]
#
# 먼지떨이 	 6437 	 91
# 이상치 제거 [28190 27240 27250 46000 33500 38900 36410 33500 24250]
#
# 순금주얼리 	 1335569 	 91
# 이상치 제거 [7421000 4500000 4799000 5633240 5143720 5491590 5512590 6562600 5512590]
#
# 샌드백 	 55955 	 89
# 이상치 제거 [217500 350000 586920 321380 246790 204250 272780 216700 342890 204240
#  352910]
#
# 악기놀이 	 35356 	 93
# 이상치 제거 [226580 389500 255060 371730 309730 198600 155520]
#
# 건축 	 21110 	 93
# 이상치 제거 [ 69990  69000  67460  90990 106000  96560  89720]
#
# 팝콘 	 9210 	 96
# 이상치 제거 [ 40000  88010 181490  44500]
#
# 테이프클리너 	 11304 	 96
# 이상치 제거 [32000 31800 35900 31160]
#
# 가베 	 24285 	 86
# 이상치 제거 [162710 499900 349000  96200 159900 179500 216600 154990 139000 293390
#  109700 135000 619990 129000]
#
# 해산물 	 14281 	 98
# 이상치 제거 [42000 59000]
#
# 헤드유닛 	 187890 	 95
# 이상치 제거 [ 841190  733300 1200000  733300 1106670]
#
# 위생도기 	 185835 	 94
# 이상치 제거 [1138000  549900  632100 1130000  718440  538200]
#
# 모니터암 	 60231 	 93
# 이상치 제거 [460000 189000 189000 180000 319000 390000 189000]
#
# 휴대용게임기 	 232157 	 94
# 이상치 제거 [ 999000 1290000 1199900 1699000 1130000  990000]
#
# 스페인 	 1472693 	 100
# 이상치 제거 []
#
# 휠체어 	 132093 	 89
# 이상치 제거 [ 994100  590000  497000 1610000 1077820  829600 1340000  578000 1999000
#   902070  651000]
#
# 인테리어분수 	 65644 	 88
# 이상치 제거 [ 297680  334240  344380  319790 1317630 1367500  450000  504900  443500
#   867900 1149880  400700]
#
# 전방 	 58238 	 84
# 이상치 제거 [330000 330000 330000 519200 519200 350000 380000 575000 453910 290320
#  505280 451720 344950 531900 229800 475200]
#
# 테니스화 	 99768 	 100
# 이상치 제거 []
#
# 식초 	 8765 	 91
# 이상치 제거 [82500 38700 38000 49900 38300 66950 62410 48240 78000]
#
# 에어프라이어 	 130239 	 92
# 이상치 제거 [339000 399000 399000 439000 368000 533950 331200 385900]
#
# 스위칭허브 	 64993 	 89
# 이상치 제거 [622920 290000 506650 380400 495000 649470 769470 253000 275000 296400
#  390000]
#
# 제습기 	 220792 	 99
# 이상치 제거 [864990]
#
# 어린이자전거 	 196211 	 100
# 이상치 제거 []
#
# 농구의류 	 22754 	 93
# 이상치 제거 [ 60000 126900  66700  64350  73500  53730  53820]
#
# 오트밀 	 13217 	 99
# 이상치 제거 [45230]
#
# 피부케어기기 	 153381 	 87
# 이상치 제거 [1275990 1430000 2320000  735000  680000 1430000 1540000 2350000 1400000
#  1590000 1799000 1998000 1400000]
#
# 스포츠헤어밴드 	 8703 	 100
# 이상치 제거 []
#
# 베개솜 	 15739 	 94
# 이상치 제거 [48000 71750 48930 55670 52200 49820]
#
# 부채 	 4983 	 93
# 이상치 제거 [29700 21760 25760 30800 22320 24900 26250]
#
# 복대 	 8178 	 94
# 이상치 제거 [33000 21000 87500 35000 24000 21000]
#
# 헤어팩 	 18846 	 95
# 이상치 제거 [ 80000  90000  74000 140000  80000]
#
# 반신욕용품 	 15897 	 89
# 이상치 제거 [ 74300  69900  53800 121400 157100  54940 118550  61740  63510 136660
#   70900]
#
# 미니화분 	 9884 	 99
# 이상치 제거 [49000]
#
# 보일러 	 467760 	 100
# 이상치 제거 []
#
# 모종 	 6307 	 97
# 이상치 제거 [22000 30000 25000]
#
# 축구가방 	 33850 	 94
# 이상치 제거 [ 73900 149000  91560  99800 161595 119000]
#
# 네임태그 	 6898 	 99
# 이상치 제거 [31990]
#
# 헤어에센스 	 18583 	 93
# 이상치 제거 [ 55000 146000  62770  90970  58270 198000  60900]
#
# 쿠션솜 	 6694 	 91
# 이상치 제거 [24880 28370 23775 37000 27540 39200 63200 18260 25030]
#
# 셀카봉 	 24585 	 98
# ...
#  228200 673000]
# 모터 	 41738 	 92
# 이상치 제거 [ 267340 3500000  256440  461850  195500 4000000  422400  220000]
#
# 냄비 	 51947 	 94
# 이상치 제거 [247740 199570 170000 247740 438000 422280]
#
# 태블릿 	 536565 	 99
# 이상치 제거 [1918000]
#
# 간식 	 9415 	 93
# 이상치 제거 [59900 46700 77900 39500 50000 39210 56900]
#
# 원예공구 	 27401 	 84
# 이상치 제거 [158000 148000 237600 168300 148000 178000 198000 271160 229400 148000
#  168000 169000 138290 149000 169460 179000]
#
# 테이프 	 5220 	 86
# 이상치 제거 [29500 29000 39000 38000 34300 30400 45350 43800 30400 39500 36500 59400
#  34500 38300]
#
# 뷰티 	 8787 	 89
# 이상치 제거 [28790 29900 28800 42900 32940 28000 28900 51800 27000 34900 57750]
#
# 리빙 	 40431 	 93
# 이상치 제거 [129260 119000 112000 112290 169000 113990 120000]
#
# 헤어액세서리 	 5669 	 97
# 이상치 제거 [ 19800  41400 309820]
#
# 자수 	 12926 	 96
# 이상치 제거 [63000 45700 46000 61620]
#
# 충전기 	 28006 	 87
# 이상치 제거 [ 88900 214000 135060 109700  90510 169700 169000 134000  82700  89900
#   99700 139000 199000]
#
# 프라모델 	 57102 	 90
# 이상치 제거 [ 416000  157000  383000  177800  200000  360000 4539600  177990  179900
#   182000]
#
# 골프클럽 	 734752 	 97
# 이상치 제거 [2430000 2350000 3520000]
#
# 브라 	 17777 	 93
# 이상치 제거 [57800 54920 89910 72820 72820 72820 71910]
#
# 휠 	 192993 	 83
# 이상치 제거 [1400000  560000  770000  770000  660000  990000 3660000 1560000  650000
#   600000 3500000 1500000  560000  850000  600000  770000  850000]
#
# 복합기 	 232187 	 94
# 이상치 제거 [ 639000 1889250  659000 2744800  648970  999000]
#
# 미술 	 4942 	 91
# 이상치 제거 [37220 25500 25830 24870 31570 24030 46000 38000 27000]
#
# 악기 	 311537 	 94
# 이상치 제거 [1439000 1820000 1398000 2280000 1238000 1629990]
#
# 등산의류 	 67371 	 95
# 이상치 제거 [312000 360100 167230 296000 259340]
#
# 캠코더 	 532252 	 90
# 이상치 제거 [ 5030060  4414830  8178070  7946400 14287000  4089970  7480000  8074020
#   5050000  3900000]
#
# 메이크업 	 19398 	 94
# 이상치 제거 [65000 61490 69000 59400 70200 58800]
#
# 프린터소모품 	 13791 	 87
# 이상치 제거 [111250  72500  55000  68000 154400  60000  78480 111850 155880 330000
#  495000 182990 218460]
#
# 팔찌 	 329608 	 89
# 이상치 제거 [ 2040000 18089000 12649000  2198000  7690000  2287500  5590000  2376000
#   4015000  2332500  1590000]
#
# 필기도구 	 10659 	 91
# 이상치 제거 [135000 160000  52500 110940  74110  52500  84020 305000  56610]
#
# 패션시계 	 134628 	 83
# 이상치 제거 [ 3680000  1097000  6000000  7500000  1476000 12000000 11100000  1360000
#  21000000 87000000  8200000 18900000  6900000  5200000  1496000  4500000
#  22000000]
#
# 오토바이용품 	 64742 	 97
# 이상치 제거 [205000 250000 219000]
#
# 고양이건강 	 21423 	 93
# 이상치 제거 [59520 62200 61000 57600 57600 88900 59000]
#
# 캐릭터 	 9065 	 94
# 이상치 제거 [29800 69800 32900 64000 41170 39900]
#
# 토트백 	 141410 	 81
# 이상치 제거 [3845000 2930000 1130000 2790000 1833000 4698000 3335000 2300000  978700
#   983570 1180000 4823450 3259000  829150 2250000 1480000 6474450 1360000
#  1375000]
#
# 거울 	 42411 	 96
# 이상치 제거 [199000 149000 149000 149000]
#
# 자전거용품 	 23278 	 88
# 이상치 제거 [1080000   99000  119000  248000   89000  449000  217000  308000  111500
#    95000   93000  299000]
#
# 식탁 	 176928 	 94
# 이상치 제거 [1350000  629000  629000  778000 1701000  788000]
#
# 패션용품 	 21355 	 98
# 이상치 제거 [91040 68540]
#
# 홈웨어 	 17206 	 97
# 이상치 제거 [74900 41800 41800]
#
# 칼 	 74968 	 95
# 이상치 제거 [ 490600  680000 1020200  325000  997000]
#
# 장갑 	 19204 	 97
# 이상치 제거 [ 85000 113000 198000]
#
# 모형 	 24710 	 88
# 이상치 제거 [111870 253000 129000 160000 111100 227060 133980 329200  99650 272880
#  186500 188500]
#
# 노트 	 4672 	 93
# 이상치 제거 [ 25600 300000  24000  18000  19200  21700  17100]
#
# 보드용품 	 45020 	 81
# 이상치 제거 [226740 179200 927550 146700 269050 270000 544500 179000 263640 169000
#  228300 233100 192990 276700 892000 150780 635420 214320 150780]
#
# 손잡이 	 7626 	 94
# 이상치 제거 [50000 26320 55000 38000 38000 37000]
#
# 시트 	 43133 	 92
# 이상치 제거 [ 600000  177800  600000 4400000  177800  258000  450000  198000]
#
# 귀걸이 	 37026 	 95
# 이상치 제거 [ 295489  535060  282830 3525510  802500]
#
# RC 	 50123 	 91
# 이상치 제거 [ 248610  179000  332120  460000 1173700  161400  373450  537800  189150]
#
# 소파 	 357542 	 90
# 이상치 제거 [3397500 1560000 2021000 1980000 1346370 2793210 1946500 1492500 1754400
#  2872800]
#
# 스웨터 	 47236 	 91
# 이상치 제거 [ 250290  242190  279000  246240  206390  274590 1514240  319000  269100]
#
# 팬티 	 8733 	 90
# 이상치 제거 [53320 80000 36930 33910 50910 39970 41760 79900 39360 41900]
#
# 골프의류 	 52800 	 91
# 이상치 제거 [132900 223700 149400 150000 189750 165760 149800 148500 133000]
#
# 오토바이부품 	 39927 	 93
# 이상치 제거 [1262000  230000  883500 1391020  350000  449800  381000]
#
# 카디건 	 59924 	 90
# 이상치 제거 [299000 287100 287100 289220 287100 358900 287100 282900 287100 287100]
#
# 게임 	 14804 	 95
# 이상치 제거 [99200 59100 96600 51590 76290]
#
# 양말 	 4692 	 97
# 이상치 제거 [16900 16830 17990]
#
# 블라우스 	 37015 	 97
# 이상치 제거 [104040 139000 133540]
#
# 정리함 	 12897 	 96
# 이상치 제거 [79000 72000 69900 54900]
#
# 취미 	 12560 	 95
# 이상치 제거 [34800 49500 36900 38900 39900]
#
# 백팩 	 66912 	 92
# 이상치 제거 [ 257760  260610  374490  193600  260610  288990 1238500  244940]
#
# 목걸이 	 168952 	 88
# 이상치 제거 [1710000 1089000 2539000 3979000  899000 3299000 4409000  750000  755480
#  1368000 1280000 2390000]
#
# 프린터 	 148888 	 95
# 이상치 제거 [ 679000  499000 1169000  549000  679000]
#
# 구두 	 77457 	 94
# 이상치 제거 [206410 533000 399290 576030 200070 621530]
#
# 업소용 	 18857 	 87
# 이상치 제거 [ 82320 195000  92000  81000  69900 175000 255000 640000  97000  99000
#  550000  97800  79900]
#
# 트레이닝복 	 40296 	 95
# 이상치 제거 [160650 115370 128000 107650 139000]
#
# 젤리 	 9436 	 93
# 이상치 제거 [36900 28900 28900 29480 28200 31400 31200]
#
# 점퍼 	 64020 	 97
# 이상치 제거 [283050 189000 404190]
#
# 파티용품 	 15860 	 93
# 이상치 제거 [169700  69000 212000 121100 169000  69000 218000]
#
# 파우치 	 7858 	 91
# 이상치 제거 [ 49800  33150  30000  89000 409000  86300 661000 119000 313400]
#
# 스킨 	 17275 	 94
# 이상치 제거 [ 62790 128700  55600  42670  55000  51990]
#
# 코트 	 107010 	 89
# 이상치 제거 [ 639000  342510  769020  636300  741240  649080  446880  365840  377370
#  2470000 3923150]
#
# 밀폐용기 	 13559 	 87
# 이상치 제거 [ 80080  89900  71900 103600 106650 123520  69000 169000 147230 155770
#  151900 105140 114500]
#
# 보호필름 	 9535 	 98
# 이상치 제거 [39900 39900]
#
# 정장 	 95667 	 98
# 이상치 제거 [262980 280000]
#
# 숄더백 	 112309 	 91
# 이상치 제거 [ 968000 1381960 1221000 2402550 1683500 1890000 2429000 1368000 1263100]
#
# 이벤트 	 14892 	 90
# 이상치 제거 [169700  62000 121100 212000 299000 169000 218000 158400 109000 158000]
#
# 그림 	 22066 	 94
# 이상치 제거 [ 74800  89000  85000  83470 198000 179000]
#
# 측정공구 	 96345 	 93
# 이상치 제거 [428600 363000 317900 389620 364150 360000 495000]
#
# 오일 	 16201 	 91
# 이상치 제거 [143680  64880  75890  54000  53240  96340  46500 112200  54710]
#
# 벨트 	 47598 	 87
# 이상치 제거 [268840 294800 274000 359000 338097 294900 294800 286000 215100 519000
#  385770 268820 354400]
#
# 조끼 	 28750 	 90
# 이상치 제거 [104040 115470  99000  99000 119520  89900 129000 266200 259880 136000]
#
# 슬리퍼 	 35663 	 93
# 이상치 제거 [133120 138000 125000 178000 139800 162600 178000]
#
# 소모품 	 33707 	 88
# 이상치 제거 [685870 453260 324720 203180 376960 655680 871430 196320 165490 161150
#  346670 193310]
#
# 커피 	 15702 	 93
# 이상치 제거 [41000 40100 41920 45050 40840 41580 38580]
#
# 영양제 	 17784 	 89
# 이상치 제거 [47000 48310 46220 45450 48500 77910 69560 49890 87000 44700 52500]
#
# 퍼즐 	 12036 	 93
# 이상치 제거 [ 52400  35000  36000  52400 107300  37320  40160]
#
# 야외용품 	 52857 	 93
# 이상치 제거 [202570 369000 235000 276920 253930 831590 664900]
#
# 출산 	 41821 	 100
# 이상치 제거 []
#
# 부츠 	 81161 	 100
# 이상치 제거 []
#
# 꽃 	 9614 	 84
# 이상치 제거 [ 58000  45000  52900  59000  55000  44900  47000  52000  59000  52900
#  299000  69900  59000 111000  66900  52900]
#
# 전자 	 110493 	 100
# 이상치 제거 []
#
# 주방잡화 	 7515 	 89
# 이상치 제거 [ 39800  38600  41000  30000  39800  38790 352000  38790  39800  45990
#   38900]
#
# 사진 	 19382 	 94
# 이상치 제거 [ 74800  89000  85000  83470 101650 198000]
#
# 배터리 	 46641 	 94
# 이상치 제거 [193000 185000 188000 312550 167880 219000]
#
# 청바지 	 37135 	 97
# 이상치 제거 [ 97308 114480 128000]
#
# 장식소품 	 16074 	 94
# 이상치 제거 [272200  62720  69860  66123  85340  79155]
#
# 안전용품 	 17015 	 91
# 이상치 제거 [104000 122816 105000  86000  91500 207900 274730  93000  82500]
#
# 책상 	 112749 	 91
# 이상치 제거 [ 389000  689000  629000  709000 1100000  665000  338000  559000  389000]
#
# 지갑 	 112983 	 89
# 이상치 제거 [540000 550000 890000 546000 588900 955000 546000 998000 927000 593100
#  540000]
#
# 샌들 	 55467 	 92
# 이상치 제거 [264600 322065 809370 316480 440700 632960 809370 450528]
#
# 액자 	 21027 	 94
# 이상치 제거 [ 74800  89000  83470 179000  85000 149150]
#
# 크로스백 	 115315 	 82
# 이상치 제거 [ 928000  848000 1199000 1713190  847500 2310000  999000 3720000  937000
#   976000  887000 1059000 3162000 1352000 1570000 1549000 1759000 1550000]
# 단화 	 60877 	 95
# 이상치 제거 [348290 676445 170240 178500 502990]
#
# 침대 	 578331 	 92
# 이상치 제거 [3608700 2208100 2825800 2932500 4209000 2525720 2224370 2159700]
#
# 전동공구 	 96196 	 95
# 이상치 제거 [268000 277000 280500 269000 368000]
#
# 필름 	 14918 	 97
# 이상치 제거 [105000  37000 145000]
#
# 선반 	 19958 	 93
# 이상치 제거 [ 55500 147130  69900 193000  66000  65000  59710]
#
# 쿠션 	 23797 	 100
# 이상치 제거 []
#
# 램프 	 13891 	 83
# 이상치 제거 [  89000   72000   91430   89250  151000   93770  113000   84000   99000
#   117000  181000   89000  109000 1073900  250710   90000   89000]
#
# 강아지건강 	 28250 	 94
# 이상치 제거 [149000  91680  62700  87300  64950  91680]
#
# 헤드 	 79212 	 95
# 이상치 제거 [415130 692800 389000 573660 439000]
#
# 스니커즈 	 93982 	 93
# 이상치 제거 [ 427850  888000  863600  369600 1470000 2390000  898000]
#
# 건강식품 	 28799 	 91
# 이상치 제거 [119990 159000 189000  99000 109020 329000  99000 765490  99000]
#
# 스커트 	 40648 	 95
# 이상치 제거 [118620 129060 106000 100550 138600]
#
# 컵 	 18289 	 98
# 이상치 제거 [58990 70690]
#
# 스쿠터 	 3539937 	 93
# 이상치 제거 [11858690 10699970  8740000  9090000 17204000  9590000 15800000]
#
# 튜닝용품 	 37891 	 81
# 이상치 제거 [  400000   310000   278630   290000  2390000   539000   320000   203910
#    220000   500000   400000  1200000   217500   250000 83578000  1400000
#    800000   800000  1998000]
#
# 헤어 	 15261 	 97
# 이상치 제거 [146000  53820  58000]
#
# 청소 	 11972 	 92
# 이상치 제거 [ 34100  48000  39800  98000  39800 129000  33900  34900]
#
# 카메라 	 44922 	 90
# 이상치 제거 [2669990  751940  348000  290000  988000  692000 1058000  948890 2509000
#   378000]
#
# 식기 	 36291 	 86
# 이상치 제거 [ 403090  266250  274670 1092150  196600  249900  189890  263200  298320
#   413100  244310  371780  287550  299000]
#
# 스티커 	 3874 	 97
# 이상치 제거 [29900 19900 21900]
#
# 의자 	 112934 	 92
# 이상치 제거 [ 869000  496000 2108000 1139064  589000  672000  990000  780000]
#
# 생활소품 	 13228 	 95
# 이상치 제거 [56900 79000 69900 78000 74900]
#
# 노트북 	 1255910 	 98
# 이상치 제거 [3668670 4990000]
#
# 시계 	 158661 	 89
# 이상치 제거 [ 1097000  3680000 21000000  1476000  7500000  6900000 11100000  1360000
#   6000000  4500000  1496000]
#
# 운동화 	 70458 	 99
# 이상치 제거 [275000]
#
# 스탠드 	 27320 	 85
# 이상치 제거 [  93770  137900  151000  113000  135020  110000  110000  379000  289000
#   145000  189000   99000 1285900  142000  138000]
#
# 스트링 	 12553 	 89
# 이상치 제거 [179000  79000 149000 115430  74890 109000 132050  55900 209000  92000
#   72680]
#
# 에어 	 84717 	 99
# 이상치 제거 [345000]
#
# 주변기기 	 81694 	 100
# 이상치 제거 []
#
# 여행 	 457951 	 83
# 이상치 제거 [2199000 2418000 2545500 2762900 2063000 3494100 3162900 2643600 1848300
#  3084000 3488100 2498200 2078300 4594900 3500300 2700000 2299000]
#
# 카드 	 55637 	 88
# 이상치 제거 [540000 304470 489000 478900 550000 395000 630000 370000 395000 890000
#  546000 475000]
#
# 오토바이 	 3502426 	 89
# 이상치 제거 [44000000 44456520 27065210 15500000 16700000 37550000 23990000 21900000
#  16830000 44297820 15950000]
#
# 기계 	 70979 	 93
# 이상치 제거 [ 607740  583090  460660  637692 1251600  546950  399000]
#
# 언더웨어 	 34519 	 89
# 이상치 제거 [128000 128180 134910 134910 143910 138200 134910 129530 124140 121520
#  129900]
#
# 보드 	 353558 	 96
# 이상치 제거 [2949000 2449000 1500000 1990000]
#
# 자전거 	 975693 	 92
# 이상치 제거 [ 5525000 13855000  4440000  9095000  8330000 18500000  8850000  4690000]
#
# 생활잡화 	 15801 	 96
# 이상치 제거 [69900 92900 77900 75000]
#
# 팩 	 12826 	 97
# 이상치 제거 [53000 59000 69000]
#
# 패드 	 45249 	 84
# 이상치 제거 [1388990  595000  674950  870500 1079000 1998000  801960  391390  421330
#  1599000  658980 1127610 1274000  498970  545000  600550]
#
# 매트 	 25233 	 91
# 이상치 제거 [109000  99000 139000 179000  89300  88000  99000 169000 139000]
#
# 수작업공구 	 6135 	 91
# 이상치 제거 [ 48770  46300 140800  75500  42930  47700  34900  31800 184000]
#
# 모자 	 26595 	 97
# 이상치 제거 [82800 99000 79000]
#
# 테이블 	 95067 	 96
# 이상치 제거 [379000 368000 498000 398000]
#
# 보관 	 10198 	 91
# 이상치 제거 [ 80080 123520  56130 169000  89900  62000  63900  51390  71900]
#
# 조명 	 20041 	 90
# 이상치 제거 [160000  77000 110000 132050  96000  91430 215000  98990  90000 310000]
#
# 수납용품 	 12810 	 94
# 이상치 제거 [79000 69900 72000 72000 49000 71900]
#
# 기타 	 319549 	 94
# 이상치 제거 [1257510  919990  990000  990000 1160000 1008000]
#
# 손 	 46519 	 91
# 이상치 제거 [145500 148000 175000 159800 234700 145300 163390 201850 189280]
#
# 무선 	 152923 	 98
# 이상치 제거 [692800 639000]
#
# 홀더 	 5306 	 97
# 이상치 제거 [19500 33600 34650]
#
# 패션소품 	 25708 	 87
# 이상치 제거 [219000 180790 183800 158000 734400 322500 379000 154800 309000 265000
#  389000 309000 394800]
#
# 니트 	 49872 	 95
# 이상치 제거 [148990 159000 159900 162000 148000]
#
# 재킷 	 79312 	 92
# 이상치 제거 [686510 499000 815450 475800 245000 758000 599000 326780]
#
# 전기용품 	 15921 	 95
# 이상치 제거 [138000  89000  87800  82400  79200]
#
# DIY용품 	 7141 	 94
# 이상치 제거 [ 62000 108000 149000  85810  49000 195000]
#
# 캠핑용품 	 125035 	 91
# 이상치 제거 [1679000  653570 1990000  989000 1449000  979000  633000  633000  591000]
#
# 면 	 24129 	 92
# 이상치 제거 [158000  66870  87880  86520 115580  87880  70730  77490]
#
# 드레스 	 69328 	 94
# 이상치 제거 [189000 199000 167800 179000 169000 200000]
#
# 원피스 	 80601 	 99
# 이상치 제거 [280180]
#
# 유아 	 27675 	 95
# 이상치 제거 [126540  93010  93010  94900  98900]
#
# 휴대용 	 24226 	 93
# 이상치 제거 [167880 148000 252190 148000 620000  98000 143000]
#
# 컴퓨터 	 654504 	 97
# 이상치 제거 [4599000 2429000 2211700]
#
# 휴대폰케이스 	 15217 	 95
# 이상치 제거 [34900 38900 34800 34900 63900]
#
# 미용 	 9771 	 98
# 이상치 제거 [37900 39990]
#
# 인테리어용품 	 15711 	 87
# 이상치 제거 [ 488000  490000  419000   79000  490000 2850000   79000  305000 1950000
#    95000  388000  890000 2500000]
#
# 어린이 	 42109 	 93
# 이상치 제거 [122550 109000 126540 125900 273600 128520 126540]
#
# 전기 	 14905 	 96
# 이상치 제거 [138000  79200  82400  89000]
#
# 바지 	 23852 	 89
# 이상치 제거 [72819 59130 87600 76869 81700 65860 68170 71910 69230 70312 58260]
#
# 커버 	 19559 	 97
# 이상치 제거 [ 80000 252000  69000]
#
# 문구용품 	 10258 	 95
# 이상치 제거 [135000 160000  52500  47900  69900]
#
# 사무용품 	 10766 	 96
# 이상치 제거 [137030  47330 135000 149000]
#
# 사무 	 56806 	 95
# 이상치 제거 [180700 170100 629520 669080 189230]
#
# 육아 	 63448 	 92
# 이상치 제거 [268000 620000 260000 390000 259000 640770 535000 550000]
#
# 케이스 	 14680 	 91
# 이상치 제거 [34900 34800 50200 84910 37900 80910 63900 39900 49210]
#
# 티셔츠 	 20150 	 91
# 이상치 제거 [158000  56619  54900 140000  81120  58900  85000  59900  53910]
#
# 셔츠 	 25695 	 91
# 이상치 제거 [ 189000  119900  169000   83952   88460 1346990  129240  153090   89000]
#
# 가방 	 70369 	 82
# 이상치 제거 [ 848000  660000  968000  928000 2930000  660000 1880000 3845000 2429000
#  1199000 1979000 1683500 2310000 3720000 1713190 3162000 2790000  887000]
#
# 신발 	 66961 	 97
# 이상치 제거 [348290 275000 676445]
#
# 건강 	 24904 	 91
# 이상치 제거 [  93500  718200  129000 1415500  153770  899100  119990  149000 1790000]
#
# 세트 	 34160 	 93
# 이상치 제거 [620000 147260 193000 403090 129000 139000 159200]
#
# 소품 	 22149 	 98
# 이상치 제거 [ 84700 170000]
#
# 액세서리 	 17490 	 84
# 이상치 제거 [ 78900  96000  79000  78900 369000 172240 278070 196000  79630  79000
#  214000 408260  99000 312550 329000  99000]
#
# 인테리어 	 24267 	 93
# 이상치 제거 [149000 170000  69000  84700 488000  99000  68900]
#
# 레저 	 101085 	 88
# 이상치 제거 [ 496910  398000  653570  899000 1679000  398000  850130 2650000  549350
#  1990000  435000  989000]
#
# 남성 	 30348 	 93
# 이상치 제거 [115370 119000 366000 943820 199000  99000 289220]
#
# 스포츠 	 113380 	 91
# 이상치 제거 [ 496910 1679000  653570  899000  850130 1990000 2650000  989000  549350]
#
# 가전제품 	 222308 	 88
# 이상치 제거 [1615000 1388990 1563480 1472500 1450000 1998000 1271100 1408810 1899400
#  1590000 1079000 1537090]
#
# 가전 	 204690 	 86
# 이상치 제거 [1615000 1563480 1388990  958330  962490 1450000 1472500 1998000 1899400
#  1271100 1590000 1408810 1079000 1103660]
#
# 잡화 	 49864 	 90
# 이상치 제거 [180790 387067 158000 183800 172500 152000 154800 362346 159000 188000]
#
# 의류 	 32334 	 91
# 이상치 제거 [116000 123990 149000 168445 158000 283050 135390 499000 172080]
#
# 여성 	 41623 	 90
# 이상치 제거 [231260 410850 161690 188000 287100 815450 640000 325890 404190 169000]
#
# 패션 	 43719 	 95
# 이상치 제거 [180790 142200 387067 183800 158000]
#
# 생활 	 18904 	 92
# 이상치 제거 [ 68900  79000 119640  99000  89100  69000  70000 105230]

# %%
len(avg_price)
# Out:
# 1612

# %%
data["avg_price"] = avg_price

# %%
data.to_csv("data/category/sorted_total_store1.csv",index=False)

# %%
data
# Out:
#      relative_keyword  total_search  total_store_count  competitive_rate  \
# 0                 제모제        1250.0            50115.0             40.09
# 1              유아세탁세제        1410.0            50365.0             35.72
# 2              기저귀휴지통        3200.0            50428.0             15.76
# 3                 카테킨       12470.0            50519.0              4.05
# 4                파우더통        1500.0            50724.0             33.82
# ...               ...           ...                ...               ...
# 1607               잡화        4600.0        240755648.0          52338.18
# 1608               의류        5360.0        266761395.0          49768.92
# 1609               여성        6830.0        273371280.0          40025.08
# 1610               패션       20730.0        423405866.0          20424.79
# 1611               생활        4650.0        467694995.0         100579.57
#
#       avg_price
# 0         15649
# 1         19351
# 2         32578
# 3         27531
# 4          8217
# ...         ...
# 1607      49864
# 1608      32334
# 1609      41623
# 1610      43719
# 1611      18904
#
# [1612 rows x 5 columns]

# %% [markdown]
# # TEST용

# %%
제모제 : 25127 : (77,)
유아세탁세제 : 26309 : (81,)
기저귀휴지통 : 32081 : (92,)
카테킨 : 33042 : (93,)
파우더통 : 22736 : (69,)
코인티슈 : 32081 : (92,)
업소용냉온풍기 : 40312 : (99,)
혈당계 : 40312 : (99,)
시서스 : 40312 : (99,)

# %%
import requests
import json

keyword = "파우더통"

cookies = {
    'NNB': '6TTK2RJU3JPWG',
    'autocomplete': 'use',
    'AD_SHP_BID': '23',
    '_ga': 'GA1.2.1198469368.1669035888',
    'NV_WETR_LOCATION_RGN_M': '"MDUxMTAxMTE="',
    'ASID': '6f5bbfa400000184fa368e5f00000067',
    'SHP_BUCKET_ID': '4',
    'NV_WETR_LAST_ACCESS_RGN_M': '"MDUxMTAxMTE="',
    'NID_AUT': 'xDAIttoc1Atdn7rAs4Y+rogecRjh3p1xevXbJnm0Nr0CEioRQ5/hhmRFwExAG7+T',
    'NID_JKL': 'b+0nlz0gwdbCoxClpc3utji+0en89OQHe0BEDbaUv/Y=',
    'nx_ssl': '2',
    'Viking_Rise_visit_time': '1695077035991',
    'page_uid': 'ifYbMdprvTVsse385PlssssssE0-160453',
    'spage_uid': 'ifYbMdprvTVsse385PlssssssE0-160453',
    'NID_SES': '...',
    'sus_val': 'oosk3W1yUa/jXC7KKHHcV8KC',
    'ncpa': '5114254|lnq2oiag|6088f8339ff87318d5466310aa33bd3df5f4ee8e|s_21a15037d5896|4a037b7e1ad4f4b2b46b7552bf557d83d6e09c69:4801924|lnq2r5yw|252c45b5b1c89d88d92fb4fd42bf99065652c3d4|s_1aec08c8356c9|4a0769694c3e60ffa7b878ff1e700b5ee7a31a93:95694|lnq2t46o|8f47110d725d91bc72e3083c0376c78965d77ffe|95694|28deee716df4986a1bc2f535eccb8e15165491ff:114|lnrg1u34|6c1e428c1fdcf6109a6e368afd36c2c6547842b5|s_1f0b6dd34481|0d9a8a153a4fd6f9e60247ee72a897423e0d11c7',
}

headers = {
    'authority': 'search.shopping.naver.com',
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    # 'cookie': 'NNB=6TTK2RJU3JPWG; autocomplete=use; AD_SHP_BID=23; _ga=GA1.2.1198469368.1669035888; NV_WETR_LOCATION_RGN_M="MDUxMTAxMTE="; ASID=6f5bbfa400000184fa368e5f00000067; SHP_BUCKET_ID=4; NV_WETR_LAST_ACCESS_RGN_M="MDUxMTAxMTE="; NID_AUT=xDAIttoc1Atdn7rAs4Y+rogecRjh3p1xevXbJnm0Nr0CEioRQ5/hhmRFwExAG7+T; NID_JKL=b+0nlz0gwdbCoxClpc3utji+0en89OQHe0BEDbaUv/Y=; nx_ssl=2; Viking_Rise_visit_time=1695077035991; page_uid=ifYbMdprvTVsse385PlssssssE0-160453; spage_uid=ifYbMdprvTVsse385PlssssssE0-160453; NID_SES=...; sus_val=oosk3W1yUa/jXC7KKHHcV8KC; ncpa=5114254|lnq2oiag|6088f8339ff87318d5466310aa33bd3df5f4ee8e|s_21a15037d5896|4a037b7e1ad4f4b2b46b7552bf557d83d6e09c69:4801924|lnq2r5yw|252c45b5b1c89d88d92fb4fd42bf99065652c3d4|s_1aec08c8356c9|4a0769694c3e60ffa7b878ff1e700b5ee7a31a93:95694|lnq2t46o|8f47110d725d91bc72e3083c0376c78965d77ffe|95694|28deee716df4986a1bc2f535eccb8e15165491ff:114|lnrg1u34|6c1e428c1fdcf6109a6e368afd36c2c6547842b5|s_1f0b6dd34481|0d9a8a153a4fd6f9e60247ee72a897423e0d11c7',
    'logic': 'PART',
    'referer': 'https://search.shopping.naver.com/search/all?frm=NVSCPRO&origQuery&pagingSize=80&&productSet=total&query=%EC%84%B8%EC%A0%9C&sort=rel&timestamp=&viewType=list',
    'sbth': 'd222b49238bd2b7f29803e2ed2f08d01eedaa3d14d24417197e36287d8d5eae0ca4c01288a05847bfed167eb56487188',
    'sec-ch-ua': '"Chromium";v="118", "Google Chrome";v="118", "Not=A?Brand";v="99"',
    'sec-ch-ua-arch': '"x86"',
    'sec-ch-ua-bitness': '"64"',
    'sec-ch-ua-full-version-list': '"Chromium";v="118.0.5993.70", "Google Chrome";v="118.0.5993.70", "Not=A?Brand";v="99.0.0.0"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': '""',
    'sec-ch-ua-platform': '"Windows"',
    'sec-ch-ua-platform-version': '"15.0.0"',
    'sec-ch-ua-wow64': '?0',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36',
}

params = {
    'frm': 'NVSCPRO',
    'pagingIndex': '1',
    'pagingSize': '100',
    'productSet': 'total',
    'query': f"{keyword}",
    'sort': 'rel',
    'viewType': 'list',
}

response = requests.get('https://search.shopping.naver.com/api/search/all', params=params, cookies=cookies, headers=headers)
itemlist = json.loads(response.text)

sum = 0
price_lst = []
for idx,i in enumerate(itemlist['shoppingResult']['products']):
    price = i['price'],
    price =  int(price[0])
    price_lst.append(price)
    
price_arr = np.array(price_lst)
removed_arr,excluded_prices = get_outlier(price_arr, weight=1.5)
print(f"{keyword} \t {int(removed_arr.mean())} \t {removed_arr.shape[0]} ")
print(f"이상치 제거 {excluded_prices}\n")
# Out:
# 파우더통 	 8217 	 91
# 이상치 제거 [27300 34570 26900 26400 33130 58690 25500 76000 20620]

# %%
fig, axs = plt.subplots(1, 2, figsize=(10,6))
axs[0].boxplot(price_lst);
axs[1].hist(price_lst, bins=100);

# %%
fig, axs = plt.subplots(1, 2, figsize=(10,6))
axs[0].boxplot(removed_arr);
axs[1].hist(removed_arr, bins=100);

# %%
def get_outlier(price_arr, weight=1.5):
  # target 값과 상관관계가 높은 열을 우선적으로 진행
    quantile_25 = np.percentile(price_arr, 25)
    quantile_75 = np.percentile(price_arr, 75)

    IQR = quantile_75 - quantile_25
    IQR_weight = IQR*weight
  
    lowest = quantile_25 - IQR_weight
    highest = quantile_75 + IQR_weight
  
    price_arr = price_arr[(price_arr >=lowest) & (price_arr <= highest)]
    return price_arr

# %%
get_outlier(price_arr)
# Out:
# array([ 8330,  8200,  6100,  6500,  5100, 19500, 12000, 11900,  4550,
#         4500, 27200, 10980, 30170,  4600, 23600,  1250,  2880,  7900,
#         6400,  1000, 12000, 14900,  8000,  2830,  5300,  6090, 17900,
#        23600,  1300, 19900,  6900, 13900,  5100, 12700,  7900,   640,
#         8160,  1000, 12200, 12500, 21920,  1800,  5900,  8000, 13500,
#         2610,  5580,  1560,  2920,  4500,   840,  6720,   890,  6410,
#        27200,  8320,  6900,  6400,  7000,  8100, 20020,  7900, 30170,
#         6150, 17900,  5370,  6930,  8000,  7000,  5580,   890,  3170,
#         8070,  7350,  8400,   890,  1500,  6440, 23440,  4600, 15500,
#         5580,  6700, 23200, 16900,  8500, 21000,  8300, 18740,   800,
#         3190,  5000, 11360,  7460, 19900, 10200,  5300,   840,  1920])

# %%
plt.boxplot(get_outlier(price_arr));

# %%
arr = price_arr

def remove_outliers(arr) :
    mean = arr.mean()
    std = arr.std()
    upper_bound = mean + (3 * std)
    lower_bound = mean - (3 * std)
    return (upper_bound,lower_bound)

upper_bound,lower_bound = remove_outliers(arr)

removed_arr = arr[(arr <=upper_bound) & (arr >= lower_bound)]
print(arr[(arr >=upper_bound) | (arr <= lower_bound)])
print(removed_arr.shape)
int(removed_arr.mean())
# Out:
# [160000 154000 200000]
# (97,)
# 16774
