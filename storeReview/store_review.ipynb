# %%
import requests
import json
import pandas as pd

# %%
"""url 채워넣고 keyword 입력"""

# %%
import requests

url = "https://search.shopping.naver.com/search/all?adQuery=%EC%B6%A9%EC%A0%84%EA%B8%B0&frm=NVSHATC&origQuery=%EC%B6%A9%EC%A0%84%EA%B8%B0&pagingIndex=2&pagingSize=40&productSet=total&query=%EC%B6%A9%EC%A0%84%EA%B8%B0&sort=rel&timestamp=&viewType=list"

shopping_cookies = {
    'NNB': 'BZQEKFFD3ZGWG',
    'ASID': '75100b1e000001840cfb852400000053',
    'NV_WETR_LOCATION_RGN_M': '"MDUxMTAxMTg="',
    'NaverSuggestUse': 'unuse%26use',
    'autocomplete': 'use',
    'NV_WETR_LAST_ACCESS_RGN_M': '"MDUxMTAxMTg="',
    '_ga': 'GA1.1.687219659.1669681140',
    '_ga_K2ECMCJBFQ': 'GS1.1.1686294140.1.0.1686294145.0.0.0',
    '_ga_SQ24F7Q7YW': 'GS1.1.1686294140.1.0.1686294145.0.0.0',
    'SHP_BUCKET_ID': '9',
    'nx_ssl': '2',
    'nid_inf': '817842596',
    'NID_AUT': 'BEIDBXT986GCzggDVdz/yyBv3C1/IgECgIfkmYt5ccWFwXErFV4u3e9loTqeYU3P',
    'NID_JKL': 'KG8H1DNSm6LRAP9EWlbJRNS4gSnyL9kDK6ljPSL4pW8=',
    'NID_SES': '...',
    'page_uid': 'iUsmwwqo1LVssvjC520ssssstlw-520838',
    'spage_uid': 'iUsmwwqo1LVssvjC520ssssstlw-520838',
    'sus_val': '1b6RBD1FZDOomWMxEDN3LEto',
    'ncpa': '95694|lprzjkoo|079082572a94ce3307d7ce5cfa1f98813527a107|95694|db6a4b03a9b918f109a3c9db4ab41365ce293096:3776448|lptga01s|069acf4d4c0848a9f7d3f7eb08f7a7ab611c795a|s_66064036b8ff|bf5bf28a9ec0203926e799e66342acd8ed27cbe1:2425958|lptgd8k8|14b72a5fdf30cbee497146a9fe750836dfa594c1|s_9f074674dd2f|7282ac0e8c8f8b9f7d6c46777e2fa18d5635b45b',
}

shopping_headers = {
    'authority': 'search.shopping.naver.com',
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    # 'cookie': 'NNB=BZQEKFFD3ZGWG; ASID=75100b1e000001840cfb852400000053; NV_WETR_LOCATION_RGN_M="MDUxMTAxMTg="; NaverSuggestUse=unuse%26use; autocomplete=use; NV_WETR_LAST_ACCESS_RGN_M="MDUxMTAxMTg="; _ga=GA1.1.687219659.1669681140; _ga_K2ECMCJBFQ=GS1.1.1686294140.1.0.1686294145.0.0.0; _ga_SQ24F7Q7YW=GS1.1.1686294140.1.0.1686294145.0.0.0; SHP_BUCKET_ID=9; nx_ssl=2; nid_inf=817842596; NID_AUT=BEIDBXT986GCzggDVdz/yyBv3C1/IgECgIfkmYt5ccWFwXErFV4u3e9loTqeYU3P; NID_JKL=KG8H1DNSm6LRAP9EWlbJRNS4gSnyL9kDK6ljPSL4pW8=; NID_SES=...; page_uid=iUsmwwqo1LVssvjC520ssssstlw-520838; spage_uid=iUsmwwqo1LVssvjC520ssssstlw-520838; sus_val=1b6RBD1FZDOomWMxEDN3LEto; ncpa=95694|lprzjkoo|079082572a94ce3307d7ce5cfa1f98813527a107|95694|db6a4b03a9b918f109a3c9db4ab41365ce293096:3776448|lptga01s|069acf4d4c0848a9f7d3f7eb08f7a7ab611c795a|s_66064036b8ff|bf5bf28a9ec0203926e799e66342acd8ed27cbe1:2425958|lptgd8k8|14b72a5fdf30cbee497146a9fe750836dfa594c1|s_9f074674dd2f|7282ac0e8c8f8b9f7d6c46777e2fa18d5635b45b',
    'logic': 'PART',
    'referer': url,
    'sbth': '61ff126fbd21a88b6bace776dd23d34efd87def2d766df5aff1deab09745f670b9df6df189e81e7ad88a80749392c2be',
    'sec-ch-ua': '"Google Chrome";v="119", "Chromium";v="119", "Not?A_Brand";v="24"',
    'sec-ch-ua-arch': '"x86"',
    'sec-ch-ua-bitness': '"64"',
    'sec-ch-ua-full-version-list': '"Google Chrome";v="119.0.6045.202", "Chromium";v="119.0.6045.202", "Not?A_Brand";v="24.0.0.0"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': '""',
    'sec-ch-ua-platform': '"Windows"',
    'sec-ch-ua-platform-version': '"10.0.0"',
    'sec-ch-ua-wow64': '?0',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36',
}

# %%
keyword = "충전기"

shopping_params = {
    'adQuery': f'{keyword}',
    'eq': '',
    'frm': 'NVSCPRO',
    'iq': '',
    'origQuery': f'{keyword}',
    'pagingIndex': '1',
    'pagingSize': '40',
    'productSet': 'total',
    'query': f'{keyword}',
    'sort': 'rel',
    'viewType': 'list',
    'xq': '',
}

shopping_response = requests.get('https://search.shopping.naver.com/api/search/all', params=shopping_params, cookies=shopping_cookies, headers=shopping_headers)

# %%
"""리뷰 페이지에 필요한 정보들 리스트 형식으로 만들기"""
shopping_result = json.loads(shopping_response.text)
products = shopping_result["shoppingResult"]["products"]

mallProdlUrl_lsts  = []
MerchantNo_lsts  = []
originProductNo_lsts  = []

for idx,product in enumerate(products):
    mallProdlUrl =  product["mallProductUrl"]
    MerchantNo =  product["chnlSeq"]
    originProductNo =  product["originalMallProductId"]
    
    
    if mallProdlUrl and MerchantNo and originProductNo :
        mallProdlUrl_lsts.append(mallProdlUrl)
        MerchantNo_lsts.append(MerchantNo)
        originProductNo_lsts.append(originProductNo)   
        
print(mallProdlUrl_lsts,MerchantNo_lsts,originProductNo_lsts)
# Out:
# ['https://smartstore.naver.com/main/products/5482195874', 'https://smartstore.naver.com/main/products/3842123266', 'https://smartstore.naver.com/main/products/6502641139', 'https://smartstore.naver.com/main/products/6207554973', 'https://smartstore.naver.com/main/products/6217998819', 'https://smartstore.naver.com/main/products/6911451797', 'https://smartstore.naver.com/main/products/6906031923', 'https://smartstore.naver.com/main/products/8736097783', 'https://smartstore.naver.com/main/products/7073731403', 'https://smartstore.naver.com/main/products/7399582655', 'https://smartstore.naver.com/main/products/9473357010', 'https://smartstore.naver.com/main/products/9255043551', 'https://smartstore.naver.com/main/products/8848692626', 'https://smartstore.naver.com/main/products/7660599508'] ['500004221', '500059276', '500005615', '100634478', '101443035', '500055385', '100383754', '101915494', '100364796', '101720453', '101954039', '100364796', '100364796', '500072261'] ['5459259840', '3835497973', '6471626213', '6178116909', '6188509704', '6878568604', '6873173580', '8694882635', '7040134466', '7364774261', '9428795222', '9211636771', '8806954921', '7623617366']

# %% [markdown]
# <font color="Maroon" size="5"><b>리뷰 랭킹 순</b></font>

# %%
cnt = 0 
review_contents = [] # 데이터를 담을 리스트 생성

for mallProdlUrl_lst,MerchantNo_lst,originProductNo_lst in zip(mallProdlUrl_lsts,MerchantNo_lsts,originProductNo_lsts):
    
    product_cookies = {
        'NNB': 'BZQEKFFD3ZGWG',
        'ASID': '75100b1e000001840cfb852400000053',
        'NV_WETR_LOCATION_RGN_M': '"MDUxMTAxMTg="',
        'NaverSuggestUse': 'unuse%26use',
        'NV_WETR_LAST_ACCESS_RGN_M': '"MDUxMTAxMTg="',
        '_ga': 'GA1.1.687219659.1669681140',
        '_ga_K2ECMCJBFQ': 'GS1.1.1686294140.1.0.1686294145.0.0.0',
        '_ga_SQ24F7Q7YW': 'GS1.1.1686294140.1.0.1686294145.0.0.0',
        'nx_ssl': '2',
        '_fwb': '93q9grDQUebvMRC57RGY3G.1701774255856',
        'nid_inf': '817842596',
        'NID_AUT': 'BEIDBXT986GCzggDVdz/yyBv3C1/IgECgIfkmYt5ccWFwXErFV4u3e9loTqeYU3P',
        'NID_JKL': 'KG8H1DNSm6LRAP9EWlbJRNS4gSnyL9kDK6ljPSL4pW8=',
        '_naver_usersession_': '4od3zcb0O5LWCipxKkmxPA==',
        'NID_SES': '...',
        'page_uid': 'iUsmwwqo1LVssvjC520ssssstlw-520838',
        }

    product_headers = {
            'authority': 'smartstore.naver.com',
            'accept': 'application/json, text/plain, */*',
            'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
            'content-type': 'application/json;charset=UTF-8',
            # 'cookie': 'NNB=BZQEKFFD3ZGWG; ASID=75100b1e000001840cfb852400000053; NV_WETR_LOCATION_RGN_M="MDUxMTAxMTg="; NaverSuggestUse=unuse%26use; NV_WETR_LAST_ACCESS_RGN_M="MDUxMTAxMTg="; _ga=GA1.1.687219659.1669681140; _ga_K2ECMCJBFQ=GS1.1.1686294140.1.0.1686294145.0.0.0; _ga_SQ24F7Q7YW=GS1.1.1686294140.1.0.1686294145.0.0.0; nx_ssl=2; _fwb=93q9grDQUebvMRC57RGY3G.1701774255856; nid_inf=817842596; NID_AUT=BEIDBXT986GCzggDVdz/yyBv3C1/IgECgIfkmYt5ccWFwXErFV4u3e9loTqeYU3P; NID_JKL=KG8H1DNSm6LRAP9EWlbJRNS4gSnyL9kDK6ljPSL4pW8=; _naver_usersession_=4od3zcb0O5LWCipxKkmxPA==; NID_SES=...; page_uid=iUsmwwqo1LVssvjC520ssssstlw-520838',
            'origin': 'https://smartstore.naver.com',
            'referer': mallProdlUrl_lst,
            'sec-ch-ua': '"Google Chrome";v="119", "Chromium";v="119", "Not?A_Brand";v="24"',
            'sec-ch-ua-mobile': '?0',
            'sec-ch-ua-platform': '"Windows"',
            'sec-fetch-dest': 'empty',
            'sec-fetch-mode': 'cors',
            'sec-fetch-site': 'same-origin',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36',
        }


    json_data = {
        'checkoutMerchantNo': MerchantNo_lst,
        'originProductNo': originProductNo_lst,
        'page': 1,
        'pageSize': 20,
        'reviewSearchSortType': 'REVIEW_RANKING',
    }

    product_response = requests.post(
        'https://smartstore.naver.com/i/v1/contents/reviews/query-pages',
        cookies=product_cookies,
        headers=product_headers,
        json=json_data,
    )
    
    try:
        data = json.loads(product_response.text)
        for content in data["contents"]:
            review_contents.append(content["reviewContent"]) # 리뷰 저장

            print(f'{cnt}. {content["reviewContent"]}')
            print("----------------------------------------")
            cnt += 1
    except:
        pass

print(f"리뷰 개수 : {cnt}")
# Out:
# 0. 폰은 플립3라 고속 충전만 지원돼서 초고속 충전기 써도 소용없지만 갤탭 s8+는 체감 확 되네요 충전 속도가 일반에 비해 2배 빠르고 호환되는 45w 충전기랑은 차이 없을 줄 알았는데 20분 더 빨라요 대박;; 급하게 충전해야할 때 유용할 거 같아요~~~ 선도 일반 정품 충전 케이블보다 두껍고 튼튼해요 삼성 정품 a to c는 8년째 써도 멀쩡한데 이건 얼마나 오래갈지 궁금하네요 그간 쓴 c to c케이블은 금방 휘어져서 몇달 쓰고 버렸는데 이건 정품인 만큼 오래 쓰면 좋겠네요ㅜㅜ
# ----------------------------------------
# 1. 얼마전에 충전기가 고장이 나서 여기서 구매하게 되었습니다! 리뷰도 많고 괜찮은것 같아서 구매해봤어요!
# 확실히 리뷰 쓰여있는대로 배송이 빠릅니다
# 11월 24일 주문했는데 11월 25일에 도착했습니다!!
# 핸드폰 충전도 초고속 충전으로 계속 잘 됩니다
# 리뷰 중에 2번정도 초고속 되다가 안 된다고 쓰여있는 걸 봐서 걱정했었는데 다행히 잘 됩니다.
# (제품마다 다른 것 같습니다!)
# 아직 쓴지 얼마 안 되어서 앞으로는 어떨지 모르겠지만 지금은 충전도 잘 되고 잘 구매한 것 같아 만족합니다!
# ----------------------------------------
# 2. 주문 - 2023년 11월 9일(목)/ 12:54PM
# 수령 - 2023년 11월 10일(금)/ 12:50PM
# 힘든시기에 택배기사분들 고생많으십니다.
#
# 기존 사용하던 충전기가 먹통이라
# 예전에 부모님 충전기 구입했던 이곳에서
# 다시 구입하게 되었습니다.
#
# 도착 후 테스트 해보니 이상없이 충전 잘 되네요.
#
# 다만, 먹통이던 기존 충전기도
# 갑자기 당일부터 다시 작동해서
# 괜히 구입한 게 되어버렸네요.
#
# 다시 고장나면 그때 사용해야 할 것 같습니다.
#
# 리뷰점수를 첨에 300점으로 알려줬는데
# 막상 지금 150점 밖에 적립되지 않는게 좀 아쉽네요.
#
# 번창하세요.
# ----------------------------------------
# 3. 역시 정품이 충전속도 굿
# 계속 정품쓰다가 언니가 준거 썼었는데 느리더라구요
# 선은 게속 정품썼었구요
# 역시나 정품써야하는 이유입니다
# ----------------------------------------
# 4. 가격도 좋고 삼성 AS 가능한 정품이라 만족합니다. 당일 발송 시간에 맞추느라 급하게 구매한 탓에 다른 케이블 추가 구매는 깜박했는데 주말 주문량으로 배송 지연될 줄 알았더라면 주문 취소 후 추가해서 주문하는건데 아쉽네요. 배송 지연 알게된 익일 오전엔 또 이미 발송되어 솜씻너꼴.. 무튼 이틀째 무사히 받았습니다. 고속충전도 잘 되고 구성품으로 포함된 케이블은 추가 구매가능한 정품 케이블 1번과 제품명 같았습니다.
# ----------------------------------------
# 5. 다른곳보다 금액이 저렴한데 물건 상태 너무 좋아요.
# 길이도 길어서 침대에 누워서 자유롭게 쓰기 너무 편해요. 다음에 또 구매할게요
# ----------------------------------------
# 6. 확실히 빨리 충전되고 배송도 하루만에 와서 만족합니다~ 좀 더 써 봐야 알겠지만 리뷰가 많아서 믿고 구매했어요!
# ----------------------------------------
# 7. 지플립5라 25w로 2개 구매 했습니다
# 갑자기 고장나서 회사,집 사용하려고 샀는데 빠르게 와서 너무 좋네여! 초고속 충전이라 그런지 빠릅니다
# 감사합니다
# ----------------------------------------
# 8. 저번에 충전기 구매해서 잘 사용하고있었는데 하나 더 필요해서 또 구매했어요 이번에는 케이블 같이 있는걸로 주문했는데 충전 잘 되고 좋네요!
# ----------------------------------------
# 9. 갤8 플러스때부터 쓰던 삼성 정품충전기가 너무 오래되어서 그런지 자꾸 저속 충전이되어 구매하게되었습니다. 현재 기종은 갤럭시 21 울트라이고 구매하자마자 충전해보았는데 ....초고속충전의 신세계를 맛보았네요 ㅋㅋㅋ
#
# 30퍼센트 대일때 꽂아서 30여분만에 완충되는거 보고 놀랬습니다..ㅠㅠ그동안 도대체 충전기 아득바득 더쓰겠다고 했는지 후회될정도였어요 ㅋㅋ 너무좋습니다 성능도 최고네요! 고장나면 무조건 여기서 또 구매하겠습니다
# ----------------------------------------
# 10. 부모님께서 필요하시다하여 샀었는데
# 아직 아무말씀 없으신 것 보니 잘 쓰고 계신 것 같습니다.
# 예전 충전기로 사용하시다 바꾸신건데 이번것도 잘 사용하셨으면 좋겠어요.
# 삼성 정품이니 믿습니다!
# ----------------------------------------
# 11. 빠른 배송 좋았고 물건품질은 볼게 없죠 삼성정품이니ㅎ워치 충전용으로 구입했는데 잘작동하네요^^
# ----------------------------------------
# 12. 배송 빠르고 가격도 적당하게 잘 샀어요.
# 충전해보니 빠르고 좋네요.
# ----------------------------------------
# 13. 원래 가지고 있던 충전기가 고장나서 새로 샀는데.. 너무 좋아요ㅜㅠ 노트10인데 초고속 충전이라고 뜨네요! 잘 사용하겠습니다ㅎㅎ
# ----------------------------------------
# 14. 좋아용. 충전 정상적으로 잘 돼용
# ----------------------------------------
# 15. 아버지 훈대폰 바꿔셔서 사다 드렸는데잘 사용하고 있어요 역시 정품이 비싸도 값어치를 하네요
# ----------------------------------------
# 16. 역시역시 정품이최고 확실히 충전이 빨리되고 폰이 뜨거워지지안하서 강추 전에거 그냥 꼽았다가 충전시간 길어서 같이열올랐는데 말끔히 해결됨
# ----------------------------------------
# 17. 초고속충전 너무 좋아요!!! 원래쓰던거 고장나서 싸구려쓰다가 초고속쓰니까 속시원함
# 선 꽂으면 보이는 청록색 게이지가 기분까지 좋게 해줌
# ----------------------------------------
# 18. 계속 다른 좀 저렴한 제품 쓰다가 충전시 폰과열이 좀 심한거 같아 그냥 정품 샀는데 확실히 열이 많이 덜 나요 이래서 정품 제품을 사야하나봐요
# ----------------------------------------
# 19. 5월에 샀던 충전기가 끊어져서 다시 주문했습니다. 긴 것도 추가로. 오래 가면 좋겠네요
# ----------------------------------------
# 20. 배송빠르고 충전 빠르고
# 정품이 최고에요
# 서비스로 주신 것도 감사합니다
# ----------------------------------------
# 21. 배송도 빠르고 딸이 충전 아주 잘된다고 좋아하네요~차에서 충전할 아이폰 케이블이 없어서 같이 주문했는데 아직 사용전이라 잘되는지는 모르겠어요ㅋ무엇보다 택배포장이 아주 굿입니다~!!가격만 좀 저렴했으면 하는바램이예요~ㅠ 아~!서비스로 주신 선 보호캡?!추가주문해서 식구들 충전기들에 다 끼워서 사용중인데 별거아닌거 같은데도 선 망가질 걱정이 한시름 놓이네요ㅎㅎ
# ----------------------------------------
# 22. 혹시 고장날까 걱정했는데(하도 그런게많아) 아직 한달이지났지만 괜찮습니다. 충전도 꽤잘돼요
# ----------------------------------------
# 23. 패키징도 너무 잘되어있고 배송도 빠르게 왔습니다 ㅎㅎ 애초에 단선방지캡을 줘서 추가로 안사도 될것 같아요
# ----------------------------------------
# 24. 급하게 사야해서 주문했었는데 배송도 빨리왔구요 지금까지도 잘 쓰고있습니다!! 이제 계속 여기서 사러올꺼같아요!!
# ----------------------------------------
# 25. 충전도 빨리되고 튼튼하게 잘 사용하고 있습니다!
# 다음에도 재구매하고 싶어요~
# ----------------------------------------
# 26. 좀 더러운게 뭍어서 왔어요;;새상품 맞는거죠.?찝찝한데 충전은 되서 그냥 씁니다
# ----------------------------------------
# 27. 배송 빠르고 저렴한 가격이 좋습니다.
# 시험삼아 구매했는데 작동 잘 되면 바로 추가구매 하겠습니다
# ----------------------------------------
# 28. 일년전에 애플정품 충전기 샀는데 요즘 접촉이 꽉 안되길래 다시 산건데요.
# 제 경우는 핸드폰점검을 받았어야하나봐요. 어쨌든 충전기 자체는 좋습니다.
# ----------------------------------------
# 29. 찰떡이네요!!! 생각보다 좀 보이기는 하는데 그 외는 붙이기도 쉽고~ 100% 만족이에요!!!
# ----------------------------------------
# 30. 잘 쓰고 있어요! 충전 빨리 돼서 존좋!
# ----------------------------------------
# 31. 배송도 빠르고 딸이 충전 아주 잘된다고 좋아하네요~무엇보다 택배포장이 아주 굿입니다~!!가격만 좀 저렴했으면 하는바램이예요~ㅠ
# ----------------------------------------
# 32. 잘받았어요 배송빠르고 만족해요
# ----------------------------------------
# 33. 정품이라 좋아요~
# 서비스로 주신것도 넘 좋으네요
# ----------------------------------------
# 34. 정품이라 좋아요~
# 서비스로 주신것도 넘 좋으네요
# ----------------------------------------
# 35. 진짜 정품입니다
# 믿고 쓰는 정품 그리고 단지 예방 꽈배기까지 훌륭합니다
# ----------------------------------------
# 36. 완전 고속충전입니다 !!!! 이거 또살거에요  감사해용
# ----------------------------------------
# 37. 충전 잘 돼요~ 보호 캡도 주셔서 감사합니다.
# ----------------------------------------
# 38. 좋네여 역시 ㅎㅎ 잘쓸게요
# ----------------------------------------
# 39. 정품 맞는거같고배송도 빨라서 좋았습니다
# ----------------------------------------
# 40. 회사에서 사서 쓰다가 빠른 &quot;초고속충전&quot;이
# 너무 맘에 들어서 집에도 사서 쓰려고 구매했어요
# 진짜 급하고 시간없을때 딱 꼽아놓으면
# 빨리 충전해서 갈수있어서 좋아요
# 그리고 정품이니까 절대 고장나거나 합선 이런걱정 안해도 되고요
# ----------------------------------------
# 41. 개당 비싸서... 살까말까 고민했는데.. 저속 일반 충전기 저려미 애매한거 살빠에 이런거 사세용.
# 고속도 아니고 초고속충전이라 아주 매우 빠름ㅋㅋㅋ
# 선 본체 모두 짱짱해서 아주 만족함.
# 회사1개 집1개 구매해서 잘쓰고있음.
# ----------------------------------------
# 42. 충전기 검색하다 후기가 좋아서 구매 했는데 고속충전이라 만족하며 사용하고 있어요
# 충전이 잘 되어 가족들에게 인기 최고 랍니다
# ----------------------------------------
# 43. 성능 굿
# 삼성 정품 좋아요
# 강추합니다
# ----------------------------------------
# 44. 충전속도가 빨라요
# 근데 저희집 보조배터리는 충전이 안되네요ㅜㅜ
# 뭐가 안 맞나봐여 여행가서 두개 다 충전하려다 안돼서 당황했습니다...  전에 쓰던 선으로 바꿨는데 그건 돼요..
# 여튼 폰은 잘 충전됩니다
# ----------------------------------------
# 45. 배송 빠르고 충전 속도 엄청 빨라 좋아요
# 두번째 구매했네요ㅎ
# ----------------------------------------
# 46. 리뷰읽고 샀는데 정상 작동합니다.
# 기존 25W 접지 충전기에 비해서 충전속도가 빠르지는 않네요.
# 와이프 쓰라고 줬습니다. ^^
# 암튼 오래도록 고장 안나길 바랍니다.
# ----------------------------------------
# 47. C to C인줄 확인도안하고샀어요.
# 폰은 충전이 빠르게되느데 탭은 충전이 안되네요..
# ----------------------------------------
# 48. 배송빠르고 품질좋네요 비싼값하길...
# ----------------------------------------
# 49. 솔직히 드라마틱하게 빠른건 잘 모르겠지만, 충전이 빨리되긴 해요. 좋아요!!
# ----------------------------------------
# 50. 25w짜리보다 선이 단단? 부드럽지못해서 선을 움직일때 꺽여져? 고장났습니다 ㅜㅜ
# ----------------------------------------
# 51. 급속충전으로 여행시 배터리 소진을
# 빨리 해결해주어서 일본 호텔에서도
# 체크 아웃 뒤에 충전을 안해주려는 걸 복도에 나있는 전원 콘센트를 이용해서 짧은 시간에 20-30프로 를 충전하여 잘 활용해서 만족도 최고!!
# ----------------------------------------
# 52. 삼성 정품이라 믿고 구매합니다
# 품질, 성능, 가격, 배송 모두 만족합니다
# 기존에 쓰던 충전기도 삼성 제품인데
# 멀티충전기에는 전압이 약해서 45W로
# 구매했어요 속도 좋아요
# 멀티충전기랑 한 세트 같아요
# 강추드립니다
# ----------------------------------------
# 53. 삼성정품충전기가 좋은 것 같아요, 타사는 사도 고장도 잘 나고 했었는데 정품을 사면 덜 그런 것 같아요
# ----------------------------------------
# 54. 빠른 배송 감사합니다.
# 충전도 해봤는데 잘 되네요
# 역시 정품은 믿고 쓰는거죠
# ----------------------------------------
# 55. 사무실에서 사용하려고 구매했어요 고속충전에 선도 길어서 만족합니다
# ----------------------------------------
# 56. 45w 신세계네요 빨리 충전되서 너무좋아요
# ----------------------------------------
# 57. 충전이 빨리 되어서 좋아요 충전 선도 길어서 편리해요
# ----------------------------------------
# 58. 고속충전으로 스피드 업업~!!
# 빠른배송도 감사해요 😊
# ----------------------------------------
# 59. 정품이라서 믿고 구매합니다.
# 충전도 잘되고 좋아요
# 감사합니다
# ----------------------------------------
# 60. 기존에 사용하던 충전기가 갑자기 망가져서 주문했어요. 사용했던 충전기는 일반 중소업체거 쓰고있었는데
# 나름 충전하는데 문제없었는데 역시나 몇개월 못가고 망가져버려서 이번엔 정품 충전기를 구매했습니다.
#
# 여기서 구매한 이유!
#
# 가격도 저렴하고 삼성에서 공식적으로 인증된 업체라서 믿고 구매 했습니다.
# (물론 후기도 많고 다들 정품이라는 글이 많았습니다.)
#
# 배송도 빠르고 받고나서 바로 핸드폰에 테스트 충전 해봤는데 충전속도 잘나옵니다.
# 사실 충전기가 없어서 기존에 쓰던 보조배터리 사용하고 있었는데 이것도 충전 했는데 대용량 보조배터리 인데도 금방 충전됐어요.
# (핸드폰 사은품으로 준 중소기업 충전기로는 충전이 오래걸렸어요 ㅠ)
#
# ++추가로 충전기가 뜨거워지거나 핸드폰 뜨거워 지는일이 많았는데 정품 쓰니까 발열도 없어졌어요.
#
# 결론적으로 역시 정품을 써야 충전 걱정은 안하고 살것 같네요.
# 집에 있는 충전기.케이블도 바꿔야 겠네요.
#
# 잘 사용하고 1달 후에 사용후기 또 남기도록 할게요.
# 지금은 대!!만족하고 쓰겠습니다.
# ----------------------------------------
# 61. 삼성정품이라  믿고  쓸수 있어요 어제오후에  시켰는데 오늘  아침에 배송왔네요  번창하세요
# ----------------------------------------
# 62. 배송이 빠르네요. 사진상으로는 잘 안보이는데 예전에 쓰던 케이블보다 이번에 산 케이블이 더 튼튼해보여요.
# ----------------------------------------
# 63. 오자마자 핸드폰에 껴보니 충전잘되고 좋네요. 여기가 제일 저렴하면서 신뢰가 가서 구입했어요. 여기저기 고민하시는분들 여기 완전 추천드려요!
# ----------------------------------------
# 64. 마음에 들어요~ USB-C 케이블 쓸수있는 충전기가 필요했는데 잘샀어요~
# ----------------------------------------
# 65. 갑자기 충전기가 망가져서 급하게 주문했는데 배송도 빠르고 충전기도 이상없이 잘 작동되요~~ 절전형이라서 더 좋을것같아요!
# ----------------------------------------
# 66. 집에 사용하던게 고장난줄알고 2개 구매했는데 충전이 또 되네요~ㅎㅎ 어찌됐던 2개다 초고속충전 잘 됩니다~
# ----------------------------------------
# 67. 배송 이틀만에 왔어요 오후에 주문해서 그런가봐요~ 충전기 고장나서 정품이라해서 샀습니다~
# ----------------------------------------
# 68. 핸드폰 사고 받은 충전기는 회사에서 사용하고 있는데 집에서도 초고속 충전 하려고 구매했습니다.
# 충전 빨라서 너무 좋네요.
# 잘쓰고있어요.
# ----------------------------------------
# 69. 기존에 쓰던 케이블선이 고장나서 급하게 질문드리고 주문했어요 빠르고 친절한 답변도 감사드리고 배송도 하루만에 왔어요 급했는데 감사합니다:) 충전 잘되요~!!
# ----------------------------------------
# 70. 역시 믿고쓰는 삼성제품!! 전압이 일정하게 출력되는게 아주 마음에 듭니다. 전기제품은 꼭 믿을 수 있는 제품이 좋은거 같습니다.
# ----------------------------------------
# 71. 충전 완전빠르네요 일반 고속충전 보다 좀더 빨리 됩니다 단 초고속 충전가능한 기기여야 할 듯요 삼성정품 아닌 그냥고속 충전기를 쓰니 폰(z플3)은 고속이 되던데 s탭9는 충전 자체가 안되더라구요 그래서 삼성로고박힌걸로 쓰면 될것 같아 이왕 구매하는거 초고속으로 사서 써보니까 잘 되네요 기기랑 충전기의 호환이 되어야 하는줄 처음 알았네요
# ----------------------------------------
# 72. 충전 잘 됩니다! 선이 좀 길었으면~ 하는 아쉬움은 있네요ㅜㅜ 잘 쓰겠습니다!
# ----------------------------------------
# 73. 배송 빠르고 충전도 빨리됩니다 감사합니다 잘쓸게요
# ----------------------------------------
# 74. 무난하게 잘 쓰고 있습니다
# ----------------------------------------
# 75. 45w 충전기 사용중 전에 쓰던 줄이 망가져서 다시 구매했습니다:) 충전도 너무 잘되고 있어서 좋네여 ㅎㅎ 사는김에 어뎁터도 하나 더 들였어요~!
# 배송도 빠르고 다음에도 구매할 일 있으면 여기서 구매하려구요~!
# ----------------------------------------
# 76. 포장이 다 터져서 도착했네요. 제품은 무사히 작동 잘 됩니다.
# ----------------------------------------
# 77. 삼성 정품이라 믿고 샀어요.  충전잘되고 좋아여
# ----------------------------------------
# 78. 아버지 충전기가 끊겨서 선 사는김에 어댑터도 같이 구매했습니다.
# 예전에 쓰시던건 그냥 충전기였는데 이건 초고속 충전까지 되서 좋네요.
# 봉인씰도 잘 붙여있고 충전기도 잘 작동하는것 같습니다.
# ----------------------------------------
# 79. 일반 충전기보다 살짝 무겁긴하지만..
# 초고속 충전기에요ㅠㅠ하나 더 구매해야 할것같아요
# 줄도 길고 진짜 매우매우 만족입니닷!!!
# 동생도 와서 써보고 엄청좋다고했어요ㅠㅠ
# ----------------------------------------
# 80. 아주 마음에 듭니다 흰색 블랙 둘다 주문했어요 가격도 좋고 배송도 빠르고 만족합니다 일단 오자마자 써봤는데 충전 잘됩니다! 아직 블랙은 사용 안해봤어요 ㅎ
# ----------------------------------------
# 81. 집에 아이폰 충전기밖에 없어서 불편해서 주문했어요! 정품이라 좋고 착한가격에 배송도 빨라서 좋습니다!
# ----------------------------------------
# 82. 고속충전만 지원하는 충전기만 써보다가 이번에 사서 충전하니 속도가 참 빠르네요. 리뷰보면 빨리 고장난다는 내용이 있던데 오래 쓰고 싶어요...
# ----------------------------------------
# 83. 노트북에도 그냥 사용하는데 25w여서 그런지 고속충전 잘되고 좋아요. 깔끔하고 추가상품으로 받은 것도 마음에 들어요.
# ----------------------------------------
# 84. 갤럭시 Z플립3 충전하려고 구입했어요. 잘 됩니다.
# ----------------------------------------
# 85. 아이폰 15샀는데 충전기가 없어서 샀어용
# 충전도 빨라요 ! 아주 굿입니다 ㅎㅎㅎ
# ----------------------------------------
# 86. 깔끔해서 마음에 들어요. 충전도 잘되고, 줄이 너무 길지 않아서 좋아요. 양쪽 다 c타입이어서 편해요.
# ----------------------------------------
# 87. 아주 마음에 듭니다 더 써봐야 알겠지만 일단 충전은 지금 잘되고 있구요 배송 빠릅니다!
# ----------------------------------------
# 88. 배송 진짜 빨랐어요ㅜㅜ 급하게 필요했는데
# 정말 감사합니다 ♡
# 초고속 아니여도 고속도 좋아요^^
# 가격도 착하고 ㅜㅜ 삼성이라 더 믿음이 가네요^^
# ----------------------------------------
# 89. 충전 빠르고 좋아요!! 재구매 의사 있습니다!
# ----------------------------------------
# 90. 가격저렴해서 미리 사두었어요
# 충전빨리되요
# 좋아요
# ----------------------------------------
# 91. 정품이라 믿고 사용할 수 있네요
# ----------------------------------------
# 92. 좋아요! 집에 충전기가 잘안되서 급하게
# 주문했어요.. 잘쓸게요
# ----------------------------------------
# 93. 휴대용 하나랑 놓고 쓰는 용으로 하나 총 2개 구매했습니다 둘 다 충전 잘 되네요 감사합니다
# ----------------------------------------
# 94. 흰색 이뻐요ㅠㅠ 잘 쓰고있답니다
# 보조배터리에도 쓰고 잘 돼요
# ----------------------------------------
# 95. 빠른배송 감사합니다.잘쓰겠습니다.
# ----------------------------------------
# 96. 일단 작동은 잘 됩니다. 망가지지 않고 오래 사용할 수 있었으면 좋겠네요.
# ----------------------------------------
# 97. 삼정정품이라고적혀잇길래삿는데 정품이아니네요? 정품은 최고속으로 뜬다는데 이제품은 고속으로뜨네요? 이게무슨정품입니까? 가서 사는것보다 저렴해서 산건데 그게 잘못이엿네요 삼성전자가서 사는게최고네요ㅎㅎ
# ----------------------------------------
# 98. 충전속도 빠르고 좋아요
# 책상옆에두고 사용중이에요
# ----------------------------------------
# 99. 재구매입니다. 전에 써보고 잘돼서 동생 사줬는데 좋다고 하네요
# ----------------------------------------
# 리뷰 개수 : 100

# %%
rank_df = pd.DataFrame(review_contents, columns=["리뷰 내용"])
rank_df
# Out:
#                                                 리뷰 내용
# 0   폰은 플립3라 고속 충전만 지원돼서 초고속 충전기 써도 소용없지만 갤탭 s8+는 체...
# 1   얼마전에 충전기가 고장이 나서 여기서 구매하게 되었습니다! 리뷰도 많고 괜찮은것 같...
# 2   주문 - 2023년 11월 9일(목)/ 12:54PM\n수령 - 2023년 11월 ...
# 3   역시 정품이 충전속도 굿\n계속 정품쓰다가 언니가 준거 썼었는데 느리더라구요\n선은...
# 4   가격도 좋고 삼성 AS 가능한 정품이라 만족합니다. 당일 발송 시간에 맞추느라 급하...
# ..                                                ...
# 95                                 빠른배송 감사합니다.잘쓰겠습니다.
# 96          일단 작동은 잘 됩니다. 망가지지 않고 오래 사용할 수 있었으면 좋겠네요.
# 97  삼정정품이라고적혀잇길래삿는데 정품이아니네요? 정품은 최고속으로 뜬다는데 이제품은 고...
# 98                        충전속도 빠르고 좋아요\n책상옆에두고 사용중이에요
# 99                 재구매입니다. 전에 써보고 잘돼서 동생 사줬는데 좋다고 하네요
#
# [100 rows x 1 columns]

# %%
rank_df.to_excel(f"RankReview/{keyword}_RankReview.xlsx", index=False)

# %% [markdown]
# <font color="Maroon" size="5"><b>리뷰 나쁜 순</b></font>

# %%
cnt = 0 
review_contents = [] # 데이터를 담을 리스트 생성

for mallProdlUrl_lst,MerchantNo_lst,originProductNo_lst in zip(mallProdlUrl_lsts,MerchantNo_lsts,originProductNo_lsts):
    
    product_cookies = {
        'NNB': 'BZQEKFFD3ZGWG',
        'ASID': '75100b1e000001840cfb852400000053',
        'NV_WETR_LOCATION_RGN_M': '"MDUxMTAxMTg="',
        'NaverSuggestUse': 'unuse%26use',
        'NV_WETR_LAST_ACCESS_RGN_M': '"MDUxMTAxMTg="',
        '_ga': 'GA1.1.687219659.1669681140',
        '_ga_K2ECMCJBFQ': 'GS1.1.1686294140.1.0.1686294145.0.0.0',
        '_ga_SQ24F7Q7YW': 'GS1.1.1686294140.1.0.1686294145.0.0.0',
        'nx_ssl': '2',
        '_fwb': '93q9grDQUebvMRC57RGY3G.1701774255856',
        'nid_inf': '817842596',
        'NID_AUT': 'BEIDBXT986GCzggDVdz/yyBv3C1/IgECgIfkmYt5ccWFwXErFV4u3e9loTqeYU3P',
        'NID_JKL': 'KG8H1DNSm6LRAP9EWlbJRNS4gSnyL9kDK6ljPSL4pW8=',
        '_naver_usersession_': '4od3zcb0O5LWCipxKkmxPA==',
        'NID_SES': '...',
        'page_uid': 'iUsmwwqo1LVssvjC520ssssstlw-520838',
        }

    product_headers = {
            'authority': 'smartstore.naver.com',
            'accept': 'application/json, text/plain, */*',
            'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
            'content-type': 'application/json;charset=UTF-8',
            # 'cookie': 'NNB=BZQEKFFD3ZGWG; ASID=75100b1e000001840cfb852400000053; NV_WETR_LOCATION_RGN_M="MDUxMTAxMTg="; NaverSuggestUse=unuse%26use; NV_WETR_LAST_ACCESS_RGN_M="MDUxMTAxMTg="; _ga=GA1.1.687219659.1669681140; _ga_K2ECMCJBFQ=GS1.1.1686294140.1.0.1686294145.0.0.0; _ga_SQ24F7Q7YW=GS1.1.1686294140.1.0.1686294145.0.0.0; nx_ssl=2; _fwb=93q9grDQUebvMRC57RGY3G.1701774255856; nid_inf=817842596; NID_AUT=BEIDBXT986GCzggDVdz/yyBv3C1/IgECgIfkmYt5ccWFwXErFV4u3e9loTqeYU3P; NID_JKL=KG8H1DNSm6LRAP9EWlbJRNS4gSnyL9kDK6ljPSL4pW8=; _naver_usersession_=4od3zcb0O5LWCipxKkmxPA==; NID_SES=...; page_uid=iUsmwwqo1LVssvjC520ssssstlw-520838',
            'origin': 'https://smartstore.naver.com',
            'referer': mallProdlUrl_lst,
            'sec-ch-ua': '"Google Chrome";v="119", "Chromium";v="119", "Not?A_Brand";v="24"',
            'sec-ch-ua-mobile': '?0',
            'sec-ch-ua-platform': '"Windows"',
            'sec-fetch-dest': 'empty',
            'sec-fetch-mode': 'cors',
            'sec-fetch-site': 'same-origin',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36',
        }


    json_data = {
        'checkoutMerchantNo': MerchantNo_lst,
        'originProductNo': originProductNo_lst,
        'page': 1,
        'pageSize': 20,
        'reviewSearchSortType': 'REVIEW_SCORE_ASC',
    }

    product_response = requests.post(
        'https://smartstore.naver.com/i/v1/contents/reviews/query-pages',
        cookies=product_cookies,
        headers=product_headers,
        json=json_data,
    )
    
    try:
        data = json.loads(product_response.text)
        for content in data["contents"]:
            review_contents.append(content["reviewContent"]) # 리뷰 저장

            print(f'{cnt}. {content["reviewContent"]}')
            print("----------------------------------------")
            cnt += 1
    except:
        pass

print(f"리뷰 개수 : {cnt}")
# Out:
# 0. 에이에스 맡겨야 해요ㅜㅜ
# ----------------------------------------
# 1. 내 폰이 이상한가 처음 한두번은 잘대더니
# 이제는 아예 반응이 없네요 ㅡㅡㅋ
# 한달 내내 서랍장에 박혀 잇음
# ----------------------------------------
# 2. 충전속도가  별로 빠르다는걸 못느낌
#   마트에파는 일반충전기랑 충전되는 속도가 비슷
# ----------------------------------------
# 3. 중간에 계속 충천 멈추고, 나중에는 그냥 충천이 아예 안되요.
# ----------------------------------------
# 4. ，，，，，，，，，，
# ----------------------------------------
# 5. 제가 초고속충전기를 삿는데 초고속 충전이 되서 좋아라 했는데 2초 지나니까 그냥 충전으로 바껴서 너무 짜증이나네요 이거 사기에요
# ----------------------------------------
# 6. 짜증남 처음엔 잘 되는가 싶더니 접지 잘 안되고 연결 소리만 몇번을 나는지 요즘엔 10번 중에 6번은 연결 잘 안되서 뺐다가 다시 연결하고 선도 이리저리 바꿔봄 폰 살때 줬던 충전기는 몇년을 썼는데 얘는 왜이러나
# ----------------------------------------
# 7. 좋아요충전잘되네요 굿굿굿
# ----------------------------------------
# 8. 충전기 고장나서 당일배송보고 주문했는데 이틀뒤에나 배송준비하네요 ㅠ
# ----------------------------------------
# 9. 잘못시켜서 반품도 안되는 버리기엔 아까운...
# ----------------------------------------
# 10. 잘 산거같애요 잘쓰게 습니다.
# ----------------------------------------
# 11. 물건은 당연히 좋아아하고 문제없이 잘 작동되네요.
# 근데 배송받고나니 영 찜찜했던건 어쩔수없네요.
# 택배 라벨에 쓰여진 사후처리 관련된 부분만 잘하시면 별 5개 드릴수있겠는데 아쉽네요.
# 새상품인데 확인해보고 문제있으면 서비스센터가보라니요..ㅎㅎ 불량이든 뭐든 팔면 땡이라는 심보인건지요?중고도 아니고 새상품 구매한건데 문제있으면 당연히 교환해주고 판매자측에서 교환하든 수리하든 하는게 맞지않을까요?
# 정상작동돼서 다행이지 불량이었으면 한바탕할뻔했네요.
# 이런 뽑기 운에 맡겨서 불편을 감수해야하는거였다면 구매안했을텐데요.
# 차라리 상세페이지에 주의사항으로 써 놓으시는게 맞아보이네요.
# ----------------------------------------
# 12. 1점도 아깝습니다
# 서비스센터 가기 귀찮아서 인터넷배송 시킨건데
# 몇번 쓰지도 않은채로 일주일만에 고장나고
# 교환은 또 서비스센터 직접 가야되네요
# 제품 질이 너무 랜덤이에요
# ----------------------------------------
# 13. 줄이 없어서 사용 못함
# 이딴게 다있어
# ----------------------------------------
# 14. 아이폰 사용중인데 고속충전이 안되네요
# ----------------------------------------
# 15. 초고속을 샀는데 집에있는 고속보다 느려요
# ----------------------------------------
# 16. 핸드폰 충전 대박나게 빨라서 너무좋아요
# ----------------------------------------
# 17. 조아요
#  충전이 너어무 느립니당
# 절대 사지 마세요
# 별 반 개는 없나 뮬라
# ----------------------------------------
# 18. 배송 지연
# 담당자 응대
# 별점 0개
# ----------------------------------------
# 19. 30분꽂고 보니 18프로충전됨..
# 참고로 갤23
# 후기잘안쓰는데 좀 확실히했음좋겠습니다
# ----------------------------------------
# 20. 금방 불량나서 다시.샀어요
# ----------------------------------------
# 21. 버렸습니다.....
# ----------------------------------------
# 22. 충전은 빠른데 딱 10일 쓰니 충전이 안되네요, 여기에서 두번째 구매하는데, 첫번째꺼는 그래도 몇달 썻는데, 본인관리소홀이라 생각하고 두번째 구매했는데, 불량이 많은가봐요
# ----------------------------------------
# 23. 정품이라 적혀있어서 알리구매안하고 사줬는데 두달만에 고장이네요ㅠ 충전안되요ㅜ
# ----------------------------------------
# 24. 정품 아닌듯 충전 개느린
# ----------------------------------------
# 25. 저는 사용 하루만에 고장 났어요 ..
# 1. 일주일내로 고장이나 불량있으면 A/S가능하다해서 A/s나 교환가능한가 문의했는데 단자가 그을린 자국이 있어서 제가 단자에 이물질 있는 상태에서 사용 한거라 근처 가까운곳에서 A/S 받으라는 답변
# 2. 정품은 씨리얼 번호 있다고 설명이 있는데 배송받은건 찾아도 아무리 찾아도 씨리얼번호가  없어요
# 이것도 문의하니까 확률적으로 걸릴수있대요.. 씨이얼 번호 없어도 제가 정품이 맞는지 불안하지만 감안하고 써야하는거겠죠..? ㅠㅠ
# ----------------------------------------
# 26. 몇천원 더 주더라도 쿠팡에서 그냥 정품 충전기 사고말지 조금 싸게사려한 내 잘못이다ㅋㅋ
# 이 글 본 분들은 이 리뷰 읽고나서 사는 거 다시 한번 생각해보세요. 이런 리뷰 남겨보는 것도 처음인데 상품 질, 서비스 응대 뭐하나 신박하지 않은게 없는 곳이네 ㅋㅋ
#  아니 뭐 험하게 다룬 적도 없고 집에서 침대 옆에다 두고 살살 쓰는데, 핸드폰에서 충전기 분리할 때 갑자기 심이 휴대폰에 박혀서 같이 빠져버리네요.
# 그러고 문의로 이거 이상하다, 충격 준 적 당연히 없고 살살 썻는데 2달 좀 넘어서 얘가 갑자기 분리됐다니까 &ldquo; 한달 지났네? a/s 안돼. 교환? ㅋㅋ 당연히 안되지 ㅋㅋ &rdquo; 이런 식으로 나와버리네요.
# 케이블 내구도 왜 이래요 이거? 정품은 맞아요? 아니 두달 좀 넘게 썻고 자기 전에 충전기 연결 해놓는 정도로 쓰는데 , 무슨 삐꺽댄다거나 하는 징조도 없이 이세계로 떠나버리니까 허망하네 이거.
# 뭐 정상인 것들도 팔겠지만 확률게임으로 삐리한 거 배송될 수도 있습니다 다시 생각해보세요.
# 할 것도 많은데 별 이상한걸로 스트레스 받으니까 기분 최고네 ㅋㅋ
# 조심하세요 운 나쁘면 케이블이던 어뎁터던 금방 발할라로 떠나버리는 놈들 오니까.
# ----------------------------------------
# 27. 살때마다 제것만 이런것인지..집 불태울뻔했습미다
# 이러고 혼자 있는거 냄새나서 발견했어요
# ----------------------------------------
# 28. 하루쓰고 바로 망가졌어요...
# ----------------------------------------
# 29. 불량이 왔네요 귀찮아서 환불은 안합니다
# ----------------------------------------
# 30. 고장난 상태로 왔어요 문의 넣었는데 연락도 없었고
# 제 폰이 이상한줄 알았는데 다른 충전기는 다 돼요 걍 사지 마세요 ^^ 허공에 돈도 날리고 시간도 날리고 최악이요~
# ----------------------------------------
# 31. 고장나서 안 됩니다....
# ----------------------------------------
# 32. 정품이라고 구매했는데, 설명과 달리 애플 정품 케이블과 비교 결과 인증번호가 없네요.
# ----------------------------------------
# 33. 아니 이거 산 지 얼마 안됐는데 벌써 고장나서 충전이 안 돼요 뭐지?
# ----------------------------------------
# 34. 충전 너무 느립니다.. 2천원짜리랑 비슷하네요.. 돈 아까움ㅜㅜ
# ----------------------------------------
# 35. 책상에서 한번 떨어트렸을뿐인데 충전하는곳이 휘어버렸네요; 저번에 샀던 것도 앞이 휘어서 못쓰게 돼서 새로산건데 이번에 또 이렇네요 ㅠ
# ----------------------------------------
# 36. 그냥 가격대비 그냥그냥
# ----------------------------------------
# 37. 정품박스라는말 빼세요 충전기만 이라고 올리세요 소비자들 현혹시키지말고요
# ----------------------------------------
# 38. 케이블하고 따로따로면 소비자가 혼돈안하게 사진올리세요 사기치지말고요
# ----------------------------------------
# 39. usb타입 아이폰 케이블 삿다가
# 충전기에 꽂기만하면 충전기가 바로 먹통되네요
# 덕분에 아이폰 정품 충전기 2개 버렸습니다
# 환불신청했더니 문제없다고 환불거절당했네요
# 만원 이만원 돈문제가 아니라 이건뭐 사람 머저리 취급하는데 기분 산뜻합니다
# ----------------------------------------
# 40. 교환이나 환불하려면 서비스센터에 직접 가서 확인받고
# 진행해야한다는게 번거로워요
# ----------------------------------------
# 41. 45W 충전안됩니다 혹시나 해서 충전속도 나오는 케이블로 했는데 20W가 최고속도네요 단독으로만충전해도
# 이미 구매한지 시간이 지나서 뭐 어떡할수도 없고
# 억울하네요 45w충전하려고 샀는데 25w 충전기보다 못하니
# ----------------------------------------
# 42. 뽑기운이없었나요.ㅜ
# 충전이빠른것도아니고,, 중간에선이그냥힘없이빠져요.이거불량아닌가
# ----------------------------------------
# 43. 정품이라고 샀는데 초고속이 안되는 이윤 멀까요? 작년에 샀던 충전기는 여전히 초고속으로 뜨는데 괜히샀네요
# ----------------------------------------
# 44. 8월에 2개 구입했는데 벌써 1개고장남ㅡㅡ
# ----------------------------------------
# 45. 초고속 아닙니다 속상해요
# ----------------------------------------
# 46. 배송이 오래걸려서 별 하나드려요...
# ----------------------------------------
# 47. 일반적인스타일이아니고
# 양쪽C핀스타일이라
# 튼튼할줄알앟고
# 무게가있어
# 든든한감이있었는데
# 고장 ㅠㅠ
# 꽤 비싸게주고 삼성정품이라구매했는데
# 완전실망 ㅠㅠ 어디가서. 하소연합니까
# ----------------------------------------
# 48. 최악 2주만에 충전안됨 무슨일? 문의글 남겨놨는데 저한테도 서비스 센터 가라고하면 저 이 리뷰 안지우고 여기 판매자 신고할꺼임 삼성 정픔이라길래 믿고 구매했더니 장난하는것도 아니고 차량용충전기도 동시충전된다길래 샀더니 안되서 문의 했더니 영상 찍으라고하더니  제품을 보내야 받을 수 있다함 내가 지금 필요해서 시켰더니 일주일 넘게 사용도 못하게하고 일처리를 뭐 이렇게해요?
# ----------------------------------------
# 49. 얼마 안가서 충전이 안됩니다!! 충전기선은 문제가 없는데.. 이상하게 충전이 안됩니다 답장부탁드려요
# ----------------------------------------
# 50. 이번에 폰 바꾸며 일부러 비싼 삼성 정품 충전기 45w 샀는데....정품 25w랑 속도가 같아요. 충전라인도 같이 정품 세트인데....어떻게 그렇죠?? 충전기는 튼튼해보이는데 성능이 꽝이네요.
# ----------------------------------------
# 51. 캡쳐사진은 올릴수가 없네요
# 배송기간이 총 4일 이였습니다.
# 오남집배센터에서 중부권 메가허브까지 이송하는데  23시간 걸렸습니다.
# 해외에 있나봅니다. 대한민국이 아닌거지요
# 중부권 메가허브에서 도착지 대리점까지 9시간 소요 되었습니다.
# 어딘가 해외에 경유지가 있나봅니다.(오전 7시 도착지 대리점 도착)
# 그리고 그날 밤 12시 고객이 인수했답니다.
# 저는 아닙니다. 귀신이 인수확인했나봅니다.
#
# 그리고 다음날 새벽  5시  배송완료 뜹니다.
# 그게 오늘 입니다.
# 오늘은  급하게 일찍 출근하느라 5시 50분에 빌라 현관에 나왔지요
# 전통육게장 1톤 차량에서 왠 택배물건이라고 생각하는 찰라 .. 혹시나 했더니 맞습니다. ㅡ.ㅡ
#
# 대단한 롯데 택배입니다.
#
# 일단 상품은 써봐야 알겠지만 판매처의 같은 상품이  여러다른가격으로 판매되니 필히 확인하세요
# 가능하시면 롯데 택배  상품은  거르시는게 좋을듯합니다
# 수도권을 제외하고 각지역에 롯데 택배 대리점이 많은곳은  상관 없을지라도 이건 이닌듯합니다. 여긴 창원 진해입니다.
#
#  도대체 어느고객이 인수를 한겁니까?
# 당사자는 인수확인도 안했는데!!!!
#
# 거짓 배송조회에 화가 납니다.
# 배송철회하려다 번거로워서 그냥 쓸건데.
# 왠만하면 클레임 걸지도 않지만 휴..
#
# 어차피 판매자는 글도 안볼꺼라 생각합니다
# 리뷰보시면 아실껍니다.
#
# 바뻐서 대충보고 구매했더니 이런 ㅡ.ㅡ
# 절대 이 판매자에겐 구매안합니다.
# 저는 그러합니다.
#
# 또다른 구매자에게 도움이 될지는 모르지만 참고하세요!
# ----------------------------------------
# 52. 충전기 받고 충전 안되서 서비스샌터 방문하니 케이블 불량이라 새걸로 바꿔준다고해서 새충전케이블 받아와서 쓸려고 보니 또 충전이 안됨  불량
# ----------------------------------------
# 53. 충전기 10회 사용도 안했는데 고장이네요
# ----------------------------------------
# 54. 신세계가 열렸읍니다..... 고민하다 좀 더 비싼걸로 산건데 돈이최고네여..정품이라그래서 믿고 씁니다
#
# ++ 고장났습니다 갑자기 충전이 안돼요. 정품인지 의심가네요;
# ----------------------------------------
# 55. 신세계네요..고민하다 1.8m 더 긴걸로 샀는데 삶의질이 높아졌어요 정품이라고 그래서 믿고씁니다
#
# ++ 고장났습니다 갑자기 충전이 안돼요 진짜 정품인지 의심가네요;
# ----------------------------------------
# 56. 으악...진짜 삼성꺼뿐이 안됨 ㅋㅋㅋ
# 테블릿 충전 안되요 ㅡㅡ
# ----------------------------------------
# 57. 케이블이 완전 뻣뻣해서 사용하기 아주불편해요
# 삼성정품이 맞는지 의심스럽네요
# 비추 비추입니다
# ----------------------------------------
# 58. 너무 느려요.. 제꺼만그런건지ㅡㅡ
# 돈아까워요 2개나샀는데..
# 일반충전보다못한듯
# ----------------------------------------
# 59. 충전기랑 선 세트로 샀는데 충전기는 하루만에 고장났어요. 어차피 선이 휘었던거라 원래 가지고 있던 충전기 헤드에 새 선 연결해서 사용하고는 있어요.
# 선만 샀으면 만원이었을걸 돈 낭비한것 같네요.
# 아무리 못해도 한달은 버텨야하는건 아닌가요?
# 선은 당장 필요하고 한동안 바빠서 굳이 환불하진 않았지만 하루만에 고장나는건 좀 너무하네요. 이거 혹시 as되나요?
# ----------------------------------------
# 60. 택배를 뜯고보니 저는 포장씰을 뜯지 않았는데 한쪽 부분이 뜯겨져 있었습니다. 이유가 어떻든간에 포장이 뜯긴 상품을 받아 기분이 좋지 않았습니다. 문의를 남기니 배송상의 문제라고 하시며 교환을 원하신다면 단순변심에 의한 교환으로 배송비를 부담하라고 하시네요. 개봉된 상품을 보내지 않으신다는 말 믿고 그냥 사용해보려합니다. 정말 배송중 패키지 파손이라면 포장에 조금 더 신경 써 주시면 좋을 것 같습니다.
# ----------------------------------------
# 61. 배송이 너무 늦어요
# ----------------------------------------
# 62. 벌써 고장이 났습니다
# 2개다 충전이 안됩니다!
# ----------------------------------------
# 63. ※ 여기서 구매하지 마세요 ※
#
# 택배상자가 아닌 택배봉투에 담겨왔고 배송은 빨랐습니다 근데 사진보시면 종이박스가 열려있고 구겨져 있어요 새상품 구매했는데 던져놓은 중고상품처럼 생겨서 교환요청 했더니 상품에 문제 있는게 아니라 거절 당했네요 종이박스 파손 안나게 발로 하지 말고 눈으로 봐가며 포장 꼼꼼히, 검수 제대로 하시길. 이런 것까지 알려줘야하니 너무 힘드네요 여기서 구매 할 것 같으면 삼성 가서 직접 구매하시는걸 추천해드립니다
# ----------------------------------------
# 64. 일주일만에 고장나고 다른 케이블도 다 상태 안좋음
# 근데 고장나면 서비스센타 찾아가라함 ㅋㅋㅋ
# 절대로 여기서 사면 안됨 돈 더주고 쓸만한걸로 사셈
# ----------------------------------------
# 65. 검은색 케이블 사용 3일만에 망가졌네요. 사용환경은 기존 쓰던 케이블과 동일한데 몇년전 산건 멀쩡하고 이건 3일만에 먹통. 가격이 싼것도 아닌데 이러니 사기당한 기분입니다.
# ----------------------------------------
# 66. 일주일도 안돼 케이블 손상되고 ㅈㄹ
# 교환도 안됨 서비스 센타 가라고함
# 절대 여기서 사지마세요
# ----------------------------------------
# 67. 일주일도 안돼 케이블 손상되고 ㅈㄹ
# 교환도 안됨 서비스 센타 가라고함
# 절대 여기서 사지마세요
# ----------------------------------------
# 68. 엣날에는 선도 줬는데, 가격내리면서 선을 없앴어요.
# 가격도 합가격이면 더 비싸요
# ----------------------------------------
# 69. 주말에 샀는데 가격이 다운이 되었군요.. 충전은 잘됩니다
# ----------------------------------------
# 70. 많이 느려요...정품 맞는건지..
# ----------------------------------------
# 71. 엉망으로 왔어요 상자도 다 구겨지고 찢어지고, 개봉씰도 마치 뜯어본것처럼 지저분해서 받자마자 기분이 상했네요~ 반품하고 싶었지만 정상배송이러네요 문제없이 오래 쓸 수 있길 바래야죠ㅎ 다음에 구매할일 있으면 다른 곳에서 사야겠어요~ㅎ
# ----------------------------------------
# 72. 이거 완전 삼정전자에 먹칠하는 짓임.
# 삼성서비스센터 직원들이 수리기사지
# 교환원이 되서는 안됨. 팔지말아라.
# ----------------------------------------
# 73. 차량용 충전기네요 이게 어딜봐서 핸드폰 충전인지
# ----------------------------------------
# 74. 산지 하루만에 고장났네요 반품하기 귀찮아서 버릴듯...충전기 하루만에 고장나는건 처음이네요
# ----------------------------------------
# 75. 너무비싸고 진짜 별로별로에요
# 잘읽어보고사세요 케이블은 별도구매 해야합니다
# ----------------------------------------
# 76. 포장이 아주 저질 입니다 물건 뿌셔지면 교환처리 쉽개 해줄 겁니까!! 인간적으로 박스포장에 에어캡 감아서 보내 주세요!
# ----------------------------------------
# 77. 1월 16일에 구매했는데 해외여행와서 지금 고장났습니다... 좀 어이없네요 비싼돈주고샀는데 해외라서 교환할수도 없고 좀 별롭니다
# ----------------------------------------
# 78. 12월에 구매한건데 벌써안되네요
# 불량품을 받은건지...
#
# C to C선은 괜찮은데
# 충전기가 안되요!
# ----------------------------------------
# 79. 35w라 샀는데 급속충전 표시만뜨고 충전속도는 겁나느리네요 집에있던 정품충전기랑 충전속도 2배 나네요;;  걍일반 충전기 속도에요.
# ----------------------------------------
# 80. 잘쓰고 있긴한대 1m 케이블 선이 얇음
# 다음번엔 안살거같음
# ----------------------------------------
# 81. 삼정정품이라고적혀잇길래삿는데 정품이아니네요? 정품은 최고속으로 뜬다는데 이제품은 고속으로뜨네요? 이게무슨정품입니까? 가서 사는것보다 저렴해서 산건데 그게 잘못이엿네요 삼성전자가서 사는게최고네요ㅎㅎ
# ----------------------------------------
# 82. 아니 ... 너무 느려서 속터지겠어요 ㅠㅠ 집에 있는것도 느려서 샀는데 .. 주문한게 더 느립니다 ㅠ 불량인건지 .. 반품하고싶어요
# ----------------------------------------
# 83. 물건이 반품제품 인지 박스가 찢어져 인내요
# 반품 할려다가 충전기가 없어 그냥 사용 합니다
# 삼성 공식파너라고 했어 믿고 구매했는데 실망입니다
# ----------------------------------------
# 84. 초고속 충전기 절대아님!!!
# 충전속도 드~~~ 럽게 느려터졌음!!!
# ----------------------------------------
# 85. 충전이 많이 느려요... 한달사용 후기입니다 망가져서 버렷네요
# ----------------------------------------
# 86. 제품 사용 하다가 갑자기 안되내요
# 아쉽네요
# ----------------------------------------
# 87. 잘쓰고 있고 고장안나길바래요
# ----------------------------------------
# 88. 충전은 잘 되지만 초고속 충전인지는 잘 모르겠네요. 빨리 될 때와 그저 그런 속도로 충전될 때가 상황마다 다른 것 같습니다. 참고하시길 바랍니다.
# ----------------------------------------
# 89. 그냥저냥 쓸만해요...감사합니다
# ----------------------------------------
# 90. 충전은 잘되는데
# 충전하면서 이어폰 사용하면
# 이어폰에서 웅웅 비슷한 소리가 울림.
# 불량?
# ----------------------------------------
# 91. 편리하게 잘사용하고 있어요.
# ----------------------------------------
# 92. 생각보다는 충전이 빨라요
# ----------------------------------------
# 93. 공기계 폰 충전하려고 집에 없어서 구매했고
# 충전도 잘되요 빠른충전인지는 잘 모르겠어요
# ----------------------------------------
# 94. 잘도착했어요...정품같아요...
# ----------------------------------------
# 95. 저렴한 가격이 좋아요...
# ----------------------------------------
# 96. 샤오미 배터리 충전하려고 샀어요 괜찮아요
# ----------------------------------------
# 97. 쓰기편해 잘쓰고 있어요
# ----------------------------------------
# 98. 충전속도 좀느리다고하니까 고객선터가 민약에 문제없으면 노 배송비 전부 부담해야한다 이런통보식으로 말하니까 좀 말투가 되게 딱딱함
# ----------------------------------------
# 99. 아주마음에 드는 제품이네요 잘받았습니다
# ----------------------------------------
# 리뷰 개수 : 100

# %%
bad_review_df = pd.DataFrame(review_contents, columns=["리뷰 내용"])
bad_review_df
# Out:
#                                                 리뷰 내용
# 0                                       에이에스 맡겨야 해요ㅜㅜ
# 1   내 폰이 이상한가 처음 한두번은 잘대더니\n이제는 아예 반응이 없네요 ㅡㅡㅋ\n한달...
# 2     충전속도가  별로 빠르다는걸 못느낌\n  마트에파는 일반충전기랑 충전되는 속도가 비슷
# 3                  중간에 계속 충천 멈추고, 나중에는 그냥 충천이 아예 안되요.
# 4                                          ，，，，，，，，，，
# ..                                                ...
# 95                                     저렴한 가격이 좋아요...
# 96                             샤오미 배터리 충전하려고 샀어요 괜찮아요
# 97                                       쓰기편해 잘쓰고 있어요
# 98  충전속도 좀느리다고하니까 고객선터가 민약에 문제없으면 노 배송비 전부 부담해야한다 ...
# 99                              아주마음에 드는 제품이네요 잘받았습니다
#
# [100 rows x 1 columns]

# %%
bad_review_df.to_excel(f"BadReview/{keyword}_BadReview.xlsx", index=False)
